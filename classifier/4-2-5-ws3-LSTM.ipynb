# %%
import sys
import os
sys.path.append('/home/franzi/anzeigendaten/python_base/skillextraktion/fh_ma')
sys.path.append('/home/franzi/anzeigendaten/EnvPython')
import prepare_training_data
from labels import *
import time
import warnings
warnings.filterwarnings('ignore')

from sklearn.utils import shuffle
import numpy as np
np.set_printoptions(precision=3)
# %precision 3
start = time.time()
x_train, y_train, x_test, y_test, test_afks, features = prepare_training_data.get_training_data(window=3)
print('took: ',time.time()-start)
# Out:
# 20861874
# 0
# skipgram, punctuation_marks, stoppwords, multiword, lower_case, vector_dim True False False False False 100
# init /home/franzi/Documents/models/no_pm_no_sw_vecDim100/skip_gram_model.model
# loading existing w2v model from  /home/franzi/Documents/models/no_pm_no_sw_vecDim100/skip_gram_model.model
# using data from  /home/franzi/Documents/data/data_3_vecDim100
# processing data...
# Found  1298  training entries.
# Found  1298  cleaned entries.
# /home/franzi/Documents/data/vectors.npy
# window 3
# window 3
# 36942 36942 11756 11756 0 0
# took:  5.578910827636719

# %%
from tensorflow.keras import *

# %%
# Build the model
print('Build model...')
model = Sequential()
model.add(layers.LSTM(256, return_sequences=True, input_shape=(x_train.shape[1],x_train.shape[2])))
model.add(layers.Dropout(0.5))
model.add(layers.BatchNormalization())
model.add(layers.LSTM(512, return_sequences=True))
model.add(layers.Dropout(0.5))
model.add(layers.BatchNormalization())
model.add(layers.LSTM(256))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256))
model.add(layers.Dense(units=len(labels)))
model.add(layers.Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

batch_size=64
history = model.fit(x_train, y_train, batch_size=batch_size, shuffle=True, epochs=5, validation_data=(x_test, y_test))
# Out:
# Build model...
# 2020-08-31 12:38:46 WARNING: From /home/franzi/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 36942 samples, validate on 11756 samples
# 2020-08-31 12:38:50 WARNING: From /home/franzi/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/5
# 36942/36942 [==============================] - 118s 3ms/sample - loss: 0.8742 - acc: 0.6773 - val_loss: 0.6488 - val_acc: 0.7673
# Epoch 2/5
# 36942/36942 [==============================] - 106s 3ms/sample - loss: 0.5726 - acc: 0.7949 - val_loss: 0.5667 - val_acc: 0.7983
# Epoch 3/5
# 36942/36942 [==============================] - 109s 3ms/sample - loss: 0.4909 - acc: 0.8276 - val_loss: 0.4734 - val_acc: 0.8365
# Epoch 4/5
# 36942/36942 [==============================] - 106s 3ms/sample - loss: 0.4445 - acc: 0.8446 - val_loss: 0.4464 - val_acc: 0.8518
# Epoch 5/5
# 36942/36942 [==============================] - 105s 3ms/sample - loss: 0.4138 - acc: 0.8550 - val_loss: 0.4636 - val_acc: 0.8454

# %%
from matplotlib import pyplot as plt
plt.plot(np.arange(1, len(history.history['acc'])+1), history.history['acc'])
plt.plot(np.arange(1, len(history.history['acc'])+1), history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim(0.65,0.9)
plt.xticks(np.arange(1, len(history.history['acc'])+1))
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# predict test data
y_pred = model.predict(x_test)

# %%
import numpy as np
# convert one hot to labels for test data
pred_label = prepare_training_data.one_hot_to_labels(y_pred)
true_label = prepare_training_data.one_hot_to_labels(y_test)

# %%
# Calc metrics for test data
import sklearn
from sklearn.metrics import precision_score, recall_score
from tabulate import tabulate
label_list = list(labels.keys())

headers = [l for l in label_list ]
headers = [' '] + headers

table=[['precision'] + list(precision_score(true_label, pred_label, average=None)), 
       ['recall']+list(recall_score(true_label, pred_label, average=None)), 
       ['f1']+ list(sklearn.metrics.f1_score(true_label, pred_label, average=None))]

print(tabulate(table, headers=headers, tablefmt='orgtbl'))
f1 = sklearn.metrics.f1_score(true_label, pred_label, average=None)
f1 = np.delete(f1, 4)
f1 = np.delete(f1, 6)
print('f1 average: ',sum(sklearn.metrics.f1_score(true_label, pred_label, average=None))/len(list(precision_score(true_label, pred_label, average=None))))
print('f1 average: ',sum(f1)/6)
print('Precision average: ',sum(precision_score(true_label, pred_label, average=None)/8))
print('recall average: ',sum(recall_score(true_label, pred_label, average=None)/8))
print('acc', sklearn.metrics.accuracy_score(true_label, pred_label))
# Out:
# |           |   Ausbildung |    Beruf |   allgemein |   berufsspez |   Sprache |   Technologie |   Softskill |   noSkill |
# |-----------+--------------+----------+-------------+--------------+-----------+---------------+-------------+-----------|
# | precision |     0.820789 | 0.692308 |    0.590331 |     0.627557 |  0.950893 |      0.666667 |    0.783514 |  0.919892 |
# | recall    |     0.848148 | 0.145161 |    0.32357  |     0.551561 |  0.963801 |      0.903311 |    0.87698  |  0.930432 |
# | f1        |     0.834244 | 0.24     |    0.418018 |     0.58711  |  0.957303 |      0.767154 |    0.827617 |  0.925132 |
# f1 average:  0.6945722646321945
# f1 average:  0.6123570845032861
# Precision average:  0.7564936121129995
# recall average:  0.6928707368574912
# acc 0.8454406260632868

# %%
# Create Confusion Matrix

import sklearn
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

cm = sklearn.metrics.confusion_matrix(true_label, pred_label)
df_cm = pd.DataFrame(cm, labels,columns = labels)
plt.figure(figsize = (10,7))
plt.ylabel('Eingabe')
plt.xlabel('Ausgabe')
sn.heatmap(df_cm, annot=True,fmt='g')

# %%
# clean noSkill for evaluation
clean_y_pred = []
clean_y_test = []
true_noSkills = 0
clean_x_test = []
afks = []

for i in range(len(y_test)):
    if(true_label[i] != 7 or pred_label[i] != 7):
        clean_x_test.append(x_test[i])
        clean_y_pred.append(pred_label[i])
        clean_y_test.append(true_label[i])
        afks.append(test_afks[i])
    else:
        true_noSkills += 1
pred_label = clean_y_pred
true_label = clean_y_test
print('correctly labeled noSkills: ', true_noSkills)
# Out:
# correctly labeled noSkills:  6821

# %%
# Create Confusion Matrix

import sklearn
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

cm = sklearn.metrics.confusion_matrix(true_label, pred_label)
df_cm = pd.DataFrame(cm, labels,columns = labels)
plt.figure(figsize = (10,7))
plt.ylabel('Eingabe')
plt.xlabel('Ausgabe')
sn.heatmap(df_cm, annot=True,fmt='g')

# %%
from word2vec import W2V
correct = []
false = []

clean_x_test, pred_label, true_label, afks = shuffle(clean_x_test, pred_label, true_label, afks,random_state=0)
skill_index = int(len(clean_x_test[0])/2)
label_list = list(labels.keys())

# %%
headers = [['|']+[l] for l in label_list ]
headers = sum(headers, [])
headers.append('|')

wvs = []
for i in range(len(clean_x_test)):
    wvs.append(clean_x_test[i][skill_index])

w2v = W2V(skipgram=True, punctuation_marks=False, stoppwords=False, multiword=False, lower_case=False, vector_dim=100)

predictions = [[],[],[],[],[],[],[], []]
for i in range(len(clean_x_test)):
    word = w2v.get_closest_word_to_vec(wvs[i])[0][0]
    label = str(true_label[i])
    predictions[pred_label[i]].append(word + '('+label+')')

table = []
# format
i = 0
while(i < len(predictions[0]) or i < len(predictions[1]) or i < len(predictions[2]) or i < len(predictions[3]) or i < len(predictions[4]) or i < len(predictions[5] or i < len(predictions[6]))):
    row = ['|']
    for x in predictions:
        if(len(x) > i and len(x[i]) <  25): 
            row.append(x[i])
            row.append('|')
        else:
            row.append('')
            row.append('|')
            
    table.append(row)
    i+=1    

print(tabulate(table, headers=headers))
# Out:
# skipgram, punctuation_marks, stoppwords, multiword, lower_case, vector_dim True False False False False 100
# init /home/franzi/Documents/models/no_pm_no_sw_vecDim100/skip_gram_model.model
# loading existing w2v model from  /home/franzi/Documents/models/no_pm_no_sw_vecDim100/skip_gram_model.model
# |    Ausbildung                |    Beruf                |    allgemein                 |    berufsspez                |    Sprache                   |    Technologie               |    Softskill                 |    noSkill                   |
# ---  ------------------------  ---  -------------------  ---  ------------------------  ---  ------------------------  ---  ------------------------  ---  ------------------------  ---  ------------------------  ---  ------------------------  ---
# |    Elektrotechnik(0)         |    Gipser(1)            |    Reisebereitschaft(7)      |    Mieten(3)                 |    Englischkenntnisse(4)     |    Python(5)                 |    Offene(6)                 |    hektischen(6)             |
# |    Elektrotechnik(0)         |    CNC-Dreher(5)        |    Kunden(7)                 |    Vertriebserfahrung(7)     |    Deutschkenntnisse(4)      |    WebSphere(5)              |    Analytisches(2)           |    Berufsausbildung(0)       |
# |    Regelungstechnik(0)       |    Bautechniker(0)      |    Kunden(2)                 |    Versandbereich(3)         |    Englischkenntnisse(4)     |    Deployment(3)             |    Teamfähigkeit(6)          |    Offenheit(6)              |
# |    Engineer(1)               |    Gipser(1)            |    Montagebereitschaft(7)    |    Gefahrenmeldetechnik(3)   |    Deutschkenntnisse(4)      |    Office-Paket(5)           |    Organisationstalent(6)    |    Weiterbildung(2)          |
# |    HwO(7)                    |    Kfz-Meister(1)       |    Kundenorientierung(2)     |    Zahlungssystemen(3)       |    Deutschkenntnisse(4)      |    Greenfield(5)             |    Teamfähigkeit(6)          |    Facharzt(1)               |
# |    Gipser(0)                 |    CNC-Dreher(5)        |    Umsetzung(2)              |    Bank(3)                   |    Deutsch(4)                |    CSS(5)                    |    selbstständig(6)          |    vernetztem(6)             |
# |    Informatik(0)             |    Gipser(1)            |    Gabelstaplerschein(3)     |    Türen(3)                  |    Spanisch(4)               |    JavaScript(5)             |    Eigeninitiative(6)        |    Weiterbildung(3)          |
# |    Anwendungsentwicklung(3)  |    prozessbasierten(7)  |    Kunden(2)                 |    Schaltgerätebau(3)        |    Französisch(4)            |    SVN(5)                    |    Eigenverantwortliche(6)   |    rasche(6)                 |
# |    juristisches(0)           |    Serviceberater(1)    |    Führerschein(2)           |    Transport(2)              |    Englischkenntnisse(4)     |    JS(5)                     |    teamfähig(6)              |    Deutsche(4)               |
# |    kaufmännische(0)          |    Gipser(1)            |    Vorstellungsvermögen(2)   |    Türen(3)                  |    Deutschkenntnisse(4)      |    Microsoft(3)              |                              |    Pair(3)                   |
# |    Softwareentwickler(0)     |    Gipser(1)            |    Führungserfahrung(2)      |    technischen(3)            |    Französischkenntnisse(4)  |    BPM(5)                    |    Führungsfähigkeit(6)      |    Macherpersönlichkeit(6)   |
# |                              |    Maler(1)             |    Führerschein(2)           |    Gas(3)                    |    Englisch-Kenntnisse(4)    |    MySQL(5)                  |    Analytisches(6)           |    kundenspezifische(2)      |
# |    Informatik(3)             |    Lackierbereich(1)    |    Schichtarbeit(2)          |    Finanzsektor(3)           |    Englisch(4)               |    Linux(5)                  |    Motivation(6)             |    internationale(3)         |
# |    Diätkoch/-köchin(0)       |                         |    Kundenorientierung(2)     |    LKW(7)                    |    Deutschkenntnisse(4)      |    i/Power(5)                |    Zeitliche(7)              |    Inhouse-Recruiting(3)     |
# |    Elektrotechnik(0)         |                         |    Randzeiten(7)             |    Kundenbetreuung(2)        |    Deutschkenntnisse(4)      |    BluePrism(5)              |    flexibel(6)               |    schichtdiensttauglich(2)  |
# |    Wirtschafts(0)            |                         |    Projektbezogene(7)        |    Geschäftsprozesse(7)      |    deutschen(4)              |    jenkins(5)                |                              |    Alter(2)                  |
# |                              |                         |    Erstellen(2)              |    GMP-Umfeld(5)             |    Deutschkenntnisse(4)      |    Java(5)                   |                              |    Psychotherapie(3)         |
# |    technischer(0)            |                         |    Reisebereitschaft(7)      |    IT-Security(3)            |    Englischkenntnisse(4)     |    Programmierkenntnisse(3)  |    Zuverlässigkeit(6)        |    Schulabschluss(0)         |
# |    Fachinformatiker(0)       |                         |    Entwicklung(3)            |    Programmoptimierung(3)    |    englischer(4)             |    Java(5)                   |    Flexibilität(6)           |    verantwortungsvolle(6)    |
# |    Interface/Interaction(0)  |                         |    Kunden(2)                 |    Montage(2)                |    Englischkenntnisse(4)     |    Python(5)                 |    Belastbarkeit(6)          |    Berufsausbildung(0)       |
# |    Mechatronik(3)            |                         |    handwerkliches(2)         |    EN(3)                     |    Englischkenntnisse(4)     |    SAP(5)                    |    Kooperationsfähigkeit(6)  |    Systemen(3)               |
# |    CTA(0)                    |                         |    Serviceorientierung(2)    |    Fenstern(3)               |    Deutschkenntnisse(4)      |    Object(3)                 |    Kommunikationsstärke(6)   |    Verantwortung(6)          |
# |    Krankenpfleger(0)         |                         |    Reisebereitschaft(2)      |    Trends(7)                 |    Deutschkenntnisse(4)      |    .Net(5)                   |    Flexibilität(6)           |    externen(2)               |
# |    Wirtschaftsinformtik(0)   |                         |    Fahrerlaubnis(2)          |    Installation(2)           |    Englischkenntnisse(4)     |    JavaSript(5)              |    Eigenverantwortung(6)     |    neugierig(6)              |
# |    Betriebselektriker(0)     |                         |    Koordination(2)           |                              |    Englischkenntnisse(4)     |    Ranorex(5)                |    Führungsfähigkeit(6)      |                              |
# |    Logistiker(0)             |                         |    Reisebereitschaft(2)      |    Demontage(3)              |    französisch/deutsch(4)    |    ASP.NET(5)                |    Denkweise(7)              |    and(3)                    |
# |    Software(0)               |                         |    Führerschein(2)           |    Sozialmedizin(3)          |    Englischkenntnisse(4)     |    ERP(7)                    |    Konfliktfähigkeit(6)      |    Zusammenarbeit(2)         |
# |    Informatik(0)             |                         |    Kunden(2)                 |    Entwicklung(3)            |    Deutsch(4)                |    Omicron(5)                |    Durchsetzungsvermögen(6)  |                              |
# |                              |                         |    Kundenorientierung(2)     |    Psychotherapie(0)         |    Englisch(4)               |    HTML(5)                   |    lösungsorientiert(6)      |    Führung(2)                |
# |    Physik(0)                 |                         |    Schichtbetrieb(2)         |    Prozessmanagement(3)      |    Englischkenntnisse(4)     |    Frameworks(3)             |    Kommunikation(6)          |    Bestandskunden(2)         |
# |    Informatik(0)             |                         |    Schichtarbeit(2)          |    Business(3)               |    Englischkenntnisse(4)     |    Office-Paket(5)           |    Teamfähigkeit(6)          |    unterrichten(2)           |
# |    Facharzt/-ärztin(0)       |                         |    Verkauf(2)                |    Administration(2)         |    Deutschkenntnisse(4)      |    MS-Office(2)              |    belastbar(6)              |    Weissputz(3)              |
# |    Psychotherapie(0)         |                         |    MS-Office(5)              |    Akutbereich(3)            |                              |    Medieninformatik(3)       |    Qualitätsbewusstsein(6)   |    freundlicher(6)           |
# |    Informatik(0)             |                         |    Verfassung(7)             |    Modellierung(2)           |    englisch(4)               |    SQL(7)                    |    Einfühlungsvermögen(6)    |    LuftSiG(3)                |
# |    Gesundheitspfleger(0)     |                         |    Statur(7)                 |    Beratungsumfeld(3)        |    Englischkenntnisse(4)     |    Server(3)                 |    gewissenhafte(6)          |    Entwicklungen(3)          |
# |    Pensionskassen(0)         |                         |    Partner(7)                |    Anlagenführer(1)          |    Deutschkenntnisse(4)      |    HTML(5)                   |    Belastbarkeit(6)          |    Gesundheits(0)            |
# |    Facharzt/-ärztin(0)       |                         |    Lebensmitteln(2)          |    Betreuung(3)              |    Deutschkenntnisse(4)      |    OO(5)                     |    lösungsorientierte(6)     |    Weiterentwicklung(2)      |
# |    BA(7)                     |                         |    Entwicklung(3)            |    Representational(7)       |    Deutschkenntnisse(4)      |    Sauberer(7)               |    Belastbarkeit(6)          |    Geschick(3)               |
# |    Informatik(0)             |                         |    Entwicklung(7)            |    Betreuungsrecht(3)        |    Englisch(4)               |    Node.js(5)                |    Belastbarkeit(6)          |    installieren(2)           |
# |    Industriemechaniker(0)    |                         |    Ortskenntnisse(6)         |    Help(3)                   |    Englischkenntnisse(4)     |    S(7)                      |    Teamfähigkeit(6)          |    innovative(6)             |
# |    Werkzeugmechaniker(0)     |                         |    hilfsbedürftigen(7)       |    Teststrategie(3)          |    Deutsch(4)                |    Framework(3)              |    Engagement(6)             |    Anwendungen(3)            |
# |    IT(7)                     |                         |    Menschen(3)               |    Entwicklung(3)            |    englischen(4)             |    Linux(5)                  |    Flexibilität(6)           |                              |
# |    Psychiatrie(3)            |                         |    Reisebereitschaft(2)      |    anzueignen(7)             |    Deutschkenntnisse(4)      |    Zendesk(5)                |    eigenverantwortlichem(6)  |    Agilität(6)               |
# |    Betriebswirt(0)           |                         |    Exzellenz(7)              |    Apps(3)                   |    Deutsch(4)                |    HTML5(5)                  |    zielorientierte(6)        |    Entwickler(3)             |
# |    Elektrotechnik(0)         |                         |    Kundenberatung(3)         |    Printlayouts(3)           |    Deutsch(4)                |    Oracle-Datenbanken(5)     |    Selbstständige(6)         |    EN(5)                     |
# |    Fleischer(0)              |                         |    Personalführung(2)        |    Richtlinien(3)            |    deutschen(4)              |    Formatierungssprache(7)   |    Zuverlässigkeit(6)        |    operative(3)              |
# |    Koch/Köchin(0)            |                         |    pädagogisches(6)          |    Betreuung(3)              |    Deutschkenntnisse(4)      |    BI(5)                     |    Selbstständigkeit(6)      |    Pflege(1)                 |
# |    Informatik(0)             |                         |    Bürotechnik(2)            |    Demontage(2)              |    Deutschkenntnisse(4)      |    JavaScript(5)             |                              |    Denken(2)                 |
# |    Controlling(0)            |                         |    Menschen(6)               |    Web-Anwendungen(3)        |    C1(7)                     |    GSAP(5)                   |    Logisches(6)              |    Ingenieurpsychologie(0)   |
# |    Medizin(0)                |                         |    Kundenorientierung(2)     |    Software-Entwicklung(3)   |    Deutschkenntnisse(4)      |    UA(5)                     |    freundliches(6)           |    Methoden(2)               |
# |    Anlagenfahrer(0)          |                         |    Umsetzung(7)              |                              |    Englischkenntnisse(4)     |    Swift(5)                  |    selbstständigen(6)        |    2-Schicht-Betrieb(2)      |
# |    Psychotherapie(0)         |                         |                              |    potenziellen(7)           |    Italienisch(4)            |    System-Kenntnisse(2)      |    Zuverlässigkeit(6)        |    Logopäde/Logopädin(3)     |
# |    Maschinenbau(0)           |                         |    Führerschein(2)           |    Integration(3)            |    Deutsch(4)                |    Fiori(5)                  |    Kundenfreundliches(2)     |    Facharzt(1)               |
# |    Ingenieurwesen(0)         |                         |    Denkvermögen(7)           |    Sozialrecht(3)            |    Englischkenntnisse(4)     |    WebLogic(5)               |    Selbstständige(6)         |    Produkte(3)               |
# |    Heizungstechnik(3)        |                         |    MS-Office-Kenntnisse(5)   |    mathematische(2)          |    Englischkenntnisse(4)     |    relationalen(3)           |    flexibel(6)               |    FS(2)                     |
# |    Informatik(0)             |                         |    Lesen(2)                  |    Beeinträchtigung(7)       |    Deutschkenntnisse(4)      |    AdobeXD(5)                |    Teamgeist(6)              |    IT-Kenntnisse(3)          |
# |    Klimatechnik(0)           |                         |    Office(5)                 |    Aphasiologie(3)           |    Französisch(4)            |    PHP(5)                    |    Initiative(6)             |    Respekt(6)                |
# |    Marketing(0)              |                         |    Marketing(7)              |    Logistikprozessen(3)      |    Französische(4)           |    Java(5)                   |    begabt(7)                 |    Versorgungsplanung(3)     |
# |    Ökotrophologie(0)         |                         |    Montagebereitschaft(2)    |    IT-Security(3)            |    Englischkenntnisse(4)     |    Architekt(3)              |    konzeptionellen(6)        |    Immobilienwelt(3)         |
# |    §66(7)                    |                         |    Reisebereitschaft(2)      |    Metall(3)                 |    Deutschkenntnissen(4)     |    ALM(5)                    |    motivierter(6)            |    Teams(6)                  |
# |    kaufmännische(0)          |                         |    Reisebereitschaft(7)      |    Public(3)                 |    Englischkenntnisse(4)     |    EJB(5)                    |    Leistungsbereitschaft(6)  |    Belastbare(6)             |
# |                              |                         |    Kunden(2)                 |    Kandidaten(7)             |    englische(4)              |    CSS(5)                    |    freundliches(6)           |                              |
# |    Informatik(0)             |                         |    Montagebereitschaft(7)    |    Administration(2)         |    Englischkenntnisse(4)     |    Social(2)                 |    verhandlungsstarke(2)     |    Führerscheine(2)          |
# |    Psychologie(0)            |                         |    Fortschritt(7)            |    skalierbaren(7)           |    Deutsch(4)                |    XML(5)                    |    teamfähig(6)              |    proaktiv(6)               |
# |    BBiG/§42m(7)              |                         |    2-Schicht-System(7)       |    IT(7)                     |    Englischkenntnisse(4)     |    EclipseRCP(5)             |    Gesprächskompetenz(6)     |    begeisterst(2)            |
# |    Informatik(0)             |                         |    Mietern(7)                |    Metallverarbeiten(3)      |    Englischkenntnisse(4)     |    Boot(5)                   |                              |    Macherpersönlichkeit(6)   |
# |    Logistik(0)               |                         |    körperliche(2)            |    Gastronomie(3)            |    Italienisch(4)            |    SQL(7)                    |    Durchsetzungsvermögen(6)  |                              |
# |    Elektrotechnik(3)         |                         |    Kunden(2)                 |    potenziellen(7)           |    Englischkenntnisse(4)     |    ChaRM(5)                  |    Analytische(6)            |    Standard(2)               |
# |    AbsolventIn(7)            |                         |    Mindestalter(7)           |    Mobile(3)                 |    Englischkenntnisse(4)     |    Oracle(5)                 |    Teamfähigkeit(6)          |    eigenständigen(6)         |
# |    Informatik(0)             |                         |    Führerschein(2)           |    Deployments(3)            |    Deutschkenntnisse(4)      |    Java(5)                   |    Belastbarkeit(6)          |                              |
# |    Fachinformatiker(0)       |                         |    Reisebereitschaft(2)      |    Integration(3)            |    Englischkenntnisse(4)     |    Angular(5)                |    Exakte(2)                 |    selbstverständlich(6)     |
# |                              |                         |    Fahrerlaubnis(2)          |    Fenstern(3)               |    Englisch(4)               |    Entwicklungstools(3)      |    SAP-R/3-Kenntnisse(5)     |    Impfschutz(2)             |
# |    Elektriker(0)             |                         |    Schichtarbeit(2)          |    Pharmaunternehmen(1)      |    Englischkenntnisse(4)     |    Office-Paket(5)           |    Exakte(6)                 |    Auffassungsgabe(6)        |
# |    computergestützten(0)     |                         |    Kundenkontakt(2)          |    Security(5)               |    Deutschkenntnisse(4)      |    C++(5)                    |    zeitliche(7)              |    Berufsausbildung(0)       |
# |    Hotelfachfrau(0)          |                         |    Dokumentieren(2)          |    Transportabläufen(3)      |    Englisch(4)               |    JavaScript/TypeScript(5)  |    Belastbarkeit(6)          |    Fahrsimulationslabor(3)   |
# |                              |                         |    multiprofessionellen(7)   |    Software(3)               |    Deutschkenntnisse(4)      |    C(5)                      |    Managementkompetenz(3)    |    Wissen(2)                 |
# |    Fachverkäufer(0)          |                         |    Führerschein(2)           |    Sourcing(3)               |    Deutschkenntnisse(4)      |    PHP(5)                    |    selbstständige(6)         |    AGILE(2)                  |
# |    Informatik(0)             |                         |    Entwicklung(2)            |    Psychotherapie(3)         |    Deutsch(4)                |    Perl(5)                   |    Teamfähigkeit(6)          |    Kunden(2)                 |
# |    Gerüstmonteur(0)          |                         |    Führerschein(2)           |    Heizungsanlagen(3)        |    Deutschkenntnisse(4)      |    jQuery(5)                 |    Teamfähigkeit(6)          |    Regelsatzverordnung(3)    |
# |    Elektro(3)                |                         |    Kundenorientierung(2)     |    Fenstern(3)               |    Deutsch(4)                |    REST(7)                   |    kontaktfreudig(7)         |    Dialog(3)                 |
# |    Psychosom(0)              |                         |    Kundenorientierung(2)     |    agiler(2)                 |    Deutschkenntnisse(4)      |    JavaScript(5)             |    Führungsfähigkeit(6)      |    technischer(0)            |
# |    Fleischereitechnik(0)     |                         |    Reisebereitschaft(7)      |    Türen(3)                  |    Deutsch(4)                |    Webframeworks(3)          |    eigenverantwortliches(6)  |    Veränderungsprozesse(2)   |
# |    Fachinformatiker(0)       |                         |    kaufmännisches(3)         |    IEF(5)                    |    Deutschkenntnisse(4)      |    CDI(5)                    |    Teamfaehigkeit(6)         |    Gründer(1)                |
# |    IT-Systemelektroniker(0)  |                         |    Outlook(5)                |    Backend(3)                |    Englisch(4)               |    Drehmaschinen(3)          |    Serviceverhalten(6)       |    planvoller(6)             |
# |    Systemintegration(3)      |                         |    Ben(7)                    |    Vorrichtungen(3)          |    Englischkenntnisse(4)     |    C#(5)                     |    zuverlässige(6)           |    Denkvermögen(6)           |
# |    Lagerbereich(0)           |                         |    Schichtarbeit(2)          |    Kandidaten(7)             |    Italienisch(4)            |    Java(5)                   |    Mobilität(6)              |    Denken(2)                 |
# |    Betriebstechnik(0)        |                         |    Kundendienst(2)           |    Fortbildungsmaßnahmen(7)  |    Englisch(4)               |    Cloud(5)                  |    Kundenorientierte(2)      |    Schwerpunkt(5)            |
# |    Informatik(0)             |                         |    Durchführung(2)           |    Anlageneinrichtung(3)     |    Deutsch(4)                |    Server(3)                 |    konzeptionellem(6)        |    humanistisches(6)         |
# |    Psychosom(0)              |                         |    Arbeitsortes(7)           |    Atemtherapie(3)           |    Englischkenntnisse(4)     |    LabView(5)                |    Organisationstalent(2)    |    Macherpersönlichkeit(6)   |
# |    Malerin(1)                |                         |    multiprofessionellen(7)   |    Datenanalyse(3)           |    Englisch(4)               |    Python(5)                 |    sorgfältig(6)             |    Weissputz(3)              |
# |    Fachlagerist(0)           |                         |    Montagebereitschaft(2)    |    Kostenrechnung(2)         |    deutsch(4)                |    CSS(5)                    |    systematische(6)          |    überzeugend(6)            |
# |    Informationstechnik(0)    |                         |    Führungszeugnis(7)        |    agilen(2)                 |    deutsche(4)               |    Java(5)                   |    Überzeugungskraft(6)      |    BGB(3)                    |
# |    Heilerziehungspfleger(0)  |                         |    Fingerfertigkeit(7)       |    Anforderungsanalysen(3)   |    deutsch(4)                |    XHTML(5)                  |                              |    Psychotherapie(3)         |
# |    BA(7)                     |                         |    Reisebereitschaft(7)      |    Client(3)                 |    Englischkenntnisse(4)     |    Linux(3)                  |    Belastbarkeit(6)          |    eingeschränkten(3)        |
# |    Kommunikationstechnik(0)  |                         |    Schichtdienst(2)          |    Werkzeugbau(3)            |    Englischkenntnisse(4)     |    CSS(5)                    |    Sorgfältiger(6)           |    Realschulabschluss(0)     |
# |    Elektrotechnik(0)         |                         |    Kundenorientierung(7)     |    E-Business(3)             |    Englischkenntnisse(2)     |    Web-basierte(3)           |    Lernbereitschaft(2)       |    schnelle(6)               |
# |    Psychosom(0)              |                         |    lesen(7)                  |    maschinellen(3)           |    Deutschkenntnisse(4)      |    TFS(5)                    |    sympathisches(6)          |    Erstellung(2)             |
# |    technische(3)             |                         |    Montagebereitschaft(2)    |    mehreren(7)               |    Deutsch(4)                |    HTML(5)                   |    Organisationsgeschick(6)  |    würdevoller(6)            |
# |    Lebensmittelhandwerk(0)   |                         |    Reisebereitschaft(2)      |                              |    Englischkenntnisse(4)     |    TypeScript(5)             |    begabt(7)                 |    Beziehungen(3)            |
# |    technische(0)             |                         |    technisches(7)            |    Softwareentwicklung(3)    |    Englischkenntnisse(4)     |    MongoDB(5)                |                              |    Pflege(3)                 |
# |    Landwirtschaftliche(0)    |                         |    Technisches(2)            |    DellOne(5)                |    Deutschkenntnisse(4)      |    ITSM-Lösungen(3)          |    Kräftige(2)               |    Strukturierte(6)          |
# |    Biologielaborant(0)       |                         |    Kunden(2)                 |    Implementierung(2)        |    Deutschkenntnisse(4)      |    Azure(5)                  |    Belastbarkeit(6)          |    IT-Kenntnisse(2)          |
# |    Maschinenfahrer(0)        |                         |    Verkauf(3)                |    Deep(7)                   |    Englischkenntnisse(4)     |    Excel(2)                  |    Verhandlungsgeschick(6)   |    körperlicher(2)           |
# |    Anwendungsentwicklung(0)  |                         |    Schwindelfreiheit(2)      |    PNF(7)                    |    Englischkenntnisse(4)     |    JavaScript(5)             |    Teamplayer(6)             |    Handwerkliches(3)         |
# |    Psychotraumatherapie(3)   |                         |    Physikalisches(2)         |    potenziellen(7)           |    Englischkenntnisse(4)     |    XD(5)                     |    Selbstreflexion(6)        |    Führungskraft(2)          |
# |    Psychosom(0)              |                         |    Kundenumgang(3)           |    technischen(7)            |    Englisch-Kenntnisse(4)    |    cloud-basierten(3)        |                              |                              |
# |    Altenpfleger(0)           |                         |    Kundenorientierung(2)     |    HR-Projekt(3)             |    Deutschkenntnisse(4)      |    4HANA(7)                  |    Flexibilität(6)           |    Planungs(2)               |
# |    AbsolventIn(7)            |                         |    multiprofessionellen(7)   |    Rasenmähen(3)             |    Englischkenntnisse(4)     |    Programmierung(3)         |                              |    Markttrends(3)            |
# |    Medizin(0)                |                         |    Moderation(7)             |    Korrosionsschutz(3)       |    Englischkenntnisse(4)     |    Full(7)                   |    Einfühlungsvermögen(6)    |    Wochenende(2)             |
# |    Informatikstudium(0)      |                         |    Kaufmännisches(6)         |    Teamleitungsfunktion(3)   |    Kursmodulen(7)            |    Qt(5)                     |    kommunikationsstarkes(6)  |    Manager(1)                |
# |    M(7)                      |                         |    Schichtarbeit(2)          |    Kindern(7)                |    Deutschkenntnisse(4)      |    HTML(5)                   |    organisiert(6)            |    Fleiss(6)                 |
# |    Wirtschaftsinformatik(0)  |                         |    Erreichen(7)              |    IT-Infrastruktur(3)       |    Deutschkenntnisse(4)      |    Docker(5)                 |    Team(6)                   |    Kommunikationswege(3)     |
# |    technisches(7)            |                         |    Leitungsposition(2)       |    Verwaltungserfahrung(2)   |    C1(7)                     |    WPF/WCF(5)                |    Lernbereitschaft(2)       |    technischer(0)            |
# |                              |                         |    Fahrerlaubnis(2)          |    Maschinenführer(1)        |    deutscher(4)              |    Unreal(5)                 |    selbständige(6)           |    Pharmaberater(1)          |
# |    Informatik(0)             |                         |    Ausführung(2)             |    CAM-Systemes(5)           |    Deutschkenntnisse(4)      |    AS(5)                     |    prozessorientierten(6)    |    Kreativer(6)              |
# |    Elektrotechnik(0)         |                         |    Entwicklung(3)            |    Psychotherapie(0)         |    Deutschkenntnisse(4)      |    LESS(5)                   |    selbstständig(6)          |    Produkten(3)              |
# |    Kaufmännische(0)          |                         |    kaufmännisches(2)         |    Design(3)                 |    Englisch(4)               |    Programmiersprachen(3)    |    Zuverlässigkeit(6)        |    Prozesse(3)               |
# |    Informatik(0)             |                         |    Entwicklung(3)            |    Qualitätskontrolle(2)     |    Deutschkenntnisse(4)      |    Adobe(5)                  |    Freundliches(6)           |    komplexe(2)               |
# |    Erzieher(0)               |                         |    Fahrerlaubnis(2)          |    kulturellen(7)            |    Deutscher(4)              |    Puppet(5)                 |    Eigeninitiative(6)        |    technischer(0)            |
# |    Wirtschafts(0)            |                         |    Führerschein(2)           |                              |    Deutsch(4)                |    Java(5)                   |    Präzision(6)              |    Realisierungsphase(2)     |
# |    Sommelier/Sommelière(0)   |                         |    arbeitsweise(7)           |    Linguistik(3)             |    Deutsch(4)                |    CSS3(5)                   |    Zuverlässigkeit(6)        |    Respekt(6)                |
# |    Verwaltungsausbildung(7)  |                         |    Technik(2)                |    Chain(7)                  |    Deutsch(4)                |    OPC(5)                    |    Zahlenverständnis(2)      |    Inhalten(3)               |
# |    Psychologie(0)            |                         |    Mindestalter(7)           |    HKLS/Kältetechnik(3)      |    Englischkenntnisse(4)     |    MS(5)                     |    strukturierte(2)          |    Qualitätsmanagements(3)   |
# |    Wirtschafts(0)            |                         |    Außendienst(2)            |                              |    Englischkenntnisse(4)     |    Frontend(3)               |    motivierte(6)             |                              |
# |    Betriebsschlosser(0)      |                         |    Reisebereitschaft(2)      |    Trockenbau(3)             |    Bevorzugt(7)              |    Datenbanken(5)            |    Flexibilität(6)           |    gute(6)                   |
# |    Psychologie(0)            |                         |    Führerschein(2)           |    Detailhandel(2)           |    Deutsch(4)                |    Batchsprachen(3)          |    Genauigkeit(2)            |                              |
# |    Wissenschaften(0)         |                         |    Zahlen(2)                 |    Verkehrs(7)               |    Englischkenntnisse(4)     |    4HANA(7)                  |                              |    umzusetzen(2)             |
# |    Speditionskaufman(0)      |                         |    internen(2)               |    Angehörigen(2)            |                              |    EDI(5)                    |    kommunikationsstarker(6)  |    Fachkraft(0)              |
# |    Staatsexamen(7)           |                         |    Führungszeugnis(2)        |    Softwareentwicklung(3)    |    Deutsch(4)                |    Python(5)                 |    eigenständige(6)          |    Technikerausbildung(0)    |
# |    Informatik(0)             |                         |    Freundliche(6)            |    Datenbanken(3)            |    Italienisch(4)            |    Shopware(5)               |    Belastbarkeit(6)          |    Werkzeugen(3)             |
# |    Airbus(3)                 |                         |    Fahrerlaubnis(2)          |    Kommissionieren(2)        |    Englischkenntnisse(4)     |    CMS(5)                    |    Flexible(6)               |    Zimmerstunde(2)           |
# |                              |                         |    verkäuferischen(2)        |    Symbol(3)                 |    Englisch(4)               |    Node.js(5)                |    kommunikative(6)          |    Psychotherapie(3)         |
# |    AbsolventIn(7)            |                         |    Nachtarbeit(2)            |    Datenbanken(5)            |    Englischkenntnisse(4)     |    SAP(5)                    |    Teamfähigkeit(6)          |    Abitur(0)                 |
# |    kaufmännische(0)          |                         |    Autoausweis(2)            |    Sozialmedizin(3)          |    Englischkenntnisse(4)     |    HTML(5)                   |    speditive(6)              |    Menschen(6)               |
# |    Fleischer(0)              |                         |    Kundenorientierung(2)     |    Client-Server-Umfeld(3)   |    Deutschkenntnisse(4)      |    Android-Umfeld(5)         |    prozessorientierten(2)    |                              |
# |                              |                         |    Geräten(7)                |    Elektro(3)                |    Englischkenntnisse(4)     |    CMS(5)                    |    Flexibilität(6)           |    ethische(3)               |
# |    IT-Schwerpunkt(0)         |                         |    Montagebereitschaft(2)    |    Projektmanagement(7)      |    Englisch(4)               |    UI(3)                     |    Sicheren(7)               |    Erstellung(2)             |
# |    Medizin(0)                |                         |    Führungserfahrung(6)      |    4-Wege(3)                 |    Englisch(4)               |    Typo3(5)                  |    Lernbereitschaft(6)       |    Professional(1)           |
# |                              |                         |    Montagebereitschaft(2)    |    User(3)                   |    Englischkenntnisse(4)     |                              |    Teamfähigkeit(6)          |    flexibler(6)              |
# |    Gas(3)                    |                         |    Montagebereitschaft(2)    |    Wartung(2)                |    Deutschkenntnisse(7)      |    APP-Entwicklung(3)        |                              |    Plaudertasche(6)          |
# |    Lüftungstechnik(3)        |                         |    Fahrzeug(7)               |    ASIL(7)                   |    Deutsch(4)                |    SPSS(5)                   |                              |    Office(2)                 |
# |    Fachkraft(1)              |                         |    Vorkontierung(3)          |    Management(3)             |    Deutschkenntnisse(4)      |    Office(2)                 |    Motivation(6)             |    entladen(2)               |
# |    Zerspanungsmechaniker(1)  |                         |    Führungserfahrung(2)      |    MATLAB/Simulink(5)        |    Deutschkenntnisse(4)      |    Baustellenverkehr(7)      |    Soziale(6)                |    Produktentwicklung(2)     |
# |    Informationstechnik(0)    |                         |    Reisebereitschaft(2)      |    Problemlagen(7)           |    Englischkenntnisse(4)     |    SoapUI(5)                 |    Selbstständige(6)         |    Einführung(2)             |
# |    Maschinenbau(0)           |                         |    technisches(3)            |    Datenbanken(3)            |    Englischkenntnisse(4)     |    JavaScript(5)             |    teamorientierte(2)        |    TIPS(5)                   |
# |                              |                         |    Verfassung(7)             |    Psychotherapie(0)         |    Deutschkenntnisse(4)      |    Webtechnologien(7)        |    Belastbarkeit(6)          |    effizient(6)              |
# |    Human(0)                  |                         |    Schichtarbeit(2)          |    Elektrotechnik(3)         |    Englischkenntnisse(4)     |    Java(7)                   |    strukturiert(2)           |    Kunden(2)                 |
# |    Psychiatrie(3)            |                         |    Führerschein(2)           |    Netzwerk(3)               |    Deutsch(4)                |    Node.js(5)                |    kommunikative(6)          |    Belastung(6)              |
# |    Mediengestaltung(0)       |                         |    Sachkontenbuchhaltung(3)  |    UX(5)                     |    Deutschkenntnisse(4)      |    SAP(5)                    |    Qualitätsbewusstsein(6)   |    Psychotherapie(0)         |
# |    technisches(0)            |                         |    Kundenorientierung(2)     |    Montage(3)                |    Englischkenntnisse(4)     |    MS-Office(5)              |    Menschen(2)               |    Unterstützung(2)          |
# |    Facharzt/-ärztin(1)       |                         |    Klasse(7)                 |    Langzeitpflege(3)         |    Deutsch(4)                |    Redis(5)                  |    Belastbarkeit(6)          |    pünktlich(6)              |
# |    kaufmännische(0)          |                         |    Reisebereitschaft(2)      |    Prozessoptimierung(2)     |    Deutsch(4)                |    Spring(5)                 |    kreatives(6)              |    Entwicklungen(2)          |
# |    IT-Bereich(0)             |                         |    Führerschein(2)           |    Administration(7)         |    Englisch(4)               |    Java(5)                   |    Führungsfähigkeit(2)      |    Fenstermonteur(1)         |
# |    Ergotherapeuten(0)        |                         |    Schicht-Bereitschaft(2)   |    Tastaturen(7)             |    Englischkenntnisse(4)     |    AS(5)                     |    Teamfähigkeit(6)          |    Reife(6)                  |
# |    Schreiner(0)              |                         |    Handwerkliches(2)         |    Beschreibung(2)           |    Englisch(4)               |    C#(5)                     |    Teamfähigkeit(6)          |    Breites(3)                |
# |    Wirtschafts(0)            |                         |    Fahrerlaubnis(2)          |    Software-Strukturen(3)    |    Deutsch(4)                |    WooCommerce(5)            |    Selbständiges(7)          |    Anleitung(2)              |
# |                              |                         |    Schichtbetrieb(2)         |    Bereich/Montage(2)        |    Englischkenntnisse(4)     |    Office(5)                 |    Organisationsgeschick(6)  |                              |
# |    Maschinenbau(0)           |                         |    Führerschein(2)           |    Logistik(3)               |    Englischkenntnisse(4)     |    Office-Paket(5)           |    Team(6)                   |    kompetent(6)              |
# |    Wirtschafts(0)            |                         |    Reisebereitschaft(2)      |    Maschinenbedienung(3)     |    Englischkenntnisse(5)     |    EASA(5)                   |    Teamarbeit(6)             |    Jahre(2)                  |
# |    Textilingenieur(0)        |                         |    Führungserfahrung(0)      |    potenziellen(7)           |    Deutschkenntnisse(4)      |    Webservices(7)            |    analytische(6)            |    Luftsicherheitsgesetz(3)  |
# |    Mechatronik(0)            |                         |    PKW-Führerschein(2)       |    Küche(3)                  |    Englischkenntnisse(4)     |    CSS(5)                    |    Selbstständige(6)         |    Indikations-Erfahrung(2)  |
# |    Anlagenmechaniker(0)      |                         |    Verkauf(2)                |    Hauswirtschaftliche(3)    |    Englischkenntnisse(4)     |    scikit-learn(3)           |    Flexibilität(6)           |    technisch(0)              |
# |    Bauingenieur(0)           |                         |    Kunden(7)                 |    Oberflächenschutzes(7)    |    Französisch(4)            |    JavaScript-Framework(5)   |                              |    unternehmerische(2)       |
# |                              |                         |    Führungserfahrung(2)      |    Fenster(3)                |    Englisch(4)               |    Programmiersprachen(7)    |    Teamfähigkeit(6)          |    Hochdeutsch(4)            |
# |    Informationstechnik(0)    |                         |    Planung(2)                |    Personalberatung(3)       |    Englischkenntnisse(4)     |    Excel(5)                  |    lösungsorientiertes(2)    |    Verkaufserfahrung(2)      |
# |    Schreiner(0)              |                         |    MS-Office-Kenntnisse(2)   |    Programming(3)            |    Deutsch(4)                |    JSON(5)                   |    Gewissenhaftigkeit(6)     |    Überzeugendes(6)          |
# |    Medizintechnik(0)         |                         |    Führerschein(2)           |    Elektrophorese(3)         |    Englischkenntnisse(4)     |    C#(5)                     |    mobil(2)                  |    Abrieb(3)                 |
# |    Metallverarbeitung(0)     |                         |    Menschen(2)               |    Bediener(7)               |    Englischkenntnisse(4)     |    Ticketsystemen(3)         |    Einsatzbereitschaft(6)    |    Expertise(3)              |
# |    Informatik(0)             |                         |    Qualitätsprüfung(2)       |    Steuerungen(3)            |    Deutschkenntnisse(4)      |    AWS(5)                    |    offenes(6)                |    politische(2)             |
# |    Zerspanungsmechaniker(0)  |                         |    Kunden(2)                 |    agilen(3)                 |    Deutsch(4)                |    VB.NET(5)                 |    engagierte(6)             |    Kundenstandort(2)         |
# |                              |                         |    administrative(2)         |    Dienstanweisungen(7)      |    Deutsch(4)                |    Programmierung(3)         |    Zuverlässigkeit(6)        |    unternehmerische(2)       |
# |    Anlagenmechaniker(0)      |                         |    Fahrerlaubnis(2)          |    Oriented(3)               |    Englisch(4)               |    ABAP(5)                   |    offene(6)                 |    Report(3)                 |
# |    Informatik(0)             |                         |    Reisebereitschaft(2)      |    SCRUM(5)                  |    deutsche(4)               |    Hibernate(5)              |    Ausdrucksformen(7)        |    Approbation(3)            |
# |    Informatikstudium(0)      |                         |    Kundenorientierung(7)     |    Service-Architekturen(3)  |    Deutsch(4)                |    Visualisierungstools(3)   |    gepflegtes(7)             |    Entwickeln(2)             |
# |    Psychotraumatherapie(3)   |                         |    Reisebereitschaft(7)      |    Beschaffungen(7)          |    Deutsch(4)                |    R(5)                      |    Zeitliche(7)              |    Bereitschaft(2)           |
# |    Pharmazie(0)              |                         |    Übernachtung(2)           |    Psychotherapie(3)         |    Spanisch(4)               |    Siemens(5)                |    professionelles(6)        |    unternehmerischem(2)      |
# |    Gerüstbauer(0)            |                         |    Kraftmaschinenbau(3)      |    Anwendungsentwicklung(3)  |    Englisch(4)               |    JUnit(5)                  |    selbständig(6)            |    KleinkinderzieherIn(0)    |
# |    Verkehrswesen(0)          |                         |    Gabelstaplerschein(2)     |    Sprecherziehung(3)        |    Französisch(4)            |    React(5)                  |    Sorgfalt/Genauigkeit(6)   |    PC-Kenntnisse(2)          |
# |                              |                         |    Führerschein(2)           |    Management(2)             |    Englischkenntnisse(4)     |    PHP(5)                    |    konstruktives(6)          |    Fahrer(1)                 |
# |    Informatik(0)             |                         |    Entwicklung(7)            |    Verpacken(2)              |    Deutschkenntnisse(4)      |    HSM(5)                    |                              |    umzusetzen(2)             |
# |    Maschinenbau(0)           |                         |    Autoausweis(2)            |    Spezifikationen(7)        |    Englischkenntnisse(4)     |    C#(5)                     |    Eigeninitiative(6)        |    professionelle(6)         |
# |    Wirtschaftsinformatik(0)  |                         |    Reisebereitschaft(2)      |    Automation(3)             |    Englisch(4)               |    Typo3(5)                  |    prozessorientierte(2)     |    unterstützen(2)           |
# |    Informatik(0)             |                         |    technisches(2)            |    Absatzfinanzierung(3)     |    Deutschkenntnisse(4)      |    SOAP(7)                   |    Teamgeist(6)              |    umwelttechnisch(3)        |
# |    kaufmännische(0)          |                         |    Kundenorientierung(2)     |    Softwareentwicklung(3)    |    Deutschkenntnisse(4)      |    2012(7)                   |    Eigeninitiative(6)        |    industriellen(3)          |
# |                              |                         |    Verfassung(7)             |    Hygienevorschriften(2)    |    Englischkenntnisse(4)     |    XML(5)                    |                              |    verantwortlich(2)         |
# |    Engineering(3)            |                         |    Staplerschein(2)          |                              |    Deutschkenntnisse(4)      |    Java(5)                   |    Engagement(6)             |    Handeln(2)                |
# |    staatlicher(7)            |                         |    Menschen(2)               |    Akutbereich(3)            |    Deutschkenntnisse(4)      |    Staplerschein(3)          |    Flexibilität(6)           |    entwickeln(2)             |
# |    Chemie(0)                 |                         |    Kunden(2)                 |    SWT/JFace/RCP(5)          |    Deutschkenntnisse(4)      |    Javascript(5)             |    effiziente(6)             |    Fortbildung(2)            |
# |    Elektrotechnik(0)         |                         |    Kundenorientierung(2)     |                              |    Englischkenntnisse(4)     |    Eclipse-CDT(5)            |                              |    Team(6)                   |
# |    kaufmännische(0)          |                         |    polizeiliches(7)          |    Programmierkenntnisse(3)  |    Englischkenntnisse(4)     |    Programmiersprache(3)     |    Teamfähigkeit(6)          |    Betriebssoftware(3)       |
# |    Betriebswirtschaft(0)     |                         |    Kunden(7)                 |    Patch(2)                  |    Deutschkenntnisse(4)      |    SAP(7)                    |    Teamfähigkeit(6)          |    Verkaufserfahrung(3)      |
# |    Informatik(0)             |                         |    Schichtarbeit(2)          |    technisches(7)            |    Englischkenntnisse(4)     |    X(5)                      |    Motivation(6)             |    Führung(2)                |
# ...
# |                              |                         |                              |                              |                              |    Cloud(3)                  |    Teamfähigkeit(6)          |                              |
# |                              |                         |                              |                              |                              |    CSS(5)                    |    Teamfähigkeit(6)          |                              |
# |                              |                         |                              |                              |                              |    Queues(3)                 |    selbständiges(6)          |                              |
# |                              |                         |                              |                              |                              |    HTML(5)                   |    Einfühlungsvermögen(6)    |                              |
# |                              |                         |                              |                              |                              |    AngularJS(5)              |    Einfühlungsvermögen(6)    |                              |
# |                              |                         |                              |                              |                              |    Java-Ökosys-​(5)           |    Kommunikationsstärke(6)   |                              |
# |                              |                         |                              |                              |                              |    Ansible(5)                |    kommunikativ(6)           |                              |
# |                              |                         |                              |                              |                              |    MS-Office(5)              |    Engagement(6)             |                              |
# |                              |                         |                              |                              |                              |    Softwareentwicklung(3)    |    Sozialkompetenz(6)        |                              |
# |                              |                         |                              |                              |                              |    OO(5)                     |    strukturierte(6)          |                              |
# |                              |                         |                              |                              |                              |    Autodesk(5)               |    Zuverlässigkeit(6)        |                              |
# |                              |                         |                              |                              |                              |    OO(7)                     |    Lernbereitschaft(6)       |                              |
# |                              |                         |                              |                              |                              |    Mappern(3)                |    analytische(6)            |                              |
# |                              |                         |                              |                              |                              |    Network(5)                |    Leistungsbereitschaft(6)  |                              |
# |                              |                         |                              |                              |                              |    Java(5)                   |    zielorientierte(6)        |                              |
# |                              |                         |                              |                              |                              |    MS(2)                     |    Beratungskompetenzen(3)   |                              |
# |                              |                         |                              |                              |                              |    Programmiersprache(3)     |    Engagement(6)             |                              |
# |                              |                         |                              |                              |                              |    Scriptsprachen(3)         |    Exakte(2)                 |                              |
# |                              |                         |                              |                              |                              |    CSS3(5)                   |    Beratungskompetenz(6)     |                              |
# |                              |                         |                              |                              |                              |    CISA(5)                   |    Durchsetzungsvermögen(6)  |                              |
# |                              |                         |                              |                              |                              |                              |    Team(6)                   |                              |
# |                              |                         |                              |                              |                              |    HTML(5)                   |    Leistungsbereitschaft(2)  |                              |
# |                              |                         |                              |                              |                              |    Office(5)                 |    konzeptionelle(6)         |                              |
# |                              |                         |                              |                              |                              |    .NET(5)                   |    Teamfähigkeit(6)          |                              |
# |                              |                         |                              |                              |                              |    VBA(5)                    |    selbständige(7)           |                              |
# |                              |                         |                              |                              |                              |    PHP(5)                    |    hilfsbereiter(6)          |                              |
# |                              |                         |                              |                              |                              |    ABAP(5)                   |    Selbstorganisation(6)     |                              |
# |                              |                         |                              |                              |                              |    Angular(5)                |    Flexibilität(6)           |                              |
# |                              |                         |                              |                              |                              |    Fremdbegriff(7)           |    Teamfähigkeit(6)          |                              |
# |                              |                         |                              |                              |                              |    Webservice(3)             |                              |                              |
# |                              |                         |                              |                              |                              |    Javascript(5)             |    Zuverlässigkeit(6)        |                              |
# |                              |                         |                              |                              |                              |    Testtools(7)              |    sicheres(6)               |                              |
# |                              |                         |                              |                              |                              |    Solution(1)               |    sicheres(7)               |                              |
# |                              |                         |                              |                              |                              |    Microsoft(5)              |    zielstrebig(6)            |                              |
# |                              |                         |                              |                              |                              |    Media(3)                  |    zielorientierte(6)        |                              |
# |                              |                         |                              |                              |                              |    DevOps(5)                 |    Leistungsbereitschaft(6)  |                              |
# |                              |                         |                              |                              |                              |    Microsoft(5)              |    Teamplayer(6)             |                              |
# |                              |                         |                              |                              |                              |    Windows(3)                |    strukturierte(6)          |                              |
# |                              |                         |                              |                              |                              |    Python(5)                 |    Zuverlässigkeit(6)        |                              |
# |                              |                         |                              |                              |                              |    Expect(5)                 |    kommunikativer(6)         |                              |
# |                              |                         |                              |                              |                              |    CNC-Maschinen(3)          |    strukturierte(2)          |                              |
# |                              |                         |                              |                              |                              |    HTML(5)                   |    Zuverlässig(2)            |                              |
# |                              |                         |                              |                              |                              |    AJAX(5)                   |    Flexibilität(6)           |                              |
# |                              |                         |                              |                              |                              |    C++(5)                    |    zuverlässige(6)           |                              |
# |                              |                         |                              |                              |                              |    SAP(5)                    |    Belastbarkeit(6)          |                              |
# |                              |                         |                              |                              |                              |    eCommerce(3)              |    Team(7)                   |                              |
# |                              |                         |                              |                              |                              |    Datenbanksystemen(5)      |    zuverlässig(6)            |                              |
# |                              |                         |                              |                              |                              |    Mobile(3)                 |    Mass(7)                   |                              |
# |                              |                         |                              |                              |                              |    HTML(5)                   |    Kooperationsfähigkeit(6)  |                              |
# |                              |                         |                              |                              |                              |    Windows(5)                |    strukturiertes(6)         |                              |
# |                              |                         |                              |                              |                              |    Eclipse-RCP(5)            |    überdurchschnittlich(7)   |                              |
# |                              |                         |                              |                              |                              |    Spring(7)                 |                              |                              |
# |                              |                         |                              |                              |                              |    Continuous(3)             |    zuverlässige(6)           |                              |
# |                              |                         |                              |                              |                              |    Sketch(5)                 |    qualitätsorientiert(6)    |                              |
# |                              |                         |                              |                              |                              |    SQL(5)                    |    zuverlässig(6)            |                              |
# |                              |                         |                              |                              |                              |    Script(5)                 |    Teamfähig(6)              |                              |
# |                              |                         |                              |                              |                              |    Ubuntu(5)                 |    lösungsorientiertes(2)    |                              |
# |                              |                         |                              |                              |                              |    Web-Entwickler(1)         |    durchsetzungsstarke(6)    |                              |
# |                              |                         |                              |                              |                              |    SAP(5)                    |    analytisches(6)           |                              |
# |                              |                         |                              |                              |                              |    Java(5)                   |                              |                              |
# |                              |                         |                              |                              |                              |    Regular(5)                |    Kundenfreundliches(6)     |                              |
# |                              |                         |                              |                              |                              |    React(5)                  |    Teamorientiertheit(6)     |                              |
# |                              |                         |                              |                              |                              |    Scripting(5)              |    zuverlässig(6)            |                              |
# |                              |                         |                              |                              |                              |    Objektorientiertem(3)     |    kommunikative(6)          |                              |
# |                              |                         |                              |                              |                              |    SQL(5)                    |                              |                              |
