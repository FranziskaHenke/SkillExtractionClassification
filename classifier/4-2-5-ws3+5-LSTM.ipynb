# %%
import sys
import os
sys.path.append('/home/franzi/anzeigendaten/python_base/skillextraktion/fh_ma')
sys.path.append('/home/franzi/anzeigendaten/EnvPython')
import prepare_training_data
from labels import *
import time
import warnings
warnings.filterwarnings('ignore')

from sklearn.utils import shuffle
import numpy as np
np.set_printoptions(precision=3)
# %precision 3
start = time.time()
x_train, y_train, x_test, y_test, test_afks, features = prepare_training_data.get_training_data(window=[3,5])
print('took: ',time.time()-start)
# Out:
# 20861874
# 0
# skipgram, punctuation_marks, stoppwords, multiword, lower_case, vector_dim True False False False False 100
# init /home/franzi/Documents/models/no_pm_no_sw_vecDim100/skip_gram_model.model
# loading existing w2v model from  /home/franzi/Documents/models/no_pm_no_sw_vecDim100/skip_gram_model.model
# using data from  /home/franzi/Documents/data/data_35_vecDim100
# processing data...
# Found  1298  training entries.
# Found  1298  cleaned entries.
# /home/franzi/Documents/data/vectors_win3-5.npy
# 0 []
# window [3, 5]
# window [3, 5]
# 36627 36627 11649 11649 0 0
# took:  605.7149965763092

# %%
from tensorflow.keras import *

# %%
# Build the model
print('Build model...')
model = Sequential()
model.add(layers.LSTM(256, return_sequences=True, input_shape=(x_train.shape[1],x_train.shape[2])))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.LSTM(512, return_sequences=True))
model.add(layers.Dropout(0.5))
model.add(layers.BatchNormalization())
model.add(layers.LSTM(256))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256))
model.add(layers.Dense(units=len(labels)))
model.add(layers.Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

batch_size=64
history = model.fit(x_train, y_train, batch_size=batch_size, shuffle=True, epochs=5, validation_data=(x_test, y_test))
# Out:
# 2020-08-31 14:56:17 WARNING: From /home/franzi/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Build model...
# Train on 36627 samples, validate on 11649 samples
# 2020-08-31 14:56:21 WARNING: From /home/franzi/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/5
# 36627/36627 [==============================] - 162s 4ms/sample - loss: 0.8211 - acc: 0.6986 - val_loss: 0.6821 - val_acc: 0.7500
# Epoch 2/5
# 36627/36627 [==============================] - 143s 4ms/sample - loss: 0.5413 - acc: 0.8096 - val_loss: 0.5205 - val_acc: 0.8116
# Epoch 3/5
# 36627/36627 [==============================] - 145s 4ms/sample - loss: 0.4753 - acc: 0.8329 - val_loss: 0.4964 - val_acc: 0.8405
# Epoch 4/5
# 36627/36627 [==============================] - 148s 4ms/sample - loss: 0.4413 - acc: 0.8468 - val_loss: 0.4559 - val_acc: 0.8419
# Epoch 5/5
# 36627/36627 [==============================] - 167s 5ms/sample - loss: 0.4140 - acc: 0.8564 - val_loss: 0.4468 - val_acc: 0.8484

# %%
from matplotlib import pyplot as plt
plt.plot(np.arange(1, len(history.history['acc'])+1), history.history['acc'])
plt.plot(np.arange(1, len(history.history['acc'])+1), history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim(0.65,0.9)
plt.xticks(np.arange(1, len(history.history['acc'])+1))
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# predict test data
y_pred = model.predict(x_test)

# %%
import numpy as np
# convert one hot to labels for test data
pred_label = prepare_training_data.one_hot_to_labels(y_pred)
true_label = prepare_training_data.one_hot_to_labels(y_test)

# %%
# Calc metrics for test data
import sklearn
from sklearn.metrics import precision_score, recall_score
from tabulate import tabulate
label_list = list(labels.keys())

headers = [l for l in label_list ]
headers = [' '] + headers

table=[['precision'] + list(precision_score(true_label, pred_label, average=None)), 
       ['recall']+list(recall_score(true_label, pred_label, average=None)), 
       ['f1']+ list(sklearn.metrics.f1_score(true_label, pred_label, average=None))]

print(tabulate(table, headers=headers, tablefmt='orgtbl'))
f1 = sklearn.metrics.f1_score(true_label, pred_label, average=None)
f1 = np.delete(f1, 4)
f1 = np.delete(f1, 6)
print('f1 average: ',sum(sklearn.metrics.f1_score(true_label, pred_label, average=None))/len(list(precision_score(true_label, pred_label, average=None))))
print('f1 average: ',sum(f1)/6)
print('Precision average: ',sum(precision_score(true_label, pred_label, average=None)/8))
print('recall average: ',sum(recall_score(true_label, pred_label, average=None)/8))
print('acc', sklearn.metrics.accuracy_score(true_label, pred_label))
# Out:
# |           |   Ausbildung |    Beruf |   allgemein |   berufsspez |   Sprache |   Technologie |   Softskill |   noSkill |
# |-----------+--------------+----------+-------------+--------------+-----------+---------------+-------------+-----------|
# | precision |     0.784893 | 0.785714 |    0.535124 |     0.646125 |  0.936652 |      0.850904 |    0.752969 |  0.917657 |
# | recall    |     0.891791 | 0.177419 |    0.367376 |     0.657795 |  0.949541 |      0.750332 |    0.901422 |  0.924601 |
# | f1        |     0.834934 | 0.289474 |    0.43566  |     0.651908 |  0.943052 |      0.797459 |    0.820535 |  0.921116 |
# f1 average:  0.7117673239787694
# f1 average:  0.6383284072904148
# Precision average:  0.776254706800577
# recall average:  0.7025346305316595
# acc 0.8483990042063696

# %%
# Create Confusion Matrix

import sklearn
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

cm = sklearn.metrics.confusion_matrix(true_label, pred_label)
df_cm = pd.DataFrame(cm, labels,columns = labels)
plt.figure(figsize = (10,7))
plt.ylabel('Eingabe')
plt.xlabel('Ausgabe')
sn.heatmap(df_cm, annot=True,fmt='g')

# %%
# clean noSkill for evaluation
clean_y_pred = []
clean_y_test = []
true_noSkills = 0
clean_x_test = []
afks = []

for i in range(len(y_test)):
    if(true_label[i] != 7 or pred_label[i] != 7):
        clean_x_test.append(x_test[i])
        clean_y_pred.append(pred_label[i])
        clean_y_test.append(true_label[i])
        afks.append(test_afks[i])
    else:
        true_noSkills += 1
pred_label = clean_y_pred
true_label = clean_y_test
print('correctly labeled noSkills: ', true_noSkills)
# Out:
# correctly labeled noSkills:  6720

# %%
# Create Confusion Matrix

import sklearn
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

cm = sklearn.metrics.confusion_matrix(true_label, pred_label)
df_cm = pd.DataFrame(cm, labels,columns = labels)
plt.figure(figsize = (10,7))
plt.ylabel('Eingabe')
plt.xlabel('Ausgabe')
sn.heatmap(df_cm, annot=True,fmt='g')

# %%
from word2vec import W2V#get_closest_word_to_vec_matrix
correct = []
false = []

clean_x_test, pred_label, true_label, afks = shuffle(clean_x_test, pred_label, true_label, afks,random_state=0)
skill_index = int(len(clean_x_test[0])/2)
label_list = list(labels.keys())

# %%
headers = [['|']+[l] for l in label_list ]
headers = sum(headers, [])
headers.append('|')

wvs = []
for i in range(len(clean_x_test)):
    wvs.append(clean_x_test[i][skill_index])

w2v = W2V(skipgram=True, punctuation_marks=False, stoppwords=False, multiword=False, lower_case=False, vector_dim=100)

predictions = [[],[],[],[],[],[],[], []]
for i in range(len(clean_x_test)):
    word = w2v.get_closest_word_to_vec(wvs[i])[0][0]
    label = str(true_label[i])
    predictions[pred_label[i]].append(word + '('+label+')')

table = []
# format
i = 0
while(i < len(predictions[0]) or i < len(predictions[1]) or i < len(predictions[2]) or i < len(predictions[3]) or i < len(predictions[4]) or i < len(predictions[5] or i < len(predictions[6]))):
    row = ['|']
    for x in predictions:
        if(len(x) > i and len(x[i]) <  25): 
            row.append(x[i])
            row.append('|')
        else:
            row.append('')
            row.append('|')
            
    table.append(row)
    i+=1    

print(tabulate(table, headers=headers))
# Out:
# skipgram, punctuation_marks, stoppwords, multiword, lower_case, vector_dim True False False False False 100
# init /home/franzi/Documents/models/no_pm_no_sw_vecDim100/skip_gram_model.model
# loading existing w2v model from  /home/franzi/Documents/models/no_pm_no_sw_vecDim100/skip_gram_model.model
# |    Ausbildung                |    Beruf           |    allgemein                 |    berufsspez                |    Sprache                  |    Technologie               |    Softskill                 |    noSkill                   |
# ---  ------------------------  ---  --------------  ---  ------------------------  ---  ------------------------  ---  -----------------------  ---  ------------------------  ---  ------------------------  ---  ------------------------  ---
# |    ä(0)                      |    CNC-Dreher(7)   |    erfolgreich(2)            |    Clean(7)                  |    Mindestalter(4)          |    etc(5)                    |    Teamplayer(7)             |    ARBEITSZEIT(0)            |
# |    IT-Umfeld(7)              |    sind(1)         |    Montagebereitschaft(7)    |    Architektur(3)            |    Wort(4)                  |    HTML5(5)                  |    Kundenorientierung(6)     |    idealerweise(5)           |
# |    beziehungsweise(0)        |    Tätigkeiten(1)  |    Freude(7)                 |    etc(3)                    |    sind(7)                  |    XML(5)                    |    interessiert(2)           |    höchstem(2)               |
# |    §66(0)                    |    besitzen(1)     |    Flurförderzeuge(2)        |    Web-basierte(3)           |    Wort(4)                  |    XAML(5)                   |    fokussiert(6)             |    Zimmerstunde(2)           |
# |    beziehungsweise(0)        |    Tätigkeiten(1)  |    Sehr(2)                   |    Datenbanken(3)            |    gute(4)                  |    SAP(5)                    |    sind(7)                   |    Initiative(2)             |
# |    vorzugsweise(3)           |    m/w/d(1)        |    mindestens(2)             |    Softwareprogrammen(3)     |    Wort(4)                  |    GlassFish(5)              |    Deutschkenntnisse(6)      |    Interesse(3)              |
# |    Bautechniker(0)           |    m/w/d(1)        |    Kundenumgang(3)           |    Transport(3)              |    sowie(4)                 |    Anwendungen(5)            |    Auftreten(6)              |    operativen(3)             |
# |    Teamfähigkeit(0)          |    Tätigkeiten(1)  |    Office(5)                 |    im(3)                     |    Wort(4)                  |    REST(7)                   |    Flexibilität(6)           |    Hype(5)                   |
# |    Erfahrung(0)              |    haben(3)        |    Arriba(5)                 |    Technologien(5)           |    Englischkenntnisse(4)    |    ASP.NET(5)                |    Auftreten(7)              |    Kenntnisse(2)             |
# |    Grundausbildung(0)        |    Tätigkeiten(1)  |    gelegentlicher(2)         |    sowie(3)                  |    Führerschein(4)          |    caret(3)                  |    Leidenschaft(6)           |    Fähigkeiten(2)            |
# |    vergleichbaren(0)         |    haben(2)        |    Sprachen(3)               |    Suche(7)                  |    Mindestalter(4)          |    Server(5)                 |    Selbstständigkeit(7)      |    sowie(3)                  |
# |    zum(0)                    |    Schwerpunkt(1)  |    Verständnis(7)            |    Test(3)                   |    Persönliche(4)           |    Datenbanken(5)            |    durchsetzungsstarke(6)    |    Küche(0)                  |
# |    Berufserfahrung(0)        |    bringst(1)      |    sowie(7)                  |    Arbeit(3)                 |    Englischkenntnisse(4)    |    Git(5)                    |    sowie(6)                  |    Berufserfahrung(3)        |
# |    und/oder(0)               |    Tätigkeiten(1)  |    Reisebereitschaft(7)      |    Fenster(7)                |    Sprachkenntnisse(4)      |    ERP-Systemen(3)           |    Zuverlässigkeit(6)        |    Geräten(3)                |
# |    Psychotherapie(0)         |                    |    Deutsch(7)                |    Softwarelösungen(3)       |    Englisch(4)              |    sowie(5)                  |    Leistungsbereitschaft(6)  |    Schaltschrankbau(2)       |
# |    Erste(3)                  |                    |    Zusammenhänge(2)          |    Datenmodellen(3)          |    Englischkenntnisse(4)    |    Tumult(5)                 |    Gespür(7)                 |    runden(3)                 |
# |    kennen(0)                 |                    |    SPSS(2)                   |    Webservices(7)            |    Motivation(4)            |    BluePrism(5)              |    sowie(6)                  |    wirtschaftlichem(2)       |
# |    Software(0)               |                    |    Matlab/Simulink(7)        |    wünschenswert(3)          |    Wort(4)                  |    sind(5)                   |    Kunden(6)                 |                              |
# |                              |                    |    hohes(2)                  |    wäre(3)                   |    mündlich(4)              |    Angular(5)                |    teamfähige(6)             |    Informatik(0)             |
# |    Umfeld(0)                 |                    |    Nachtarbeit(7)            |    Spaß(2)                   |    Wort(4)                  |    Kenntnisse(5)             |    Arbeiten(6)               |    erfolgreich(3)            |
# |    Techniker(7)              |                    |    Trainings(2)              |    Elektrotechnik(2)         |    strukturierte(4)         |    Kenntnisse(2)             |    schwierigen(6)            |    Gestalten(2)              |
# |    Psychiatrie(0)            |                    |    Kräftige(7)               |    Java(3)                   |    Wort(4)                  |    Systemen(5)               |    Selbständiges(6)          |    Anwendungen(2)            |
# |    Mechatroniker(0)          |                    |    Führungserfahrung(2)      |    Apps(3)                   |    Bestandskunden(4)        |    Logisches(5)              |    Flexibilität(6)           |    zweiten(2)                |
# |    Berufserfahrung(0)        |                    |    Office-Paket(5)           |    idealerweise(5)           |    Selbständige(4)          |    und/oder(5)               |    Flexibilität(6)           |    Ausbildung(0)             |
# |    Informatik(0)             |                    |    rasche(2)                 |    idealerweise(3)           |    Umgang(4)                |                              |    selbstbewusstes(7)        |    Kenntnisse(3)             |
# |    w/m/d(1)                  |                    |    MS(2)                     |    Kenntnisse(3)             |    Folgende(4)              |    Strukturierte(5)          |    Lernbereitschaft(6)       |    kanonischen(2)            |
# |    Qualifikation(0)          |                    |    Englisch-Kenntnisse(2)    |    Profi(3)                  |    Unternehmen(4)           |    C(5)                      |    entsprechender(6)         |    Personalberatung(3)       |
# |    vergleichbaren(0)         |                    |    Geschick(6)               |    Backend(3)                |    sowie(4)                 |    Python(5)                 |    Sorgfalt/Genauigkeit(6)   |    geben(6)                  |
# |                              |                    |    biomedizinischen(2)       |    Programmoptimierung(3)    |    runden(4)                |    CAs(5)                    |    Teamfähigkeit(6)          |    Connector(1)              |
# |    verfügst(3)               |                    |    PKW(2)                    |    Handwerklich(3)           |    Wort(4)                  |    CSS3(5)                   |    Umgangsformen(7)          |    voranzutreiben(3)         |
# |    Energietechnik(0)         |                    |    Arbeiten(7)               |    und/oder(3)               |    Wort(4)                  |    STL(5)                    |    beharrliche(6)            |    Station(2)                |
# |    Studium(0)                |                    |    idealerweise(2)           |    Interesse(3)              |    Analytisches(4)          |    relevanten(5)             |    Arbeitsweise(2)           |    Empathie(6)               |
# |    grundständig(0)           |                    |    verfügen(2)               |    Gutes(3)                  |    sowie(4)                 |    Framework(3)              |    Arbeitsweise(6)           |    sprichst(6)               |
# |    Interface/Interaction(0)  |                    |    technisch(2)              |    ESB(3)                    |    Zielorientierte(4)       |    PowerPoint(5)             |    hohen(6)                  |    Client-Server-Umfeld(3)   |
# |                              |                    |    Verkaufen(2)              |    engagierten(3)            |    Clarity(4)               |    Angular(5)                |    sowie(6)                  |    zuverlässigen(6)          |
# |    Informatik(0)             |                    |    Persönliche(2)            |    Antriebstechnik(2)        |    gute(4)                  |    kennst(5)                 |    sowie(7)                  |    sowie(2)                  |
# |    CTA(0)                    |                    |    Autoausweis(7)            |    wünschenswert(7)          |    Erste(4)                 |    Notes(5)                  |    Ausgeprägte(6)            |    Fahrerlaubnis(2)          |
# |    m/w/d(0)                  |                    |    Denken(2)                 |    Learning(5)               |    sowie(4)                 |    Grundkenntnisse(7)        |    Arbeitsweise(6)           |    LuftSiG(3)                |
# |    Staplerschein(0)          |                    |    Klasse(2)                 |    Vorteil(3)                |    Ausgeprägtes(4)          |    Tower(5)                  |    sowie(6)                  |    aufbaut(3)                |
# |    Psychologie(0)            |                    |    Geschick(2)               |    zurück(7)                 |    sowie(4)                 |    CSS3(5)                   |    sorgfältig(6)             |    Blick(5)                  |
# |    Betriebswirt(0)           |                    |    sowie(2)                  |    UI(3)                     |    erwünscht(4)             |    BI(5)                     |    Kommunikative(6)          |    Beruf(0)                  |
# |    andere(0)                 |                    |    erforderlich(7)           |    iOS(3)                    |    Englischkenntnisse(4)    |    sowie(7)                  |    hohe(6)                   |    Endkunden(2)              |
# |    Berufserfahrung(0)        |                    |    Verkauf(3)                |    C#(3)                     |    Englischkenntnisse(4)    |    SAP(7)                    |    Gewandtheit(7)            |    unserer(3)                |
# |    Psychotherapie(3)         |                    |    erforderlich(7)           |    begeistern(3)             |    sowie(4)                 |    Persönliche(5)            |    Hohes(6)                  |    wissenschaftlicher(2)     |
# |    Heilerziehungspfleger(0)  |                    |    sowie(2)                  |    Produkte(3)               |    Berufsausbildung(4)      |    hast(5)                   |    sowie(6)                  |    ist(5)                    |
# |    Ausbildung(0)             |                    |    Freude(6)                 |    Kenntnisse(7)             |    gute(4)                  |    Azure(5)                  |    Persönlichkeit(6)         |    Innovationen(3)           |
# |    Gesundheits(0)            |                    |    Interesse(3)              |    Bereich/Montage(2)        |    ist(4)                   |    Node.js(5)                |    lösungsorientiert(6)      |    sowie(3)                  |
# |    vergleichbare(0)          |                    |    lösungsorientiertes(2)    |    im(3)                     |    sowie(4)                 |    CANoe(7)                  |    Belastbarkeit(6)          |    Engagement(6)             |
# |    Mathematik(0)             |                    |    sowie(2)                  |    9001:2015(3)              |    Voraussetzungen(7)       |    Windows(5)                |    organisatorische(6)       |    agilen(6)                 |
# |    Mechatronik(0)            |                    |    7,5t(2)                   |    NoSQL(5)                  |    Weitere(4)               |    CISSP(5)                  |    Ausgeprägte(6)            |    Bereich(3)                |
# |    Beikoch/Beiköchin(0)      |                    |    komplexer(2)              |    gute(3)                   |    sowie(4)                 |    P8(5)                     |    Teamorientiertheit(7)     |    Personalberatung(3)       |
# |    Ausbildung;(0)            |                    |    Bestellung(7)             |    Beispiel(3)               |    Wort(4)                  |    Java(5)                   |    Leistungsbereitschaft(6)  |    einzuarbeiten(3)          |
# |    Ausbildung(0)             |                    |    Office-Kenntnisse(2)      |    Qualitätsmanagement(3)    |    Selbstständige(4)        |    MySQL(5)                  |    hohe(6)                   |    z(3)                      |
# |    Psychotherapie(0)         |                    |    hast(6)                   |    Oriented(3)               |    sowie(4)                 |    Bootstrap(5)              |    speditive(2)              |    Implementation(5)         |
# |    Wirtschaftsinformatik(0)  |                    |    sowie(2)                  |    Kenntnisse(3)             |    Wort(4)                  |    Microsoft(3)              |    Mobilität(6)              |    Ausbildung(0)             |
# |                              |                    |    Sicheren(2)               |    Grundkenntnissen(3)       |    fliessend(4)             |    Erfahrungen(5)            |    Flexibilität(7)           |    sind(5)                   |
# |    können(0)                 |                    |    Organisationsgeschick(2)  |    Produkten(7)              |    sowie(4)                 |    JavaScript(5)             |    Auftreten(6)              |    Abgeschlossene(0)         |
# |    Heilpädagoge(0)           |                    |    arbeiten(2)               |    Kenntnisse(3)             |    Clarity(4)               |    Erfahrung(5)              |    Genauigkeit(6)            |    Bereich(3)                |
# |    ETH(0)                    |                    |    Erfahrungen(2)            |    Gute(3)                   |    sowie(4)                 |    Spring(7)                 |    Bereitschaft(6)           |    Initiative(6)             |
# |    Psychotherapie(3)         |                    |    Verständnis(3)            |    Java(7)                   |    Clarity(4)               |    PHP(5)                    |    prozessorientierten(6)    |    Arbeit(2)                 |
# |    Psychiatrie(0)            |                    |    Fähigkeit(2)              |                              |    Englischkenntnisse(4)    |    Management(3)             |    Kunden(6)                 |    Software(2)               |
# |    Berufsausbildung(7)       |                    |    Sorgfalt/Genauigkeit(2)   |    Staplerführerschein(2)    |    Sprache(4)               |    Python(5)                 |    Denken(2)                 |    und/oder(1)               |
# |    Berufsausbildung(3)       |                    |    Gepflegtes(2)             |    Controlling(3)            |    gute(4)                  |    Kenntnisse(5)             |    Teamfähigkeit(6)          |    sind(5)                   |
# |    beziehungsweise(0)        |                    |                              |    sind(2)                   |    Englischkenntnisse(4)    |    Android(5)                |    gewissenhafte(6)          |    Beispiel(3)               |
# |    Logistik(0)               |                    |    Konzeption(3)             |    Vorteil(3)                |    Sprache(4)               |    Spring(5)                 |    Freude(6)                 |    erforderlich(2)           |
# |    Physik(0)                 |                    |    Freude(7)                 |    potenziellen(7)           |    Wort(4)                  |    und/oder(5)               |    Beratungskompetenz(6)     |    sowie(2)                  |
# |    Psychotherapie(3)         |                    |    leisten(2)                |                              |    sowie(4)                 |    sowie(5)                  |    Persönlichkeit(6)         |    sowie(3)                  |
# |    Beikoch(7)                |                    |    wissen(7)                 |    sowie(3)                  |    sind(4)                  |    Kenntnisse(5)             |    zeitliche(6)              |    Verfassung(2)             |
# |    berufliche(7)             |                    |    Menschen(7)               |    Softwaretool(3)           |    Wort(4)                  |    JavaScript(5)             |    Arbeiten(2)               |    Spaß(0)                   |
# |    Fachlagerist(0)           |                    |    CAM-Systemes(7)           |    im(3)                     |    Erforderlich(4)          |    CMS(7)                    |    Zuverlässigkeit(6)        |    Ausgeprägte(1)            |
# |    Ingenieurwesen(0)         |                    |    Klasse(2)                 |    etc(3)                    |    Englischkenntnisse(4)    |    Spring(5)                 |    Initiative(6)             |    KindererzieherIn(0)       |
# |    Interesse(0)              |                    |    Offenheit(7)              |    gehendes(7)               |    Reisebereitschaft(4)     |    TypeScript(5)             |    Beratungshaltung(6)       |    Ausbildung(0)             |
# |    Ökotrophologie(0)         |                    |    Organisationsgeschick(6)  |    Datenbanken(5)            |    Englischkenntnisse(4)    |    Javascript(5)             |    Malerunternehmen(7)       |    Abrieb(3)                 |
# |    grundständig(0)           |                    |    im(7)                     |    ICE(5)                    |    Englischkenntnisse(4)    |    eventuell(5)              |    prozessorientierten(2)    |    DEKRA(1)                  |
# |    Kenntnisse(0)             |                    |    Gute(7)                   |    Oriented(3)               |    sowie(4)                 |    basierte(5)               |    Fähigkeiten(2)            |    Arbeit(6)                 |
# |    vergleichbare(0)          |                    |    je(2)                     |    Elektro(3)                |    sind(4)                  |    Office(7)                 |    Belastbarkeit(6)          |    Lagerlogistik(0)          |
# |    grundständig(0)           |                    |    Account(7)                |    Zertifizierung(5)         |    Englischkenntnisse(4)    |    Android-Umfeld(5)         |    Flexibilität(6)           |    Anforderungsprofil(2)     |
# |    Medizin(0)                |                    |    Handeln(7)                |    Ware(2)                   |    runden(2)                |    Kenntnisse(5)             |    zielorientiertes(6)       |    MS(2)                     |
# |    vergleichbaren(0)         |                    |    Montagebereitschaft(7)    |    Schaltanlagen(3)          |    Fahrerlaubnis(7)         |    o(5)                      |    teamfähige(6)             |    sowie(2)                  |
# |    o.ä(0)                    |                    |    Montieren(7)              |    Heidenhain(3)             |    Spanisch(4)              |    basierten(5)              |    sein(6)                   |    logische(6)               |
# |    d/m/w(0)                  |                    |    Organisationsgeschick(2)  |    Tools(3)                  |    sowie(2)                 |    Office(2)                 |    arbeitet(6)               |    besitzen(0)               |
# |    Psychiatrie(0)            |                    |    Montagebereitschaft(2)    |    D-Software(7)             |    Bevorzugt(4)             |    Objective(5)              |    Teamfähigkeit(6)          |    zeigen(2)                 |
# |    Digitale(0)               |                    |    Team(7)                   |    Java(3)                   |    sind(4)                  |    Java-Ökosys-​(5)           |    sind(6)                   |    sollten(1)                |
# |    grundständig(0)           |                    |    leisten(2)                |    Java(3)                   |    Englischkenntnisse(4)    |    CSS(5)                    |    Bereitschaft(6)           |    Vorteil(2)                |
# |    Elektrotechnik(0)         |                    |    Montagebereitschaft(2)    |    Netzwerk(3)               |    C1(4)                    |    CSS3(5)                   |    Arbeitsweise(6)           |    Asset(3)                  |
# |    vergleichbar(0)           |                    |    Denken(2)                 |    Geschäftsabläufe(7)       |    sowie(4)                 |    etc(5)                    |    sowie(6)                  |    Pflegeheimen(3)           |
# |    vergleichbare(0)          |                    |    B(2)                      |    Atemtherapie(3)           |    und/oder(4)              |    vergleichbaren(5)         |    strukturierte(6)          |    Lösungen(3)               |
# |    Fleischereitechnik(0)     |                    |    Produkten(2)              |    Basis(3)                  |    Wort(4)                  |    CISA(5)                   |                              |    Voll(1)                   |
# |    ä(0)                      |                    |    Montagebereitschaft(2)    |    Erfahrung(5)              |    sowie(4)                 |    basierenden(5)            |    Kundenorientierung(6)     |    schwerer(3)               |
# |    m/w/d(0)                  |                    |    PowerPoint(2)             |    idealerweise(2)           |    Englischkenntnisse(4)    |    JavaScript-Framework(5)   |    flexibel(6)               |    Berufsanfängern(3)        |
# |    Regelungstechnik(0)       |                    |    Team(7)                   |    Bereitschaft(3)           |    Hochdeutsch(7)           |    ABAP(5)                   |    Denken(6)                 |    Fähigkeit(3)              |
# |    Systemintegration(0)      |                    |    Kat(2)                    |    Prozessen(7)              |    sind(4)                  |    5+(5)                     |    neugierig(6)              |    Regelsatzverordnung(3)    |
# |    Psychosom(0)              |                    |    IT(3)                     |    Kundenorientierte(7)      |    sowie(4)                 |    Hohe(5)                   |    hohem(6)                  |    Teamplayer(2)             |
# |    Informatik(0)             |                    |    Klasse(2)                 |    Türen(3)                  |    Kursmodulen(4)           |    Darüber(5)                |    Teamgeist(6)              |    Vorkontierung(3)          |
# |    ersten(0)                 |                    |    Produkten(5)              |    dSPACE(5)                 |    gerne(4)                 |    EE(5)                     |    Kompetenz(6)              |    Grundkenntnisse(5)        |
# |    mindestens(0)             |                    |    zeitweilige(2)            |    mindestens(3)             |    Mindestalter(4)          |    JavaScript(5)             |    Persönlichkeit(6)         |    sowie(6)                  |
# |    Berufserfahrung(0)        |                    |    erforderlich(7)           |    AWS(5)                    |    Mindestalter(4)          |    fällt(5)                  |    Flexibilität(6)           |    oben(2)                   |
# |    Studium(0)                |                    |    rasche(2)                 |    etc(3)                    |    Motivierte(4)            |    Handels-/E-Commerce(5)    |    Teamfähigkeit(6)          |    Fähigkeit(3)              |
# |                              |                    |    runden(2)                 |    Umgebungen(7)             |    englisch(4)              |    VB.NET(5)                 |    sowie(6)                  |    Überdurchschnittliche(3)  |
# |    VWL(0)                    |                    |    LKW(7)                    |    Stahlbauunternehmens(3)   |    sind(5)                  |    Kenntnisse(5)             |    Leistungsbereitschaft(6)  |                              |
# |    Bürokaufmann(0)           |                    |    Freude(2)                 |    Sauberer(3)               |    MS-Office-Kenntnisse(4)  |    Java(5)                   |    Wünschenswert(6)          |    SAP-R/3-Kenntnisse(2)     |
# |    Finanzwesen(7)            |                    |    Arbeitsortes(7)           |    Heizungsanlagen(3)        |    Wort(4)                  |    Leidenschaft(5)           |    Konfliktfähigkeit(6)      |    einzuarbeiten(3)          |
# |    Psychotherapie(0)         |                    |    Klasse(2)                 |    hohe(3)                   |    Wort(4)                  |    sind(5)                   |    zuverlässig(6)            |    Quereinsteiger(0)         |
# |    Betriebstechnik(0)        |                    |    agilen(5)                 |    u.a(3)                    |    sind(4)                  |    JavaScript(5)             |    Teamfähigkeit(6)          |    pädagogisches(6)          |
# |    abgeschlossen(0)          |                    |    Freude(2)                 |    Einführung(2)             |    Gute(7)                  |    C#(5)                     |    selbständiges(7)          |    Weissputz(3)              |
# |    Krankenpfleger(0)         |                    |    erforderlich(7)           |    Simulationsverfahren(3)   |    German(4)                |    CSS(5)                    |    Arbeitsweise(6)           |    sind(6)                   |
# |    Psychosom(1)              |                    |    Klasse(2)                 |    Wissen(5)                 |    Kenntnisse(4)            |    haben(5)                  |    zuverlässige(6)           |    kommunikative(6)          |
# |    Fachkraft(1)              |                    |    Organisationsgeschick(2)  |    Enterprise(5)             |    verhandlungssicher(4)    |    ERP-System(5)             |    verhandlungssicher(2)     |    Monitoring(5)             |
# |    Elektrotechnik(0)         |                    |    Montagebereitschaft(2)    |    Test(3)                   |    Fähigkeiten(4)           |    sind(5)                   |                              |    Kundenberatung(3)         |
# |    Facharzt/-ärztin(7)       |                    |    Freude(2)                 |    Systeme(2)                |    sowie(4)                 |    Google(5)                 |    Zuverlässigkeit(6)        |                              |
# |    vergleichbare(0)          |                    |    Office-Anwendungen(2)     |    Engineering(7)            |    Vertrauensvolle(4)       |    XML(5)                    |    Arbeitsweise(6)           |    werden(3)                 |
# |    Approbation(0)            |                    |    Kenntnisse(2)             |    Kenntnisse(2)             |    sowie(4)                 |    verstehendes(5)           |    bist(6)                   |    haben(5)                  |
# |    Ausbildung(3)             |                    |    Office(2)                 |                              |    mündlich(4)              |    ABAP(5)                   |    sowie(2)                  |    Aufgabenbereich(6)        |
# |    Fleischer(0)              |                    |    zählen(2)                 |    Management(3)             |    sowie(4)                 |    AutoCAD(5)                |                              |    MongoDB(5)                |
# |    m/w/d(0)                  |                    |    Gespür(7)                 |    wünschenswert(3)          |    Englischkenntnisse(4)    |    HTML5(5)                  |    Auftreten(6)              |    KleinkinderzieherIn(0)    |
# |    Engineer(3)               |                    |    Autoausweis(7)            |    Analytische(1)            |    sowie(4)                 |    sind(5)                   |    Belastbarkeit(6)          |    Umgang(2)                 |
# |    vergleichbares(0)         |                    |    B(2)                      |    sowie(2)                  |    Wort(4)                  |    Datenbanken(5)            |    Arbeitsweise(6)           |    sowie(6)                  |
# |    Abschluss(0)              |                    |    sowie(2)                  |    Airbuserfahrung(3)        |    Sprachkenntnisse(4)      |    Idealerweise(5)           |    betreffend(6)             |    Konfliktfähigkeit(6)      |
# |    Praktische(0)             |                    |    gute(2)                   |    Energiemanagement(3)      |    und/oder(4)              |    JavaScript(5)             |    sympathisches(6)          |    HTML(5)                   |
# |    Gerüstmonteur(0)          |                    |    Durchführen(2)            |    Wissen(3)                 |    Wort(4)                  |    REST(5)                   |    neue(6)                   |    Sharepoint(5)             |
# |    Elektroniker(0)           |                    |    Fachdokumenten(2)         |    Unity(3)                  |    gute(4)                  |    Verhandlungssichere(5)    |    kommunikative(6)          |    Kommunikation(6)          |
# |    vergleichbaren(0)         |                    |    Handeln(7)                |    vertraut(7)               |    Wort(4)                  |    IDEA(5)                   |    flexible(6)               |    Art(6)                    |
# |    vergleichbare(0)          |                    |    Team(7)                   |    Ware(2)                   |    gute(4)                  |    Umfangreiche(5)           |    positive(7)               |    Arbeit(2)                 |
# |    m/w(5)                    |                    |    arbeitsagogische(7)       |    Integration(3)            |    gute(4)                  |    Cloud(5)                  |    Denkvermögen(6)           |    Feiertagsschichten(2)     |
# |    umfassende(5)             |                    |    Gerüstbau-Kolonne(2)      |    Qualitätsprüfung(3)       |    Wort(4)                  |    haben(5)                  |    Wort(6)                   |    im(6)                     |
# |                              |                    |    leisten(2)                |    Bereich(3)                |    Englischkenntnisse(4)    |    Kenntnisse(5)             |    Gute(6)                   |    Versorgungsplanung(3)     |
# |    Berufsausbildung(3)       |                    |    Verständnis(7)            |    technischen(2)            |    Klasse(2)                |    Gute(7)                   |    Motivation(6)             |    Entschädigung(6)          |
# |    Freude(0)                 |                    |    Entwicklern(3)            |    GSAP(3)                   |    sowie(4)                 |    JavaScript/TypeScript(5)  |    ausgeprägtes(6)           |    geeigneten(0)             |
# |    Psychiatrie(0)            |                    |                              |    Entwicklung(3)            |    sowie(4)                 |    Oracle(5)                 |    sowie(6)                  |    Ausbildung(0)             |
# |    vergleichbare(0)          |                    |    Klasse(2)                 |    Industrie4.0(5)           |    sowie(4)                 |    Sass/Less(5)              |    eigenverantwortliche(6)   |    speziell(3)               |
# |    Psychiatrie(0)            |                    |    mitbringen(2)             |    ähnlichen(3)              |    Englischkenntnisse(4)    |    Manager(1)                |    Teamfaehigkeit(2)         |    sprichst(3)               |
# |    grundständig(0)           |                    |    Profil(2)                 |    potenziellen(7)           |    Englischkenntnisse(4)    |    Deutsch(3)                |    Berufsausbildung(7)       |    sowie(2)                  |
# |                              |                    |    Verfassung(2)             |    Java(3)                   |    besitzt(4)               |    Atlassian(5)              |    gute(6)                   |    dokumentieren(2)          |
# |    mindestens(0)             |                    |    Anforderungsanalysen(2)   |    Erfahrungen(3)            |    Wort(4)                  |    ORACLE(5)                 |    Arbeitsweise(6)           |    Expert(1)                 |
# |    Nachrichtentechniker(0)   |                    |    Sehr(2)                   |    Bestand(3)                |    Vorteil(7)               |    Erfahrung(5)              |                              |    CAS(0)                    |
# |    vergleichbare(0)          |                    |    Elektrotechnik(3)         |    Data(5)                   |    sowie(4)                 |    git(5)                    |    arbeiten(6)               |    SGB(3)                    |
# |    Bauingenieur(0)           |                    |    lösungsorientiertes(2)    |                              |    Wort(4)                  |    Hibernate(5)              |    Spaß(6)                   |    Zerspanungsmechaniker(0)  |
# |    Mehrjährige(0)            |                    |    Arbeiten(7)               |    IT-Security(5)            |    Bevorzugt(4)             |    Revit(5)                  |    Einsatzbereitschaft(6)    |    wissbegierigen(6)         |
# |    Grundausbildung(0)        |                    |    Führerschein(2)           |    Gesetzen(2)               |    sowie(4)                 |    Javascript(5)             |    Gipser(6)                 |    Offenheit(2)              |
# |    Lackierbereich(1)         |                    |    entsprechender(7)         |    Vorgaben(7)               |    Wort(4)                  |    PHP(5)                    |    Teamfähigkeit(6)          |    technisches(1)            |
# |    m/w/d(0)                  |                    |    Kenntnisse(2)             |    Exchange(3)               |    sowie(4)                 |    Hibernate(5)              |    Arbeitsweise(2)           |    Python(3)                 |
# |    Sanitär(0)                |                    |    arbeiten(2)               |    Kenntnisse(7)             |    Persönliche(4)           |    Kenntnisse(3)             |    kommunikative(6)          |    Menschenbild(6)           |
# |    Ausbildung(0)             |                    |    Handeln(6)                |    Hervorragende(3)          |    sowie(4)                 |    Windchill(5)              |    teamorientierter(6)       |    Schulabschluss(2)         |
# |    bald(0)                   |                    |    Begabung(3)               |    Verpacken(3)              |    Wort(4)                  |    sowie(7)                  |    zuverlässige(6)           |    S/MIME(5)                 |
# |    Wirtschaftsinformatik(0)  |                    |    Freundliches(2)           |    IntelliJ(3)               |    Englischkenntnisse(4)    |    Hohe(5)                   |    Belastbarkeit(6)          |    Kenntnisse(5)             |
# |    Erfahrung(0)              |                    |    Team(3)                   |    Führerschein(7)           |    verhandlungssicher(4)    |    Erfahrung(5)              |    Reisebereitschaft(6)      |    sowie(6)                  |
# |    w/m/d(0)                  |                    |    heterogenen(3)            |    Sicheres(3)               |    Englisch(4)              |    X.509-Zertifikaten(5)     |    Denken(6)                 |    Übernahme(6)              |
# |    §66(0)                    |                    |    Integration(3)            |    Kenntnisse(5)             |    Persönliche(4)           |    Office(2)                 |    Arbeitsweise(6)           |    Gute(2)                   |
# |    Berufsausbildung(3)       |                    |    Wochenendarbeit(2)        |    relationale(3)            |    verfügen(7)              |    APP-Entwicklung(5)        |    Arbeitsweise(6)           |    gute(2)                   |
# |    Steuerhintergrund(7)      |                    |    SAP(5)                    |    Windows(3)                |    Sprache(4)               |    S(5)                      |    Arbeitsweise(6)           |    explizit(3)               |
# |    Lebensmittelhandwerk(0)   |                    |    Fundierte(2)              |    Technisches(7)            |    sowie(4)                 |    Erfahrung(5)              |    Denken(6)                 |    sowie(3)                  |
# |    Lackierer(1)              |                    |    Lösungen(3)               |    potenziellen(7)           |    Clarity(4)               |    AS(5)                     |    Führerscheine(6)          |    unserer(3)                |
# |    IT(7)                     |                    |    Kontaktfreude(2)          |    sind(3)                   |    sowie(5)                 |    Network(5)                |    Arbeiten(6)               |    genannten(0)              |
# |    zum(0)                    |                    |    Trainings(7)              |    Bank(7)                   |    Englischkenntnisse(4)    |    Nexus(5)                  |    Arbeiten(6)               |    Auffassungsgabe(6)        |
# |    grundständig(0)           |                    |    sowie(7)                  |    XML(3)                    |    mündlich(4)              |    Framework(5)              |    sowie(7)                  |    Salepoint(5)              |
# |    Mathematik(0)             |                    |    Kat(2)                    |    OOD(3)                    |    gute(4)                  |    Doors(5)                  |                              |    Ausbildung(0)             |
# |    Chemielaborant(0)         |                    |    Bereich(7)                |    einzustellen(7)           |    sind(4)                  |    sind(5)                   |    offene(6)                 |    3-Kenntnisse(5)           |
# |    Psychiatrie(1)            |                    |    ist(7)                    |    Sachkontenbuchhaltung(3)  |    Drittmittels(4)          |    4D(5)                     |    zielorientierte(6)        |    Netzwerktopologie(3)      |
# |    grundständig(0)           |                    |    Verständnis(3)            |    runden(5)                 |    Vorteil(4)               |    MYSQL(5)                  |    Malerunternehmen(7)       |    Webservice(3)             |
# |    IHK(0)                    |                    |    Gutes(2)                  |    Türen(3)                  |    Erforderlich(4)          |    AngularJS(5)              |    Flexibilität(6)           |    Bereich(0)                |
# |    Gerne(0)                  |                    |    Reisebereitschaft(3)      |    gute(7)                   |    Zudem(4)                 |    Spring(7)                 |    Auftreten(6)              |    Weiterbildung(2)          |
# |    Berufsausbildung(3)       |                    |    externen(2)               |    Zudem(3)                  |    Konstante(4)             |    Kenntnisse(7)             |    Wünschenswert(6)          |    entladen(3)               |
# |    Elektroanlagenmonteur(0)  |                    |    ausgeprägten(3)           |    Design(3)                 |    Erforderlich(4)          |    sowie(5)                  |    Denkweise(6)              |    Mitarbeit(2)              |
# |    Bereich(0)                |                    |    Freundliches(2)           |    Demontage(3)              |    Wort(4)                  |    Kenntnisse(5)             |    zielorientierte(6)        |    Rahmen(2)                 |
# |    w/m/d(0)                  |                    |    sowie(2)                  |    Steuerungstechnik(3)      |    Dialekt(4)               |    anderen(5)                |    Handeln(6)                |    Anforderungsprofil(3)     |
# |    erfolgreich(0)            |                    |    runden(2)                 |    Erste(5)                  |    sowie(4)                 |    Outlook(5)                |    belohnt(6)                |    PROFIL(2)                 |
# |    Sozialwissenschaften(0)   |                    |    Customizing(7)            |    sowie(7)                  |    Deutsch(4)               |    Idealerweise(5)           |    prozessorientierten(7)    |    Fahrerlaubnis(2)          |
# |    Psychiatrie(1)            |                    |    Montagebereitschaft(7)    |    Vorteil(3)                |    Englisch(4)              |    Luftrecht(5)              |    sind(2)                   |    wirtschaftlich(6)         |
# |    Technomathematik(0)       |                    |    sowie(2)                  |    Trockenbau(3)             |    bringst(4)               |    Java(5)                   |    Handeln(6)                |    10(3)                     |
# |    o.ä(0)                    |                    |    Schulabschluss(2)         |    Fenster(7)                |    Sprache(4)               |    Projektmanagement(5)      |    Engagement(6)             |    Berufsabschluss(2)        |
# |    beziehungsweise(0)        |                    |    Beschreibung(2)           |    sowie(2)                  |    Englischkenntnisse(4)    |    Branchenkenntnisse(5)     |    Berufsausbildung(7)       |    können(3)                 |
# |    grundständig(0)           |                    |    sowie(2)                  |    Beispiel(3)               |    Sprachkenntnisse(4)      |    Docker(5)                 |    Softwareprojekt(6)        |    motivieren(2)             |
# |    Anwendungsentwicklung(0)  |                    |    Bereich(7)                |    Peripherie(3)             |    Persönliche(4)           |    UA(5)                     |    teamorientierten(2)       |    Kundenstandort(2)         |
# |    entsprechender(0)         |                    |    Mo-Fr(2)                  |                              |    ist(4)                   |    sowie(5)                  |    Gute(6)                   |    hohes(2)                  |
# |    Fachlagerist(7)           |                    |    interessiert(2)           |    beziehungsweise(2)        |    Sprache(7)               |    Erfahrung(5)              |    lösungsorientierte(6)     |    AdobeXD(5)                |
# |    EFZ(0)                    |                    |    Offene(2)                 |    Fahrausweis(2)            |    Englischkenntnisse(4)    |    Hibernate(3)              |    Flexibilität(7)           |    bringen(3)                |
# |    Medizintechnik(0)         |                    |    Kontakt(3)                |    Services(7)               |    sowie(4)                 |    DoIT(5)                   |    Erscheinungsbild(7)       |    Nebenfach(0)              |
# |    Heizung(3)                |                    |    Code(3)                   |    Kandidaten(7)             |    Begeisterung(4)          |    Excel(2)                  |    Organisationstalent(6)    |    Arbeit(2)                 |
# |    gehen(3)                  |                    |    Montagebereitschaft(7)    |    wäre(3)                   |    sowie(4)                 |    Vertraut(3)               |    Arbeitsweise(6)           |    Sensibilität(2)           |
# |    vergleichbare(0)          |                    |    Hohe(7)                   |    Vertieftes(3)             |    mündlich(4)              |    Boost-Libraries(5)        |    Zuverlässigkeit(6)        |    Java(3)                   |
# |    technisch(0)              |                    |    Montagebereitschaft(2)    |    Internet-Technologien(3)  |    Englischkenntnisse(4)    |    Steuerung(5)              |    Arbeitsweise(6)           |    multikulturellen(2)       |
# |    Lebensmitteltechnik(0)    |                    |    Verständnis(2)            |    Erfahrung(2)              |    sowie(4)                 |    Expressions(5)            |    Persönlichkeit(6)         |    abgeschlossenem(0)        |
# |    Mathematik(0)             |                    |    neuer(2)                  |    Lagerorganisation(3)      |    Freundliche(4)           |    CSS(5)                    |    strukturiert(6)           |    Mechaniker(0)             |
# |    Fachverkäufer(0)          |                    |    international(2)          |    lesen(3)                  |    Sprache(4)               |    React(5)                  |    Reisebereitschaft(6)      |    Bankenlandschaft(3)       |
# |    Wirtschaftsinformatik(0)  |                    |    mehreren(7)               |    Betreuung(3)              |    B2(4)                    |    CSS3(5)                   |    Engagement(6)             |    Testfällen(2)             |
# |    Facharzt/-ärztin(0)       |                    |    Risikobewusstsein(7)      |    Betreuungsrecht(3)        |    Englisch(4)              |    C++(5)                    |    Teamfähig(6)              |    sicher(3)                 |
# |    Facharzt(3)               |                    |    Führerschein(7)           |    Programmierkenntnisse(3)  |    gute(4)                  |    Studio(5)                 |    Engagement(6)             |    Realisierungsphase(2)     |
# |    vergleichbare(0)          |                    |    Office(2)                 |    Vorteil(3)                |    Englischkenntnisse(4)    |    sind(5)                   |    neue(6)                   |    beispielsweise(3)         |
# |    abgeschlossen(0)          |                    |    Kompetenzen(7)            |    Erfolgsrechnungen(3)      |    Wort(4)                  |    C#(5)                     |    entscheidungsfähig(6)     |    autoline(5)               |
# |    beziehungsweise(0)        |                    |    Montieren(6)              |    betreuung(2)              |    Englischkenntnisse(4)    |    sowie(5)                  |    Möglichkeit(6)            |    Klasse(2)                 |
# |    mehrjährige(0)            |                    |    Gutes(2)                  |    Schubmaststaplern(3)      |    Wort(7)                  |    Server(7)                 |    Flexibilität(6)           |    Gute(2)                   |
# |    Bereich(0)                |                    |    Ort(7)                    |    arbeiten(3)               |    Englischkenntnisse(4)    |    Java(3)                   |    strukturiertes(6)         |    IT(3)                     |
# |    Mechatroniker(0)          |                    |    Abhängigkeit(7)           |    Ware(2)                   |    min(4)                   |    Sprachen(5)               |    im(6)                     |    Kenntnissen(5)            |
# |    Ausbildung(0)             |                    |    Führerschein(2)           |    DevOps(3)                 |    und/oder(4)              |    Erste(5)                  |    Sorgfalt/Genauigkeit(6)   |    Umgang(6)                 |
# |    Elektriker(0)             |                    |    bundesweit(2)             |    Einzelhandel(3)           |    sind(4)                  |    4HANA(7)                  |    Teamfähigkeit(6)          |    SQL(5)                    |
# |    Studium(0)                |                    |    Klasse(2)                 |    Gute(3)                   |    sowie(4)                 |    OO(5)                     |    Deutsch(6)                |    Zeichnungen(3)            |
# |    sowie(0)                  |                    |    handwerkliches(3)         |    Medizinische(3)           |    Englischkenntnisse(4)    |    sowie(5)                  |    Arbeit(6)                 |    Klasse(2)                 |
# ...
# |                              |                    |                              |    Umfeld(2)                 |                             |                              |    Arbeitsweise(2)           |                              |
# |                              |                    |                              |    Zeichnung(2)              |                             |                              |    Denkvermögen(6)           |                              |
# |                              |                    |                              |    Systeme(3)                |                             |                              |    Auftreten(6)              |                              |
# |                              |                    |                              |    Sourcing(3)               |                             |                              |    Team(6)                   |                              |
# |                              |                    |                              |    Javascript(3)             |                             |                              |    sowie(2)                  |                              |
# |                              |                    |                              |    JavaScript(3)             |                             |                              |    kunden(6)                 |                              |
# |                              |                    |                              |    Demontage(3)              |                             |                              |    Einfühlungsvermögen(6)    |                              |
# |                              |                    |                              |    Prozessmanagement(3)      |                             |                              |    Teamfähigkeit(6)          |                              |
# |                              |                    |                              |    Heidenhain(5)             |                             |                              |    Arbeitsweise(6)           |                              |
# |                              |                    |                              |    Zeitliche(3)              |                             |                              |    Lernbereitschaft(6)       |                              |
# |                              |                    |                              |    Umgebungen(7)             |                             |                              |    verhandlungsstarke(7)     |                              |
# |                              |                    |                              |    sowie(3)                  |                             |                              |    sind(2)                   |                              |
# |                              |                    |                              |    Menschen(3)               |                             |                              |    Malerunternehmen(7)       |                              |
# |                              |                    |                              |    Beispiel(7)               |                             |                              |    Arbeitsweise(2)           |                              |
# |                              |                    |                              |    Logistikprozesse(3)       |                             |                              |    Teamfähig(6)              |                              |
# |                              |                    |                              |    Datenbanken(7)            |                             |                              |    gegenüber(7)              |                              |
# |                              |                    |                              |    Hohe(1)                   |                             |                              |    kundenorientierte(6)      |                              |
# |                              |                    |                              |    Instrumenten(3)           |                             |                              |    Planvolles(6)             |                              |
# |                              |                    |                              |    wären(3)                  |                             |                              |    Statur(6)                 |                              |
# |                              |                    |                              |    Gute(3)                   |                             |                              |                              |                              |
# |                              |                    |                              |    Gewandtheit(3)            |                             |                              |    gerne(6)                  |                              |
# |                              |                    |                              |    Funktion(7)               |                             |                              |    Freude(6)                 |                              |
# |                              |                    |                              |    elektronische(3)          |                             |                              |    Arbeitsweise(6)           |                              |
# |                              |                    |                              |    und/oder(1)               |                             |                              |    Digitalisierung(7)        |                              |
# |                              |                    |                              |    Praktische(3)             |                             |                              |    sowie(6)                  |                              |
# |                              |                    |                              |    Fehlersuche(7)            |                             |                              |    sowie(6)                  |                              |
# |                              |                    |                              |    Intelligence(3)           |                             |                              |    sowie(6)                  |                              |
# |                              |                    |                              |    Testfälle(3)              |                             |                              |    bist(6)                   |                              |
# |                              |                    |                              |    ERP-Systemen(2)           |                             |                              |    Beratungskompetenz(6)     |                              |
# |                              |                    |                              |    Vorteil(5)                |                             |                              |    Erscheinungsbild(7)       |                              |
# |                              |                    |                              |    Qualitätssicherung(2)     |                             |                              |    administrative(2)         |                              |
# |                              |                    |                              |    gutes(5)                  |                             |                              |    gewissenhafte(6)          |                              |
# |                              |                    |                              |    Programmierung(3)         |                             |                              |    sowie(6)                  |                              |
# |                              |                    |                              |    Administrator(3)          |                             |                              |    Persönlichkeit(6)         |                              |
# |                              |                    |                              |    Belangen(3)               |                             |                              |    Grundhaltung(6)           |                              |
# |                              |                    |                              |    iOS(3)                    |                             |                              |    Selbstorganisation(6)     |                              |
# |                              |                    |                              |    Know-how(3)               |                             |                              |    konstruktives(2)          |                              |
# |                              |                    |                              |    Transport(3)              |                             |                              |    Reisebereitschaft(2)      |                              |
# |                              |                    |                              |                              |                             |                              |    Arbeitsweise(6)           |                              |
# |                              |                    |                              |    Fenstern(3)               |                             |                              |    Kommunikationsstärke(6)   |                              |
# |                              |                    |                              |    CTAL(7)                   |                             |                              |    können(6)                 |                              |
# |                              |                    |                              |    JAVA(3)                   |                             |                              |    Flexibilität(6)           |                              |
# |                              |                    |                              |    Sprachen(7)               |                             |                              |    freundliches(6)           |                              |
# |                              |                    |                              |    Sanitärinstallation(3)    |                             |                              |    sicheres(6)               |                              |
# |                              |                    |                              |    Deploymentprozesse(3)     |                             |                              |    positive(2)               |                              |
# |                              |                    |                              |    Branchenneulingen(3)      |                             |                              |    sowie(2)                  |                              |
# |                              |                    |                              |    Einführung(7)             |                             |                              |    Idee(6)                   |                              |
# |                              |                    |                              |    sind(3)                   |                             |                              |    Position(6)               |                              |
# |                              |                    |                              |    Ergänzend(3)              |                             |                              |    sowie(6)                  |                              |
# |                              |                    |                              |    Social(3)                 |                             |                              |    analytische(6)            |                              |
# |                              |                    |                              |    Türen(3)                  |                             |                              |    denken(6)                 |                              |
# |                              |                    |                              |    Leidenschaft(3)           |                             |                              |    hoher(7)                  |                              |
# |                              |                    |                              |    Steuerungstechnik(3)      |                             |                              |    Macherpersönlichkeit(7)   |                              |
# |                              |                    |                              |    Kenntnisse(5)             |                             |                              |    sowie(6)                  |                              |
# |                              |                    |                              |    wünschenswert(3)          |                             |                              |    durchsetzungsstarke(6)    |                              |
# |                              |                    |                              |    Java(3)                   |                             |                              |    Kooperationsfähigkeit(6)  |                              |
# |                              |                    |                              |    Media(2)                  |                             |                              |    konzeptionelle(2)         |                              |
# |                              |                    |                              |    Erziehung(3)              |                             |                              |    Wünschenswert(6)          |                              |
# |                              |                    |                              |    Schweißer(3)              |                             |                              |    schnell(2)                |                              |
# |                              |                    |                              |    Türen(3)                  |                             |                              |    Motivation(6)             |                              |
# |                              |                    |                              |    SQL(5)                    |                             |                              |    Verdienst(6)              |                              |
# |                              |                    |                              |    offenen(3)                |                             |                              |    leben(6)                  |                              |
# |                              |                    |                              |    Netzwerk(3)               |                             |                              |    Arbeitsweise(6)           |                              |
# |                              |                    |                              |    ist(2)                    |                             |                              |    Flexibilität(6)           |                              |
# |                              |                    |                              |    Oriented(3)               |                             |                              |    arbeiten(7)               |                              |
# |                              |                    |                              |    Ware(3)                   |                             |                              |    belastbar(6)              |                              |
