# %%
import sys
import os
sys.path.append('/home/franzi/anzeigendaten/python_base/skillextraktion/fh_ma')
sys.path.append('/home/franzi/anzeigendaten/EnvPython')
import prepare_training_data
from labels import *
import time
import warnings
warnings.filterwarnings('ignore')

from sklearn.utils import shuffle
import numpy as np
np.set_printoptions(precision=3)
# %precision 3
start = time.time()
x_train, y_train, x_test, y_test, test_afks, features = prepare_training_data.get_training_data(window=[2,3])
print('took: ',time.time()-start)

# %%
import numpy as np
label_y = prepare_training_data.one_hot_to_labels(y_train)

# %%
from tensorflow.keras import *

# %%
# Build the model
print('Build model...')
model = Sequential()
model.add(layers.LSTM(256, return_sequences=True, input_shape=(x_train.shape[1],x_train.shape[2])))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.LSTM(512, return_sequences=True))
model.add(layers.Dropout(0.5))
model.add(layers.BatchNormalization())
model.add(layers.LSTM(256))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256))
model.add(layers.Dense(units=len(labels)))
model.add(layers.Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

batch_size=64
history = model.fit(x_train, y_train, batch_size=batch_size, shuffle=True, epochs=5, validation_data=(x_test, y_test))
# Out:
# 2020-08-31 14:08:35 WARNING: From /home/franzi/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Build model...
# Train on 36942 samples, validate on 11756 samples
# 2020-08-31 14:08:38 WARNING: From /home/franzi/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/5
# 36942/36942 [==============================] - 107s 3ms/sample - loss: 0.7571 - acc: 0.7249 - val_loss: 0.5861 - val_acc: 0.7800
# Epoch 2/5
# 36942/36942 [==============================] - 105s 3ms/sample - loss: 0.5347 - acc: 0.8098 - val_loss: 0.5003 - val_acc: 0.8146
# Epoch 3/5
# 36942/36942 [==============================] - 98s 3ms/sample - loss: 0.4690 - acc: 0.8359 - val_loss: 0.4476 - val_acc: 0.8385
# Epoch 4/5
# 36942/36942 [==============================] - 102s 3ms/sample - loss: 0.4354 - acc: 0.8465 - val_loss: 0.4729 - val_acc: 0.8331
# Epoch 5/5
# 36942/36942 [==============================] - 100s 3ms/sample - loss: 0.4036 - acc: 0.8595 - val_loss: 0.4487 - val_acc: 0.8480

# %%
from matplotlib import pyplot as plt
plt.plot(np.arange(1, len(history.history['acc'])+1), history.history['acc'])
plt.plot(np.arange(1, len(history.history['acc'])+1), history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim(0.65,0.9)
plt.xticks(np.arange(1, len(history.history['acc'])+1))
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# predict test data
y_pred = model.predict(x_test)

# %%
import numpy as np
# convert one hot to labels for test data
pred_label = prepare_training_data.one_hot_to_labels(y_pred)
true_label = prepare_training_data.one_hot_to_labels(y_test)

# %%
# Calc metrics for test data
import sklearn
from sklearn.metrics import precision_score, recall_score
from tabulate import tabulate
label_list = list(labels.keys())

headers = [l for l in label_list ]
headers = [' '] + headers

table=[['precision'] + list(precision_score(true_label, pred_label, average=None)), 
       ['recall']+list(recall_score(true_label, pred_label, average=None)), 
       ['f1']+ list(sklearn.metrics.f1_score(true_label, pred_label, average=None))]

print(tabulate(table, headers=headers, tablefmt='orgtbl'))
f1 = sklearn.metrics.f1_score(true_label, pred_label, average=None)
f1 = np.delete(f1, 4)
f1 = np.delete(f1, 6)
print('f1 average: ',sum(sklearn.metrics.f1_score(true_label, pred_label, average=None))/len(list(precision_score(true_label, pred_label, average=None))))
print('f1 average: ',sum(f1)/6)
print('Precision average: ',sum(precision_score(true_label, pred_label, average=None)/8))
print('recall average: ',sum(recall_score(true_label, pred_label, average=None)/8))
print('acc', sklearn.metrics.accuracy_score(true_label, pred_label))
# Out:
# |           |   Ausbildung |    Beruf |   allgemein |   berufsspez |   Sprache |   Technologie |   Softskill |   noSkill |
# |-----------+--------------+----------+-------------+--------------+-----------+---------------+-------------+-----------|
# | precision |     0.797578 | 0.7      |    0.612137 |     0.639048 |  0.974093 |      0.792526 |    0.850552 |  0.893984 |
# | recall    |     0.853704 | 0.225806 |    0.32357  |     0.634816 |  0.850679 |      0.81457  |    0.790308 |  0.946665 |
# | f1        |     0.824687 | 0.341463 |    0.423358 |     0.636925 |  0.908213 |      0.803396 |    0.819324 |  0.919571 |
# f1 average:  0.7096169940260776
# f1 average:  0.6415254502469359
# Precision average:  0.7824897067150908
# recall average:  0.6800145961967217
# acc 0.8479925144607009

# %%
# Create Confusion Matrix

import sklearn
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

cm = sklearn.metrics.confusion_matrix(true_label, pred_label)
df_cm = pd.DataFrame(cm, labels,columns = labels)
plt.figure(figsize = (10,7))
plt.ylabel('Eingabe')
plt.xlabel('Ausgabe')
sn.heatmap(df_cm, annot=True,fmt='g')

# %%
# clean noSkill for evaluation
clean_y_pred = []
clean_y_test = []
true_noSkills = 0
clean_x_test = []
afks = []

for i in range(len(y_test)):
    if(true_label[i] != 7 or pred_label[i] != 7):
        clean_x_test.append(x_test[i])
        clean_y_pred.append(pred_label[i])
        clean_y_test.append(true_label[i])
        afks.append(test_afks[i])
    else:
        true_noSkills += 1
pred_label = clean_y_pred
true_label = clean_y_test
print('correctly labeled noSkills: ', true_noSkills)
# Out:
# correctly labeled noSkills:  6940

# %%
# Create Confusion Matrix

import sklearn
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

cm = sklearn.metrics.confusion_matrix(true_label, pred_label)
df_cm = pd.DataFrame(cm, labels,columns = labels)
plt.figure(figsize = (10,7))
plt.ylabel('Eingabe')
plt.xlabel('Ausgabe')
sn.heatmap(df_cm, annot=True,fmt='g')

# %%
from word2vec import W2V#get_closest_word_to_vec_matrix
correct = []
false = []

clean_x_test, pred_label, true_label, afks = shuffle(clean_x_test, pred_label, true_label, afks,random_state=0)
skill_index = int(len(clean_x_test[0])/2)
label_list = list(labels.keys())

# %%
headers = [['|']+[l] for l in label_list ]
headers = sum(headers, [])
headers.append('|')

wvs = []
for i in range(len(clean_x_test)):
    wvs.append(clean_x_test[i][skill_index])

w2v = W2V(skipgram=True, punctuation_marks=False, stoppwords=False, multiword=False, lower_case=False, vector_dim=100)

predictions = [[],[],[],[],[],[],[], []]
for i in range(len(clean_x_test)):
    word = w2v.get_closest_word_to_vec(wvs[i])[0][0]
    label = str(true_label[i])
    predictions[pred_label[i]].append(word + '('+label+')')

table = []
# format
i = 0
while(i < len(predictions[0]) or i < len(predictions[1]) or i < len(predictions[2]) or i < len(predictions[3]) or i < len(predictions[4]) or i < len(predictions[5] or i < len(predictions[6]))):
    row = ['|']
    for x in predictions:
        if(len(x) > i and len(x[i]) <  25): 
            row.append(x[i])
            row.append('|')
        else:
            row.append('')
            row.append('|')
            
    table.append(row)
    i+=1    

print(tabulate(table, headers=headers))
# Out:
# skipgram, punctuation_marks, stoppwords, multiword, lower_case, vector_dim True False False False False 100
# init /home/franzi/Documents/models/no_pm_no_sw_vecDim100/skip_gram_model.model
# loading existing w2v model from  /home/franzi/Documents/models/no_pm_no_sw_vecDim100/skip_gram_model.model
# |    Ausbildung                |    Beruf                 |    allgemein                 |    berufsspez                |    Sprache                |    Technologie               |    Softskill                 |    noSkill                   |
# ---  ------------------------  ---  --------------------  ---  ------------------------  ---  ------------------------  ---  ---------------------  ---  ------------------------  ---  ------------------------  ---  ------------------------  ---
# |    Gesundheits(0)            |    besitzen(1)           |    Eigenverantwortliche(2)   |    Gutes(3)                  |    Wort(4)                |    einschlägige(5)           |    Persönlichkeit(6)         |    wünschenswert(2)          |
# |    Informatik(0)             |    bringst(1)            |    Interesse(7)              |    sowie(2)                  |    Selbstständige(4)      |    HTML(5)                   |    Fähigkeit(6)              |    Arbeiten(6)               |
# |    Berufsausbildung(0)       |    w/m/d(1)              |    sind(2)                   |    Heidenhain(5)             |    Wort(4)                |    AngularJS(5)              |    Arbeitsweise(6)           |    Übernahme(6)              |
# |    Betriebstechnik(0)        |    Tätigkeiten(1)        |    bundesweit(2)             |    Freundliches(2)           |    gute(4)                |    Python(5)                 |    Arbeitsweise(6)           |    Bereitschaft(6)           |
# |    Fachpraktiker(0)          |    engagierten(3)        |    erforderlich(2)           |    Hohe(6)                   |    Englischkenntnisse(4)  |    HTML5(5)                  |    Flexibilität(2)           |    Netzwerktopologie(3)      |
# |    vergleichbare(0)          |    Schwerpunkt(1)        |    Fähigkeiten(2)            |    Schubmaststapler(3)       |    mündlich(4)            |    Android(5)                |    Arbeitsweise(6)           |    alt(2)                    |
# |    Fleischer(0)              |    mitverantwortlich(1)  |    Anforderungsanalysen(2)   |    Prozessen(2)              |    sowie(4)               |    Java(5)                   |    Flexibilität(6)           |    Zusammenarbeit(6)         |
# |    Elektroanlagenmonteur(0)  |    Tätigkeiten(1)        |    je(2)                     |    alter(3)                  |    Englischkenntnisse(4)  |    CSS(5)                    |    arbeiten(6)               |    sowie(3)                  |
# |    Lebensmittelhandwerk(0)   |    Tätigkeiten(1)        |    bringen(2)                |    Bereitschaft(3)           |    Kenntnisse(4)          |    Technologien(5)           |    analytische(6)            |    Kursmodulen(4)            |
# |    Klimatechnik(3)           |    und/oder(2)           |    Selbstständige(2)         |    Fenster(7)                |    Selbständige(4)        |    Seeburger-BIS6(5)         |    organisationsstarke(6)    |    Zeichnungen(3)            |
# |    vergleichbare(0)          |    und/oder(1)           |    Schrift(7)                |    Staplerschein(7)          |    gute(4)                |    GlassFish(5)              |    effiziente(6)             |    Auffassungsgabe(6)        |
# |    Studium(7)                |    Tätigkeiten(1)        |    Denken(6)                 |    Kenntnisse(5)             |    Englischkenntnisse(4)  |    o(5)                      |    gute(6)                   |    Belastbare(4)             |
# |    Wirtschafts(0)            |    und/oder(3)           |    Klasse(2)                 |    Fachkraft(3)              |    Motivierte(4)          |    diversen(5)               |    Motivation(6)             |    Facharzt(0)               |
# |    HTL/FH/Universität(0)     |    m/w/d(1)              |    B(2)                      |    Vorfertigung(3)           |    Wort(4)                |    JBoss(5)                  |    mindestens(6)             |    Handeln(2)                |
# |    Abgeschlossene(3)         |    und/oder(3)           |    Gutes(2)                  |    Verständnis(3)            |    Clarity(4)             |    sind(5)                   |    haben(6)                  |    weiterentwickeln(3)       |
# |    vergleichbare(0)          |    Anlagenführer(1)      |                              |    Interface/Interaction(0)  |    sowie(4)               |    OO(5)                     |    Konfliktfähigkeit(6)      |    verlieren(6)              |
# |    Nachrichtentechniker(0)   |    m/w(5)                |    Verständnis(2)            |    IT-Kenntnisse(3)          |    Mindestalter(4)        |    Strukturierte(5)          |    strukturiert(6)           |    unterschiedlichsten(3)    |
# |    Fachlagerist(7)           |    und/oder(3)           |    Verständnis(2)            |    Qualitätssicherung(2)     |    sowie(4)               |    idealerweise(5)           |    arbeiten(2)               |    Kommunikationsstärke(5)   |
# |    Metallverarbeitung(0)     |    m/w/d(1)              |    lösungsorientiertes(2)    |    Vorteil(3)                |    sowie(4)               |    Engine(7)                 |    starke(6)                 |    wäre(3)                   |
# |    technischen(0)            |    Tätigkeiten(1)        |    Selbstständige(2)         |    ServiceNow(3)             |    Motivation(4)          |    PHP(5)                    |    sicheres(7)               |    Altersversorgung(3)       |
# |    Informatik(0)             |                          |    Kunden(6)                 |    Konzeption(3)             |    sowie(4)               |    3D(5)                     |    Leidenschaft(6)           |    Weiterentwicklung(2)      |
# |    vergleichbare(0)          |                          |    Kenntnisse(2)             |    Sprachen(3)               |    Wort(4)                |    PHP(5)                    |    Idee(6)                   |    erfolgreich(2)            |
# |    Elektrotechnik(0)         |                          |    Fahrpraxis(2)             |    Versandbereich(3)         |    und/oder(4)            |    insbesondere(5)           |    sowie(6)                  |    gute(6)                   |
# |    Berufserfahrung(0)        |                          |    Sehr(2)                   |    solltest(2)               |    sowie(4)               |    Programmiersprache(5)     |    sowie(6)                  |    Sprachkenntnisse(4)       |
# |    Informationstechnik(0)    |                          |    Wochenendarbeit(2)        |    technisches(3)            |    sind(4)                |    i/Power(5)                |    lösungsorientierte(6)     |    flexibel(6)               |
# |    ähnliche(0)               |                          |    Verständnis(6)            |    Gute(3)                   |    Wort(4)                |    Adobe(7)                  |    flexible(6)               |    Geschick(3)               |
# |    fundierter(7)             |                          |    Verfassung(2)             |    Ware(2)                   |    Wort(4)                |    Vorteil(5)                |    Arbeitsweise(6)           |    Anforderungsprofil(2)     |
# |    Fleischereitechnik(0)     |                          |    Einsatzbereitschaft(6)    |    Kenntnisse(3)             |    Wort(4)                |    WebLogic(3)               |    Belastbarkeit(6)          |    Offenheit(2)              |
# |    grundständig(0)           |                          |    erforderlich(7)           |    Forstwirtschaft(3)        |    englisch(4)            |    4HANA(7)                  |    getragener(6)             |    Vorteil(3)                |
# |    vergleichbaren(0)         |                          |    Kat(2)                    |    Data(5)                   |    gute(4)                |    Keras(5)                  |    Freude(6)                 |    Produktionsprozesses(2)   |
# |    Berufsausbildung(3)       |                          |    B(2)                      |    Türen(3)                  |    Erforderlich(4)        |    sowie(5)                  |    Organisationsvermögen(6)  |    methoden(2)               |
# |    haben(0)                  |                          |    verfügen(2)               |    mindestens(3)             |    verhandlungssicher(4)  |    strukturierte(5)          |    Teamfähigkeit(6)          |    Statur(2)                 |
# |    computergestützten(0)     |                          |    CE(7)                     |    Suche(7)                  |    Englischkenntnisse(4)  |    Interesse(5)              |    Zuverlässigkeit(6)        |    IT(3)                     |
# |    m/w/d(0)                  |                          |    Breites(3)                |    verteilten(3)             |    Kundenorientierung(4)  |    Azure(5)                  |    Freude(7)                 |    Weiterbildungen(2)        |
# |    Selbstständiges(0)        |                          |    Freude(6)                 |    beziehungsweise(2)        |    Englischkenntnisse(4)  |    Angular(5)                |    Leistungsbereitschaft(6)  |    hast(6)                   |
# |    Psychotherapie(3)         |                          |    Montagebereitschaft(2)    |    HKLS-Anlagen(2)           |    sowie(4)               |    Network(5)                |    Teamfähigkeit(6)          |    Hardware(5)               |
# |    Ausbildung(0)             |                          |    Engineering(7)            |    Türen(3)                  |    Wort(4)                |    Idealerweise(7)           |    Gewissenhaftigkeit(6)     |    sowie(3)                  |
# |    bringst(0)                |                          |    zeitweilige(2)            |    Türen(3)                  |    Ausgeprägtes(4)        |    Controldesk(5)            |    Flexibilität(6)           |    im(3)                     |
# |    Informatik(0)             |                          |    Arbeiten(7)               |    XAMARIN(3)                |    Englischkenntnisse(4)  |    Logisches(5)              |    zählen(6)                 |    Level(3)                  |
# |    Psychotherapie(0)         |                          |    Wort(2)                   |    Test(3)                   |    Wort(4)                |    S(5)                      |    präzise(6)                |    Engineer(3)               |
# |    Berufserfahrung(0)        |                          |    bereit(7)                 |    Bereitschaft(3)           |    Analytisches(4)        |    Ausgeprägte(5)            |    Einwandfreie(3)           |    SGB(3)                    |
# |    Ausbildung(0)             |                          |    Flexibilität(7)           |    Metallverarbeiten(3)      |    sowie(4)               |    gute(5)                   |    sorgfältige(6)            |    ChaRM(5)                  |
# |    vergleichbare(0)          |                          |    Gepflegtes(2)             |    Erfahrung(7)              |    Wort(4)                |    WebSphere(5)              |    Motivation(6)             |    beziehungsweise(5)        |
# |    Ausbildung(0)             |                          |    lösungsorientiertes(2)    |    z(3)                      |    Wort(4)                |    Administrator(3)          |    Engagement(6)             |    Gute(2)                   |
# |    technisch(0)              |                          |    vorzugsweise(0)           |    Partner(6)                |    Englischkenntnisse(4)  |    sowie(3)                  |    Interesse(6)              |    Sprache(4)                |
# |    verfügen(1)               |                          |    Denken(2)                 |    Programmierung(3)         |    Berufsausbildung(4)    |    Server(7)                 |    zielorientierte(7)        |    Mitarbeiter(2)            |
# |    Fachverkäufer(0)          |                          |    Freude(2)                 |    Teamfähigkeit(7)          |    Englischkenntnisse(4)  |    inklusive(5)              |    Kompromissfähigkeit(6)    |    sowie(2)                  |
# |    Vorteil(0)                |                          |    Organisationsgeschick(2)  |    im(3)                     |    sowie(4)               |    C#(5)                     |    sind(6)                   |    unserer(3)                |
# |    Berufsausbildung(7)       |                          |    Montagebereitschaft(7)    |    bleiben(2)                |    gute(4)                |    Java(5)                   |    gepflegtes(7)             |                              |
# |    m/w/d(0)                  |                          |    sowie(2)                  |    sind(3)                   |    sowie(4)               |    Cloud(5)                  |    Lösungsorientierung(7)    |    im(6)                     |
# |                              |                          |    Montagebereitschaft(2)    |    Cloud(7)                  |    Folgende(4)            |    CSS3(5)                   |    sowie(7)                  |                              |
# |    kaufmännische(0)          |                          |    ausgeprägten(3)           |    Schubmaststaplern(3)      |    sowie(4)               |    JavaScript(5)             |    Belastbarkeit(6)          |    ISO(3)                    |
# |    Energietechnik(0)         |                          |    Verständnis(2)            |    Berufserfahrung(0)        |    gerne(4)               |    können(5)                 |    Position(6)               |    Gruppendynamiken(6)       |
# |    vergleichbare(0)          |                          |    lösungsorientiertes(2)    |    Media(3)                  |    und/oder(4)            |    XML(5)                    |    sorgfältige(6)            |    Bereich(3)                |
# |    beziehungsweise(0)        |                          |    erforderlich(7)           |    Transport(3)              |    sowie(4)               |    Umgang(5)                 |    Zuverlässigkeit(2)        |    med(3)                    |
# |    vergleichbare(0)          |                          |    Web(3)                    |                              |    Reisebereitschaft(4)   |    JavaScript(5)             |    Freude(6)                 |    Erfahrungen(6)            |
# |    Ausbildung(0)             |                          |    sowie(2)                  |    vorzugsweise(3)           |    sowie(4)               |    Tower(5)                  |    Reisebereitschaft(6)      |    Psychiatrie(0)            |
# |    abgeschlossen(0)          |                          |    Führerschein(2)           |    Ausgeprägte(7)            |    Wort(4)                |    Windows(5)                |    verhandlungssicher(2)     |    Engineer(3)               |
# |    geprüften(0)              |                          |    gegenüber(2)              |    einzustellen(3)           |    Persönliche(4)         |    Boost-Libraries(5)        |    neue(6)                   |    Dialog(3)                 |
# |    Kommunikationstechnik(0)  |                          |    wünschenswert(2)          |    Türen(3)                  |    sind(4)                |    C#(5)                     |    Arbeitsweise(6)           |    Gestalten(2)              |
# |    mindestens(0)             |                          |    Organisationstalent(6)    |    ABAP/ABAP(3)              |    mündlich(4)            |    CSS(5)                    |    Kontaktfreude(6)          |    Personalberatung(3)       |
# |    Umfeld(0)                 |                          |    agilen(7)                 |    AI(3)                     |    sowie(4)               |    SQL(5)                    |    Arbeiten(6)               |    Teamplayer(2)             |
# |    grundständig(0)           |                          |    strategischen(3)          |    Handwerklich(3)           |    Englisch(4)            |    JBoss/Tomcat(5)           |    Auftreten(6)              |    Teamfähigkeit(6)          |
# |    Psychiatrie(0)            |                          |    Führerschein(2)           |    Center(3)                 |    erwünscht(4)           |    ist(5)                    |    selbstständiges(2)        |    SQL(5)                    |
# |    Beratungskompetenz(0)     |                          |    Überdurchschnittliche(6)  |    O/R(3)                    |    Englisch(4)            |    Atlassian(5)              |    sowie(6)                  |    sowie(2)                  |
# |    vergleichbaren(0)         |                          |    Web-Anwendungen(3)        |    Automation(2)             |    Wort(4)                |    Python(3)                 |    Eigeninitiative(6)        |    Sensibilität(2)           |
# |    Chemielaborant(0)         |                          |    sowie(6)                  |    Gute(3)                   |    fliessend(4)           |    Office-Kenntnisse(5)      |    teamfähige(6)             |    Studium(0)                |
# |    eidg(0)                   |                          |    Führungskräften(7)        |    Manager(1)                |    C1(4)                  |    sowie(5)                  |    Kundenorientierung(6)     |    Heilpädagogik(0)          |
# |    erfolgreich(0)            |                          |    sowie(7)                  |    Vertraut(3)               |    sind(4)                |    Kenntnisse(7)             |    Auftreten(6)              |    Sprachkenntnisse(4)       |
# |    Bereich(0)                |                          |    Engagement(3)             |    Backend(3)                |    gewinnende(6)          |    5+(5)                     |    Sprachen(6)               |    Arbeit(2)                 |
# |    Psychosom(0)              |                          |    Top-Unternehmens(7)       |    Verständnis(3)            |    mündlich(4)            |    Vorteil(5)                |    Persönlichkeit(2)         |    sowie(6)                  |
# |    Physiotherapeut(0)        |                          |    Fähigkeit(2)              |    Sondermaschinen(3)        |    sowie(4)               |    Spring(5)                 |                              |    ERNI(1)                   |
# |    Krankenpfleger(0)         |                          |    Klasse(2)                 |    Handwerklich(3)           |    German(4)              |    caret(3)                  |                              |    Bankenlandschaft(3)       |
# |    Bereitschaft(0)           |                          |    Hands-on(6)               |    Persönlich(3)             |    Drittmittels(4)        |    Projekterfahrung(5)       |    Entschlossenheit(6)       |    sowie(2)                  |
# |    Heilerziehungspfleger(0)  |                          |    sowie(2)                  |    Strukturierte(3)          |    sowie(4)               |                              |    Auftreten(6)              |    bezüglich(6)              |
# |    vergleichbaren(0)         |                          |    Sehr(2)                   |    Netzwerke(3)              |    gute(4)                |    Script(5)                 |    sowie(6)                  |    Schaltschrankbau(2)       |
# |    HF/FH(0)                  |                          |    erforderlich(7)           |    Hohe(2)                   |    sowie(4)               |    basierten(5)              |    Persönlichkeit(2)         |    flexibel(2)               |
# |    Maschinenbauer(0)         |                          |    Fähigkeiten(2)            |    Design(0)                 |    Wort(4)                |    erwarten(5)               |    Affinität(6)              |    sowie(2)                  |
# |    Werkzeugmechaniker(0)     |                          |    Flexibilität(7)           |    Methoden(3)               |    sowie(4)               |    Sprachen(5)               |    Zuverlässigkeit(6)        |    sowie(2)                  |
# |    artverwandte(0)           |                          |    hat(6)                    |    Applikations(7)           |    sowie(4)               |    EPC(5)                    |    professioneller(6)        |    Vorteil(3)                |
# |    erfolgreich(0)            |                          |    B(2)                      |    Chain(7)                  |    sowie(4)               |    idealerweise(5)           |    Teamfähigkeit(6)          |    neuen(2)                  |
# |    alternativ(0)             |                          |    Klasse(2)                 |    Start-ups(1)              |    Wort(4)                |    o(5)                      |    Denken(6)                 |    gute(6)                   |
# |    ist(0)                    |                          |    sowie(6)                  |    Bereich(3)                |    sowie(4)               |    Server(3)                 |    Persönlichkeit(6)         |    Source(3)                 |
# |    Wirtschafts(0)            |                          |    gute(2)                   |    relationale(5)            |    sowie(4)               |    Kenntnisse(2)             |    Kunden(6)                 |    Koch/Köchin(0)            |
# |    beziehungsweise(0)        |                          |    Zuverlässigkeit(2)        |    mindestens(3)             |    Englischkenntnisse(4)  |    basierte(5)               |    Flexibilität(6)           |    haben(2)                  |
# |    sowie(0)                  |                          |    Führungserfahrung(2)      |    einschliesslich(3)        |    Unternehmen(4)         |    sowie(5)                  |    belastbare(6)             |    sind(3)                   |
# |    vergleichbare(3)          |                          |    Organisationsgeschick(6)  |    Komponenten(5)            |    sowie(4)               |    SASS(5)                   |    bleibt(6)                 |    Potential(6)              |
# |    Psychiatrie(7)            |                          |    Fitness(7)                |    Peripherie(3)             |    mündlich(4)            |    sowie(5)                  |    Führerschein(6)           |    Weissputz(3)              |
# |    Medizin(0)                |                          |    erforderlich(7)           |    Montageabteilung(2)       |    sowie(4)               |    Debian(5)                 |    sowie(2)                  |    Frontstapler(3)           |
# |    Anforderungen(3)          |                          |    lösungsorientiertes(2)    |    Energiemanagement(3)      |    Englischkenntnisse(4)  |    sowie(5)                  |    Arbeiten(6)               |    Umgang(6)                 |
# |    m/w/d(0)                  |                          |    Verfassung(7)             |    Testverfahren(3)          |    Englischkenntnisse(4)  |    Java(3)                   |    Führungsfähigkeit(6)      |    selbstständigen(6)        |
# |    Mechatronik(0)            |                          |    Flexibilität(7)           |    Automation(2)             |    Deutsch(4)             |    Azure(5)                  |    Denken(6)                 |    Kundenberatung(3)         |
# |    Kräftige(7)               |                          |    erforderlich(7)           |    ESB(3)                    |    Mindestalter(4)        |    gute(3)                   |    arbeiten(6)               |    unterrichten(3)           |
# |    IT-Systemelektroniker(0)  |                          |    Gute(7)                   |    idealerweise(3)           |    Englischkenntnisse(4)  |    TIPS(5)                   |    Kundenorientierung(6)     |    Umgang(2)                 |
# |    Psychotherapie(3)         |                          |    Gute(7)                   |    Programmierkenntnisse(3)  |    Englischkenntnisse(4)  |    WPF/WCF(5)                |    sicheres(6)               |    EN(3)                     |
# |    Idealerweise(7)           |                          |    offenen(3)                |    Gute(3)                   |    sowie(4)               |    Fiori(5)                  |                              |                              |
# |    Psychologie(0)            |                          |    Flexibilität(2)           |    Learning(5)               |    Englischkenntnisse(4)  |    BMC(5)                    |    sorgfältige(6)            |    haben(2)                  |
# |    guten(0)                  |                          |    Handeln(6)                |    Hohe(1)                   |    Reisebereitschaft(4)   |    Access(5)                 |    kommunikative(6)          |    sowie(0)                  |
# |    Sozialwissenschaften(0)   |                          |    Kenntnisse(6)             |    HR-Projekt(3)             |    sind(4)                |    Autodesk(5)               |    Leistungsbereitschaft(6)  |    Abschluss(3)              |
# |    vergleichbare(0)          |                          |    sowie(6)                  |    Menschen(2)               |    Englischkenntnisse(4)  |    JavaScript-Framework(5)   |    Teamfähigkeit(6)          |    Beratungskompetenz(6)     |
# |    Aufgaben(7)               |                          |    Geschick(2)               |    Vorteil(2)                |    Selbstständige(4)      |    haben(5)                  |    Fähigkeiten(6)            |    strukturierte(2)          |
# |    Elektronik(0)             |                          |    Klasse(2)                 |    Produkten(7)              |    Wort(4)                |    JavaScript(5)             |    Motivation(6)             |    testen(2)                 |
# |    Psychologie(0)            |                          |                              |    IT(3)                     |    Englischkenntnisse(4)  |    Java(5)                   |    Persönlichkeit(6)         |    Psychiatrie(1)            |
# |                              |                          |    Montagebereitschaft(7)    |    Logopädie(3)              |    Wort(4)                |    Kenntnisse(3)             |    Arbeitsweise(6)           |    Sorgfalt(6)               |
# |    Softwaretechnik(0)        |                          |    sowie(2)                  |    hoher(3)                  |    Wort(4)                |                              |    zielorientiertes(6)       |    Erfahrung(3)              |
# |    Berufsausbildung(0)       |                          |    Profil(2)                 |    strukturierter(7)         |    Englischkenntnisse(4)  |    Java(5)                   |    eigenen(6)                |                              |
# |    Wirtschaftsinformatik(0)  |                          |    leisten(2)                |    sowie(7)                  |    Englischkenntnisse(4)  |    z(3)                      |                              |    PROFIL(2)                 |
# |    Vertiefte(0)              |                          |    innovativen(7)            |    Sorgfältige(2)            |    sowie(4)               |    Batch(5)                  |    beschreibst(6)            |    Inbetriebnahme(2)         |
# |    mehrjähre(0)              |                          |    bereit(7)                 |    Türen(3)                  |    sowie(4)               |    VBA(5)                    |    Flexibilität(6)           |    Psychosomatik(1)          |
# |    Ausbildung(0)             |                          |    B(2)                      |    HTML5(3)                  |    Englisch(4)            |    Vorteil(5)                |    sein(6)                   |    Fördermittelgebern(3)     |
# |    Pflegewissenschaften(0)   |                          |    sowie(2)                  |    Ware(3)                   |    Mindestalter(4)        |    REST(5)                   |    Fähigkeiten(6)            |    Kompetenz(2)              |
# |    vorzugsweise(3)           |                          |    Optimierung(7)            |    Projektabwicklung(2)      |    Englischkenntnisse(4)  |    Basic(5)                  |    Arbeitsweise(6)           |    Kapitalmärkte(3)          |
# |    Meisterausbildung(0)      |                          |    Denken(2)                 |    Zeichnung(2)              |    sind(4)                |    Cloud(7)                  |    selbständiges(7)          |    arbeiten(3)               |
# |    Teamfähigkeit(0)          |                          |                              |    sind(3)                   |    runden(2)              |    Spring(7)                 |    Leistungsbereitschaft(6)  |    S7(5)                     |
# |    Informatik(0)             |                          |    zählen(2)                 |    vertraut(7)               |    Englischkenntnisse(4)  |    EclipseRCP(5)             |    speditive(6)              |    Personalberatung(3)       |
# |    beziehungsweise(0)        |                          |    Physikalisches(2)         |    tief(3)                   |    Französisch(4)         |    Javascript(5)             |    Auftreten(7)              |    Expert(1)                 |
# |    Sc(7)                     |                          |    körperliche(3)            |    Web-basierte(3)           |    Konstante(4)           |    Server(7)                 |    Arbeitsweise(6)           |    Psychiatrie(1)            |
# |    begabt(2)                 |                          |    Klasse(2)                 |    bringt(3)                 |    Mindestalter(4)        |    Studio(5)                 |    Interesse(6)              |    sowie(2)                  |
# |    sind(2)                   |                          |    mindestens(2)             |    Reisebereitschaft(3)      |    sowie(4)               |    Kenntnisse(5)             |    sowie(6)                  |                              |
# |    Arbeit(0)                 |                          |    Kontakt(3)                |    ausgeprägte(7)            |    Englischkenntnisse(4)  |    S(7)                      |    lösungsorientierte(6)     |    professionelles(3)        |
# |    Ausbildung(3)             |                          |    Zusammenhänge(2)          |    Shop(3)                   |    Wort(4)                |    DoIT(5)                   |    arbeitet(6)               |    3-Kenntnisse(5)           |
# |    Gerne(0)                  |                          |    erforderlich(2)           |    mobilen(3)                |    sind(4)                |    Exzellente(2)             |    Kompetenz(2)              |    Kat(2)                    |
# |    Wirtschaftsinformatik(0)  |                          |    Denken(2)                 |    Souveränes(3)             |    sowie(4)               |    ist(7)                    |    prozessorientierten(6)    |    21G(5)                    |
# |    abgeschlossenem(0)        |                          |    rasche(2)                 |    Baumschule(3)             |    Erste(4)               |    XML(5)                    |    Flexibilität(6)           |    Trockenbau(3)             |
# |    Fleischer(0)              |                          |    erforderlich(7)           |    Ware(2)                   |    sowie(5)               |    Vorteil(5)                |    zuverlässige(6)           |    einzuarbeiten(3)          |
# |    Grundausbildung(0)        |                          |    Selbstständiges(2)        |    Transport(3)              |    verhandlungssicher(4)  |    Umfangreiche(5)           |    Erfahrung(6)              |    Facharzt(3)               |
# |    HF(7)                     |                          |    Freude(2)                 |    HTML(5)                   |    ist(4)                 |    PHP(5)                    |    Auftreten(6)              |    Denkvermögen(6)           |
# |    vergleichbare(3)          |                          |    Sorgfalt(7)               |    JavaScript(3)             |    Zudem(4)               |    Softwaremodellierung(5)   |    Sorgfalt(6)               |    Einfühlungsvermögen(6)    |
# |    Beikoch(7)                |                          |    Partner(7)                |    Programming(5)            |    Mindestalter(4)        |    Doors(5)                  |    zeitliche(6)              |    werkzeuge(2)              |
# |    Bürokauffrau(7)           |                          |    Überzeugungsfähigkeit(6)  |    sicheren(3)               |    Persönliche(4)         |    Idealerweise(5)           |    Kommunikative(6)          |    fokussiert(6)             |
# |    Studium(0)                |                          |    sowie(2)                  |    Idealerweise(3)           |    Englischkenntnisse(4)  |    Framework(5)              |    Handwerkliche(6)          |    Studiengang(0)            |
# |    Mathematik(0)             |                          |    webbasierten(2)           |    Fähigkeit(3)              |    Persönliche(4)         |    JS(5)                     |    Denken(6)                 |    bildet(3)                 |
# |    Elektroniker(0)           |                          |    Führungserfahrung(2)      |    insbesondere(3)           |    Englischkenntnisse(4)  |    beziehungsweise(5)        |                              |    Kenntnisse(2)             |
# |    andere(0)                 |                          |    sowie(2)                  |    Freundliches(3)           |    Weitere(4)             |    Erfahrungen(5)            |    hohes(6)                  |    automatisierter(2)        |
# |    Physik(0)                 |                          |    B(2)                      |    Backend(3)                |    sowie(4)               |    OO(5)                     |    konzeptionelle(6)         |    Verfassung(2)             |
# |    Mathematik(0)             |                          |    PHP(3)                    |    Entwickler(3)             |    beherrschen(4)         |    Confluence(3)             |    Mentalität(6)             |    Hohes(2)                  |
# |    Verfahrenstechnik(0)      |                          |    Mobilität(2)              |    Sourcing(3)               |    Wort(4)                |    Kenntnisse(5)             |    Arbeiten(6)               |    sowie(2)                  |
# |                              |                          |    Teamfähigkeit(2)          |    kognitiv(3)               |    Führerschein(4)        |    sind(2)                   |    Verwaltungserfahrung(2)   |    sind(3)                   |
# |    ähnlichen(0)              |                          |    erforderlich(2)           |    Blechbearbeitung(3)       |    Bestandskunden(4)      |    Doctrine(5)               |    Gipser(7)                 |    Personen(6)               |
# |    sind(3)                   |                          |    Flexibilität(2)           |    PNF(3)                    |    besitzt(4)             |    Spring(7)                 |    strukturierte(6)          |    wäre(3)                   |
# |    Berufsausbildung(3)       |                          |    Montagebereitschaft(7)    |    Psychotherapie(3)         |    mündlich(4)            |    Gute(5)                   |    Fähigkeiten(6)            |    Vorteil(2)                |
# |    Medizin(0)                |                          |    automatischer(3)          |    Produkten(2)              |    gute(4)                |    AWS(5)                    |    Kommunikationsstärke(6)   |    sowie(3)                  |
# |    Ausbildung(7)             |                          |    Account(7)                |    Idealerweise(7)           |    Wort(4)                |    sowie(5)                  |    neue(6)                   |    Abrieb(3)                 |
# |    Informatik(0)             |                          |    sowie(2)                  |    Logos(3)                  |    Wort(4)                |    JavaScript(5)             |    Flexibilität(6)           |    einzunehmen(6)            |
# |    selbständige(7)           |                          |    internen(7)               |    Integration(3)            |    Umgang(4)              |    Kenntnisse(5)             |    schätzen(6)               |    denken(6)                 |
# |    Umfassende(0)             |                          |    Klasse(2)                 |    aufweisen(3)              |    gute(4)                |    jQuery(5)                 |    Qualitätsbewusstsein(6)   |    Auffassungsgabe(6)        |
# |    Wirtschaftsinformtik(0)   |                          |    Flexibilität(6)           |    Bereitschaft(3)           |    Englisch(4)            |    werden(3)                 |    sicherer(6)               |    Facharzt(3)               |
# |    mindestens(0)             |                          |    Belastbarkeit(2)          |    I(7)                      |    Erforderlich(4)        |    CISA(5)                   |    Arbeitsweise(6)           |    Entschädigung(6)          |
# |    beziehungsweise(0)        |                          |    Gute(3)                   |    Oriented(3)               |    Erforderlich(4)        |    Queues(3)                 |    betreffend(6)             |    7,5t(2)                   |
# |                              |                          |    sowie(5)                  |    Fenstern(3)               |    Begeisterung(4)        |    fällt(5)                  |    Flexibilität(6)           |    Lehrperson(6)             |
# |    fundierter(7)             |                          |    Grundkenntnisse(2)        |    sowie(3)                  |    Clarity(4)             |    relationalen(5)           |    speditive(2)              |    Kind(0)                   |
# |    Abschluss(0)              |                          |    Geschick(2)               |    Gute(5)                   |    min(4)                 |    JavaScript(5)             |                              |    hohes(2)                  |
# |    Zuverlässigkeit(0)        |                          |    verfügen(7)               |    Berufserfahrung(0)        |    sowie(4)               |    Core(5)                   |    Arbeiten(6)               |    Abrieb(3)                 |
# |    Studium(0)                |                          |    Integration(3)            |    Erfahrungen(7)            |    gute(4)                |    Angular(5)                |    arbeiten(6)               |    Regelsatzverordnung(3)    |
# |    Technischen(0)            |                          |    Arbeitsstil(2)            |    sowie(3)                  |    strukturierte(4)       |    Android-Umfeld(5)         |    Gute(6)                   |    Qualität(2)               |
# |    Elektrotechnik(0)         |                          |    zukunftsweisenden(3)      |    Wünschenswert(5)          |    sowie(4)               |    CSS(5)                    |    Reisebereitschaft(6)      |    m/w/d(1)                  |
# |    m/w/d(0)                  |                          |    Verkauf(3)                |    Problemlagen(7)           |    Englischkenntnisse(4)  |    Datenbanken(5)            |    Freude(6)                 |    Betriebsdienst(2)         |
# |    staatlicher(0)            |                          |    Abwicklung(2)             |    Profi(3)                  |    Englischkenntnisse(4)  |                              |    Arbeitsweise(2)           |    Beratungserfahrung(3)     |
# |    Facharzt/-ärztin(0)       |                          |    Starkes(2)                |    Mindestens(0)             |    sowie(4)               |    Gute(5)                   |    Denken(6)                 |    umwelttechnischen(2)      |
# |    m/w/d(0)                  |                          |    Interesse(3)              |    und/oder(3)               |    Englischkenntnisse(4)  |    Engine(5)                 |    konzentrierte(6)          |    zweiten(2)                |
# |    Fähigkeiten(0)            |                          |    Bereich(7)                |    Kenntnisse(3)             |    sowie(4)               |    Erfahrung(5)              |    Gute(6)                   |    idealerweise(2)           |
# |    fundierter(7)             |                          |    Kat(2)                    |    jQuery(3)                 |    Wort(4)                |    .NET(5)                   |    Reisebereitschaft(6)      |    Erfahrungen(5)            |
# |    sowie(0)                  |                          |    Führungserfahrung(2)      |    Gute(3)                   |    Wort(4)                |    Programmierung(3)         |    kundenorientierte(6)      |    sowie(2)                  |
# |    Psychotherapie(0)         |                          |    Klasse(2)                 |    Entwicklung(3)            |    Wort(4)                |    sowie(7)                  |    Arbeitsweise(6)           |    Denkvermögen(6)           |
# |    Wirtschaftsinformatik(0)  |                          |    neuer(2)                  |    Stammdatenverwaltung(3)   |    Clarity(4)             |    Java-Ökosys-​(5)           |    Flexibilität(6)           |    sowie(6)                  |
# |    Mathematik(0)             |                          |    kaufmännisches(6)         |    PHP(7)                    |    Wort(4)                |    CANoe(7)                  |                              |    Mehrjährige(0)            |
# |    Statistik(0)              |                          |    Zwingend(6)               |    Kreativität(5)            |    runden(4)              |    Erfahrung(5)              |                              |    Verkaufen(2)              |
# |    Medizintechnik(0)         |                          |    Führerausweis(7)          |    sowie(3)                  |    Wort(4)                |    Linux(2)                  |    Denkvermögen(6)           |    Wort(4)                   |
# |    m/w/d(0)                  |                          |    Deutsch(6)                |    Vorteil(5)                |    sind(4)                |    wünschenswert(5)          |    Fähigkeit(6)              |    Denken(6)                 |
# |    Medieninformatik(0)       |                          |    komplexer(2)              |    Kompetenzen(1)            |    Fähigkeiten(4)         |    sind(5)                   |    Arbeitsweise(6)           |    Führerscheine(6)          |
# |                              |                          |    zeitweilige(2)            |    Praktische(3)             |    Sprache(4)             |    GIT(5)                    |    Flexibilität(6)           |    Erste(0)                  |
# |    Gerüstbauer(7)            |                          |    Kenntnisse(2)             |    Equity(3)                 |    Strukturierte(4)       |    iOS(3)                    |    Wünschenswert(6)          |    operativen(3)             |
# |    Bereich(0)                |                          |    mehrschichtiger(2)        |    Lösungen(7)               |    Clarity(4)             |    Architekt(3)              |    Reisebereitschaft(6)      |    explizit(3)               |
# |    Erste(7)                  |                          |    Sehr(2)                   |    Hervorragende(3)          |    gute(4)                |    Indesign(5)               |    Entscheidungsfreude(6)    |    Kat(2)                    |
# |                              |                          |    helfen(7)                 |    haben(3)                  |    sind(5)                |    Gutes(5)                  |    systematische(6)          |    sowie(4)                  |
# |    aktuellen(7)              |                          |    B(2)                      |    Erfahrungen(7)            |    Wort(4)                |    Income(7)                 |    Auftreten(6)              |    im(2)                     |
# |    Berufsausbildung(3)       |                          |    Gültiger(7)               |    Fenstern(2)               |    Englisch(4)            |    AutoCAD(5)                |    Herstellung(6)            |    Leidenschaft(2)           |
# |    Natur(0)                  |                          |    B(2)                      |    iOS(3)                    |    Vertrauensvolle(4)     |    React(5)                  |                              |    Montieren(6)              |
# |    Fundierte(7)              |                          |    Erfahrung(2)              |    Zudem(3)                  |    sowie(4)               |    wünschenswert(5)          |    schnell(6)                |    132(3)                    |
# |    verwandten(0)             |                          |    Veränderungen(2)          |    Leidenschaft(3)           |    Zielorientierte(4)     |    Javascript(5)             |    Flexibilität(6)           |    Überdurchschnittliche(3)  |
# |    Mechatronik(0)            |                          |    Offene(2)                 |    Analytisches(3)           |    sowie(4)               |    C(5)                      |    belastbar(6)              |    Denkvermögen(6)           |
# |    Kräftige(7)               |                          |    Klasse(2)                 |                              |    Handwerkliches(4)      |    Verhandlungssichere(5)    |    Flexibilität(6)           |    Starkes(3)                |
# |    vergleichbare(0)          |                          |    Lernbereitschaft(2)       |    Softwareentwicklung(3)    |    Wort(4)                |    Notes(5)                  |    analytisches(6)           |    können(1)                 |
# |    CNC-Fräser(1)             |                          |    Handeln(6)                |    Kandidaten(7)             |    Clarity(4)             |    JavaScript/TypeScript(5)  |    systematische(6)          |    Fähigkeit(3)              |
# |    BTA(0)                    |                          |    Kompetenzen(7)            |    Learning(7)               |    Wort(7)                |    CAD(3)                    |    hohen(6)                  |    andere(6)                 |
# |    vergleichbare(0)          |                          |    erforderlich(2)           |    Gutes(3)                  |    Englischkenntnisse(4)  |    Gitflow(5)                |    Flexibilität(6)           |    Programming(3)            |
# |                              |                          |    sowie(2)                  |    Kraftmaschinenbau(3)      |    Englischkenntnisse(4)  |    Puppet(5)                 |    Arbeitsweise(6)           |    Steuerungen(3)            |
# |    Idealerweise(0)           |                          |    Montagebereitschaft(2)    |    Türen(3)                  |    bringst(4)             |    CSS3(5)                   |    Eigenverantwortliche(6)   |    Auffassungsgabe(6)        |
# |                              |                          |    Klasse(2)                 |    Maschinen(5)              |    sowie(4)               |    IDEA(5)                   |    organisatorische(6)       |    sprichst(3)               |
# |    Software(0)               |                          |    Kenntnisse(2)             |    Kopplung(7)               |    Wort(4)                |    relationalen(5)           |    Arbeitsstil(6)            |    Webportalen(3)            |
# |    Berufsausbildung(0)       |                          |    Organisationsgeschick(2)  |    sind(3)                   |    gute(4)                |    Framework(5)              |    Kundenorientierung(6)     |    Client-Server-Umfeld(3)   |
# |    sowie(0)                  |                          |    Konstellation(2)          |    TFS(3)                    |    Uneingeschränkte(4)    |    XSLT(5)                   |    Wünschenswert(6)          |    logische(6)               |
# |    abgeschlossen(0)          |                          |    arbeiten(2)               |    wären(3)                  |    sowie(4)               |    Office(2)                 |    Auftreten(2)              |    Zusammenhänge(6)          |
# |    Ausbildung(0)             |                          |    Überzeugendes(5)          |    Perfetti(3)               |                           |    speziell(2)               |    Flexibilität(6)           |    sowie(2)                  |
# ...
# |                              |                          |                              |    sowie(7)                  |                           |                              |    teamorientiertes(6)       |                              |
# |                              |                          |                              |    gute(5)                   |                           |                              |    Persönlichkeit(6)         |                              |
# |                              |                          |                              |    besitzt(3)                |                           |                              |    Empathie(6)               |                              |
# |                              |                          |                              |    Engineer(3)               |                           |                              |    Teamfaehigkeit(2)         |                              |
# |                              |                          |                              |    Steuerungstechnik(3)      |                           |                              |    runden(6)                 |                              |
# |                              |                          |                              |    JavaScript(3)             |                           |                              |    hohen(6)                  |                              |
# |                              |                          |                              |    sowie(3)                  |                           |                              |    Ergebnisorientierter(7)   |                              |
# |                              |                          |                              |    Beratungsumfeld(7)        |                           |                              |    bist(6)                   |                              |
# |                              |                          |                              |    Neben(3)                  |                           |                              |                              |                              |
# |                              |                          |                              |    Code(3)                   |                           |                              |                              |                              |
# |                              |                          |                              |    mitbringen(2)             |                           |                              |    Denkansatz(6)             |                              |
# |                              |                          |                              |    SQL(5)                    |                           |                              |    kommunikative(2)          |                              |
# |                              |                          |                              |    Vorteil(3)                |                           |                              |                              |                              |
# |                              |                          |                              |    IAM(3)                    |                           |                              |                              |                              |
# |                              |                          |                              |    Türen(3)                  |                           |                              |                              |                              |
# |                              |                          |                              |    Metall(2)                 |                           |                              |                              |                              |
# |                              |                          |                              |    Websites(3)               |                           |                              |                              |                              |
# |                              |                          |                              |    sowie(3)                  |                           |                              |                              |                              |
# |                              |                          |                              |    etc(3)                    |                           |                              |                              |                              |
# |                              |                          |                              |    XML(7)                    |                           |                              |                              |                              |
# |                              |                          |                              |    skalierbaren(7)           |                           |                              |                              |                              |
# |                              |                          |                              |    Fremdbegriff(3)           |                           |                              |                              |                              |
# |                              |                          |                              |    Praktische(3)             |                           |                              |                              |                              |
# |                              |                          |                              |    Kenntnisse(3)             |                           |                              |                              |                              |
# |                              |                          |                              |    Sicherer(3)               |                           |                              |                              |                              |
# |                              |                          |                              |    Kommunikationsdesign(0)   |                           |                              |                              |                              |
# |                              |                          |                              |    Montage(3)                |                           |                              |                              |                              |
# |                              |                          |                              |    gerne(3)                  |                           |                              |                              |                              |
# |                              |                          |                              |    Hohe(7)                   |                           |                              |                              |                              |
# |                              |                          |                              |    Management(2)             |                           |                              |                              |                              |
# |                              |                          |                              |    Security(7)               |                           |                              |                              |                              |
# |                              |                          |                              |    Programmierung(3)         |                           |                              |                              |                              |
# |                              |                          |                              |    Erfahrung(5)              |                           |                              |                              |                              |
# |                              |                          |                              |    Erfahrung(5)              |                           |                              |                              |                              |
# |                              |                          |                              |    Netzwerk(3)               |                           |                              |                              |                              |
# |                              |                          |                              |    erkennen(3)               |                           |                              |                              |                              |
# |                              |                          |                              |    Betreuung(3)              |                           |                              |                              |                              |
# |                              |                          |                              |    etc(3)                    |                           |                              |                              |                              |
# |                              |                          |                              |    Beispiel(3)               |                           |                              |                              |                              |
# |                              |                          |                              |    Know-how(3)               |                           |                              |                              |                              |
# |                              |                          |                              |    Persönliche(3)            |                           |                              |                              |                              |
# |                              |                          |                              |    ERP-Systemen(3)           |                           |                              |                              |                              |
# |                              |                          |                              |    routinierte(3)            |                           |                              |                              |                              |
# |                              |                          |                              |    Produkte(3)               |                           |                              |                              |                              |
# |                              |                          |                              |    absolut(3)                |                           |                              |                              |                              |
# |                              |                          |                              |    Entladen(7)               |                           |                              |                              |                              |
# |                              |                          |                              |    Automobilbranche(2)       |                           |                              |                              |                              |
# |                              |                          |                              |    Zuverlässige(3)           |                           |                              |                              |                              |
# |                              |                          |                              |    Vorteil(3)                |                           |                              |                              |                              |
# |                              |                          |                              |    Services(7)               |                           |                              |                              |                              |
# |                              |                          |                              |    Elektrotechnik(3)         |                           |                              |                              |                              |
# |                              |                          |                              |    Gute(3)                   |                           |                              |                              |                              |
# |                              |                          |                              |    haben(3)                  |                           |                              |                              |                              |
# |                              |                          |                              |    Betreuung(3)              |                           |                              |                              |                              |
# |                              |                          |                              |    sowie(3)                  |                           |                              |                              |                              |
# |                              |                          |                              |                              |                           |                              |                              |                              |
# |                              |                          |                              |    sind(3)                   |                           |                              |                              |                              |
# |                              |                          |                              |    Zeitliche(3)              |                           |                              |                              |                              |
# |                              |                          |                              |    Transport(3)              |                           |                              |                              |                              |
# |                              |                          |                              |    Fundierte(7)              |                           |                              |                              |                              |
# |                              |                          |                              |    umfassenden(3)            |                           |                              |                              |                              |
# |                              |                          |                              |    Clean(7)                  |                           |                              |                              |                              |
# |                              |                          |                              |    gutes(2)                  |                           |                              |                              |                              |
# |                              |                          |                              |    Backend(3)                |                           |                              |                              |                              |
# |                              |                          |                              |    Tests(3)                  |                           |                              |                              |                              |
