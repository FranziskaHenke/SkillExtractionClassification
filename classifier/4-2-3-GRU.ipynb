# %%
import sys
import os
sys.path.append('/home/franzi/anzeigendaten/python_base/skillextraktion/fh_ma')
sys.path.append('/home/franzi/anzeigendaten/EnvPython')
import prepare_training_data
from labels import *
import time
import warnings
warnings.filterwarnings('ignore')

from sklearn.utils import shuffle
import numpy as np
np.set_printoptions(precision=3)
# %precision 3
start = time.time()
x_train, y_train, x_test, y_test, test_afks, features = prepare_training_data.get_training_data()
print('took: ',time.time()-start)
# Out:
# 20861874
# 0
# skipgram, punctuation_marks, stoppwords, multiword, lower_case, vector_dim True False False False False 100
# init /home/franzi/Documents/models/no_pm_no_sw_vecDim100/skip_gram_model.model
# loading existing w2v model from  /home/franzi/Documents/models/no_pm_no_sw_vecDim100/skip_gram_model.model
# using data from  /home/franzi/Documents/data/data_4_vecDim100
# loading data...
# 37823 37823 12053 12053 0 0
# took:  3.490993022918701

# %%
import numpy as np
label_y = prepare_training_data.one_hot_to_labels(y_train)

# %%
from tensorflow.keras import *

# %%
# Build the model
print('Build model...')
model = Sequential()
model.add(layers.GRU(256, return_sequences=True, input_shape=(x_train.shape[1],x_train.shape[2])))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.GRU(512, return_sequences=True))
model.add(layers.Dropout(0.5))
model.add(layers.BatchNormalization())
model.add(layers.GRU(256))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256))
model.add(layers.Dense(units=len(labels)))
model.add(layers.Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

batch_size=64
history = model.fit(x_train, y_train, batch_size=batch_size, shuffle=True, epochs=5, validation_data=(x_test, y_test))
# Out:
# 2020-08-10 09:45:56 WARNING: From /home/franzi/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Build model...
# Train on 37823 samples, validate on 12053 samples
# 2020-08-10 09:45:57 WARNING: From /home/franzi/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/5
# 37823/37823 [==============================] - 130s 3ms/sample - loss: 0.8004 - acc: 0.7165 - val_loss: 0.6503 - val_acc: 0.7796
# Epoch 2/5
# 37823/37823 [==============================] - 127s 3ms/sample - loss: 0.5469 - acc: 0.8102 - val_loss: 0.5506 - val_acc: 0.8060
# Epoch 3/5
# 37823/37823 [==============================] - 132s 3ms/sample - loss: 0.4757 - acc: 0.8362 - val_loss: 0.4777 - val_acc: 0.8365
# Epoch 4/5
# 37823/37823 [==============================] - 134s 4ms/sample - loss: 0.4402 - acc: 0.8486 - val_loss: 0.4599 - val_acc: 0.8444
# Epoch 5/5
# 37823/37823 [==============================] - 133s 4ms/sample - loss: 0.4130 - acc: 0.8564 - val_loss: 0.5067 - val_acc: 0.8326

# %%
from matplotlib import pyplot as plt
plt.plot(np.arange(1, len(history.history['acc'])+1), history.history['acc'])
plt.plot(np.arange(1, len(history.history['acc'])+1), history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim(0,1)
plt.xticks(np.arange(1, len(history.history['acc'])+1))
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# predict test data
y_pred = model.predict(x_test)

# %%
import numpy as np
# convert one hot to labels for test data
pred_label = prepare_training_data.one_hot_to_labels(y_pred)
true_label = prepare_training_data.one_hot_to_labels(y_test)

# %%
# Calc metrics for test data
import sklearn
from sklearn.metrics import precision_score, recall_score
from tabulate import tabulate
label_list = list(labels.keys())

headers = [l for l in label_list ]
headers = [' '] + headers

table=[['precision'] + list(precision_score(true_label, pred_label, average=None)), 
       ['recall']+list(recall_score(true_label, pred_label, average=None)), 
       ['f1']+ list(sklearn.metrics.f1_score(true_label, pred_label, average=None))]

print(tabulate(table, headers=headers, tablefmt='orgtbl'))
f1 = sklearn.metrics.f1_score(true_label, pred_label, average=None)
f1 = np.delete(f1, 4)
f1 = np.delete(f1, 6)
print('f1 average: ',sum(sklearn.metrics.f1_score(true_label, pred_label, average=None))/len(list(precision_score(true_label, pred_label, average=None))))
print('f1 average: ',sum(f1)/6)
print('Precision average: ',sum(precision_score(true_label, pred_label, average=None)/8))
print('recall average: ',sum(recall_score(true_label, pred_label, average=None)/8))
print('acc', sklearn.metrics.accuracy_score(true_label, pred_label))
# Out:
# |           |   Ausbildung |    Beruf |   allgemein |   berufsspez |   Sprache |   Technologie |   Softskill |   noSkill |
# |-----------+--------------+----------+-------------+--------------+-----------+---------------+-------------+-----------|
# | precision |     0.664994 | 0.206897 |    0.454128 |     0.662821 |  0.897119 |      0.717213 |    0.748457 |  0.939751 |
# | recall    |     0.960145 | 0.28125  |    0.41655  |     0.483178 |  0.986425 |      0.903226 |    0.90065  |  0.895001 |
# | f1        |     0.785767 | 0.238411 |    0.434528 |     0.558919 |  0.939655 |      0.799543 |    0.817531 |  0.91683  |
# f1 average:  0.6863979625494062
# f1 average:  0.6057830973431249
# Precision average:  0.6614223962935023
# recall average:  0.7283030057734348
# acc 0.8325728034514229

# %%
# Create Confusion Matrix

import sklearn
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

cm = sklearn.metrics.confusion_matrix(true_label, pred_label)
df_cm = pd.DataFrame(cm, labels,columns = labels)
plt.figure(figsize = (10,7))
plt.ylabel('Eingabe')
plt.xlabel('Ausgabe')
sn.heatmap(df_cm, annot=True,fmt='g')

# %%
# clean noSkill for evaluation
clean_y_pred = []
clean_y_test = []
true_noSkills = 0
clean_x_test = []
afks = []

for i in range(len(y_test)):
    if(true_label[i] != 7 or pred_label[i] != 7):
        clean_x_test.append(x_test[i])
        clean_y_pred.append(pred_label[i])
        clean_y_test.append(true_label[i])
        afks.append(test_afks[i])
    else:
        true_noSkills += 1
pred_label = clean_y_pred
true_label = clean_y_test
print('correctly labeled noSkills: ', true_noSkills)
# Out:
# correctly labeled noSkills:  6785

# %%
# Create Confusion Matrix

import sklearn
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

cm = sklearn.metrics.confusion_matrix(true_label, pred_label)
df_cm = pd.DataFrame(cm, labels,columns = labels)
plt.figure(figsize = (10,7))
plt.ylabel('Eingabe')
plt.xlabel('Ausgabe')
sn.heatmap(df_cm, annot=True,fmt='g')

# %%
from word2vec import W2V#get_closest_word_to_vec_matrix
correct = []
false = []

clean_x_test, pred_label, true_label, afks = shuffle(clean_x_test, pred_label, true_label, afks,random_state=0)
skill_index = int(len(clean_x_test[0])/2)
label_list = list(labels.keys())

# %%
headers = [['|']+[l] for l in label_list ]
headers = sum(headers, [])
headers.append('|')

wvs = []
for i in range(len(clean_x_test)):
    wvs.append(clean_x_test[i][skill_index])

w2v = W2V(skipgram=True, punctuation_marks=False, stoppwords=False, multiword=False, lower_case=False, vector_dim=100)
    

predictions = [[],[],[],[],[],[],[], []]
for i in range(len(clean_x_test)):
    word = w2v.get_closest_word_to_vec(wvs[i])[0][0]
    label = str(true_label[i])
    predictions[pred_label[i]].append(word + '('+label+')')

table = []
# format
i = 0
while(i < len(predictions[0]) or i < len(predictions[1]) or i < len(predictions[2]) or i < len(predictions[3]) or i < len(predictions[4]) or i < len(predictions[5] or i < len(predictions[6]))):
    row = ['|']
    for x in predictions:
        if(len(x) > i and len(x[i]) <  25): 
            row.append(x[i])
            row.append('|')
        else:
            row.append('')
            row.append('|')
            
    table.append(row)
    i+=1    

print(tabulate(table, headers=headers))
# Out:
# skipgram, punctuation_marks, stoppwords, multiword, lower_case, vector_dim True False False False False 100
# init /home/franzi/Documents/models/no_pm_no_sw_vecDim100/skip_gram_model.model
# loading existing w2v model from  /home/franzi/Documents/models/no_pm_no_sw_vecDim100/skip_gram_model.model
# |    Ausbildung                |    Beruf                     |    allgemein                 |    berufsspez                |    Sprache                   |    Technologie               |    Softskill                 |    noSkill                   |
# ---  ------------------------  ---  ------------------------  ---  ------------------------  ---  ------------------------  ---  ------------------------  ---  ------------------------  ---  ------------------------  ---  ------------------------  ---
# |    Elektrotechnik(0)         |    Sekretariats(3)           |    zeitweilige(7)            |    Erziehung(3)              |    Deutschkenntnisse(4)      |                              |    Organisationsvermögen(6)  |    Lehrperson(1)             |
# |    Bankwesen(7)              |    Rechnungswesen(3)         |    polizeiliches(7)          |    Maschinen(3)              |    Deutsch(4)                |    API’s(5)                  |    Belastbarkeit(6)          |    Produktentwicklung(2)     |
# |    §66(7)                    |    Versicherungen(3)         |    Denken(7)                 |    Programmiersprache(3)     |    deutsche(4)               |    Bootstrap(5)              |    zielorientierte(6)        |    kommunikationsstarker(6)  |
# |    Medizin(0)                |    IT-Beratung(3)            |    Montieren(3)              |    mechatronische(2)         |    Deutschkenntnisse(4)      |    .NET(5)                   |    kundenorientiertes(2)     |    strukturierte(6)          |
# |    Facharzt(0)               |    Lagerbereich(3)           |    Montagebereitschaft(2)    |    Systeme(7)                |    Deutschkenntnisse(4)      |    JavaScript(5)             |    Engagement(7)             |    Störungsbilder(3)         |
# |    Psychologie(0)            |    Web-Entwicklung(3)        |    Fahrerkarte(7)            |    Buchhaltung(3)            |    Deutschkenntnisse(4)      |    JavaScript-Framework(3)   |    Kreativität(6)            |    Tüftler-Gen(3)            |
# |    IT(0)                     |    Gründer(1)                |    Dokumentation(2)          |    Fenstern(3)               |    Deutsch(4)                |    Game(7)                   |    Belastbarkeit(6)          |    Pünktlichkeit(2)          |
# |    HwO(7)                    |    Automation(3)             |    Lebensmittelbereich(3)    |    INHALT(3)                 |    mündlich(7)               |    Programmiersprachen(3)    |    Detail(2)                 |    Sensibilität(6)           |
# |    Physik(0)                 |    Baustellenverkehr(7)      |    Planungs(2)               |    Softwarearchitektur(7)    |    deutsche(4)               |                              |    kundenorientierte(2)      |    Untersuchungen(2)         |
# |    Fachärztin(7)             |    Backend-Entwicklung(3)    |    Technisches(7)            |    IT-Technologien(3)        |    Deutschkenntnisse(4)      |    DevOps(5)                 |    Kommunikationsstärke(6)   |    Inhouse-Recruiting(3)     |
# |    Köchin(7)                 |    Fahrer(1)                 |    priorisieren(7)           |    Beschaffungen(7)          |    Aufgabe(7)                |    Connector(1)              |    Denkweise(7)              |    Prozessverständnis(2)     |
# |    Wirtschaftsinformatik(0)  |                              |    Reisebereitschaft(2)      |    Fenstern(3)               |    Deutschkenntnisse(4)      |    Foundry(5)                |    Offene(6)                 |    Betreuung(3)              |
# |    Elektroinstallateur(0)    |    Handel(3)                 |    Kunden(2)                 |    IFRS(3)                   |    Italienisch(4)            |    Internet-Technologien(3)  |    respektvoller(6)          |    Technischen(3)            |
# |    CTA(0)                    |    Gipser(1)                 |    Fahrerlaubnis(2)          |    Software-Entwicklung(3)   |    Englischkenntnisse(4)     |    XHTML(5)                  |    Belastbarkeit(6)          |    Ware(3)                   |
# |    Baubranche(0)             |    Vertriebspartner(7)       |    Kundenorientierung(2)     |                              |    Französisch(4)            |    PHP(5)                    |    Flexibilität(6)           |    Fahrerlaubnis(3)          |
# |    Ökotrophologie(0)         |    Softwareentwicklung(3)    |    Denken(7)                 |    Code(3)                   |    Deutschkenntnisse(4)      |    Engine(7)                 |    Zuverlässig(7)            |    ethische(3)               |
# |    Handwerkliche(2)          |    Gipser(1)                 |    Betreuung(3)              |    Kandidaten(7)             |    Deutschkenntnisse(4)      |    Betrieb:D+S(3)            |    Zielorientierung(6)       |                              |
# |    kaufmännische(0)          |    Frontend(3)               |    Java-Projekten(3)         |    Active(3)                 |    Englischkenntnisse(4)     |    Software-Konzipierung(3)  |    planvoller(6)             |    Detailgenauigkeit(2)      |
# |    kaufmännische(0)          |    Controlling(1)            |    Schichtbetrieb(2)         |    Behandlungsformen(3)      |    Gültige(7)                |    Javascript(5)             |    kommunikative(6)          |    Bereitschaft(2)           |
# |    Psychotraumatherapie(3)   |    Gipser(1)                 |    Schicht-Bereitschaft(2)   |    HR-Projekt(3)             |    Englischkenntnisse(4)     |    Objektorientiertem(3)     |    Kommunikationstalent(6)   |    Erstellung(2)             |
# |    Anwendungsentwicklung(3)  |    \ue002chrift(3)           |    erweitertes(7)            |    Auftrags(7)               |    Englischkenntnisse(4)     |    Office-Kenntnisse(5)      |    Engagement(6)             |                              |
# |    verwandter(7)             |    Maschinenführer(1)        |    Veranstaltungtechnik(3)   |    verschiedener(7)          |    Deutsch(4)                |    JIRA(5)                   |    Selbstorganisation(6)     |    AGILE(2)                  |
# |    Werkstoff-(0)             |    BCM-Prozessen(3)          |    Lebensmittelbereich(3)    |    Software(3)               |    Deutschkenntnisse(4)      |    AutoCAD(5)                |    Belastbarkeit(6)          |    eingeschränkten(3)        |
# |    handwerklichen(2)         |    Mietenbuchhaltung(1)      |    psychologischen(2)        |    Dinge(5)                  |    Deutschkenntnisse(4)      |    CSS(5)                    |                              |    professioneller(6)        |
# |    Systemintegration(0)      |    Softwareentwicklung(3)    |    Kundenkontakt(2)          |    Active(3)                 |    englische(4)              |    Omada(5)                  |    Teamfähigkeit(6)          |    Reflexionsvermögen(6)     |
# |    Frästechnik(3)            |    Bauhandwerk(3)            |    PKW(2)                    |    mit…(7)                   |    fliessend(7)              |    Tower(5)                  |    Engagement(6)             |    Engineer(1)               |
# |    Kommunikationsdesign(0)   |                              |    Mercedes-Benz(7)          |    Apps(3)                   |    Deutsch(4)                |    ABAP(7)                   |    lösungsorientierte(2)     |    Kenntnisse(2)             |
# |    Informatik(0)             |    en(7)                     |    Denken(2)                 |    Datenbanken(7)            |    Englischkenntnisse(4)     |    dSPACE(5)                 |    selbständig(6)            |    Vollblutpädagoge(2)       |
# |    ADR(2)                    |    Gipser(1)                 |    Java-Projekten(3)         |    Qualitätskontrolle(2)     |    Englischkenntnisse(4)     |    IBM(5)                    |    Kreativität(6)            |    Wertschätzung(6)          |
# |    Verkehrspsychologie(0)    |    Stapler(3)                |    Affinität(3)              |    Kapitalmärkte(3)          |    Deutschkenntnisse(4)      |    Java(5)                   |    Umgangsformen(7)          |    Gesetze(3)                |
# |    Einzelfeld(5)             |    Controlling(3)            |    Schichtarbeit(2)          |    Küche(3)                  |    Deutschkenntnisse(4)      |    Object(3)                 |    Auffassungsgabe(6)        |    Approbation(3)            |
# |    Elektronik(0)             |                              |    PC(2)                     |    User(3)                   |    Englischkenntnisse(4)     |    GIT(5)                    |    Ausgeprägte(7)            |    Mitarbeiter(2)            |
# |    Software(0)               |                              |    Java-Projekten(7)         |    Metall(3)                 |    Englischkenntnisse(4)     |    C#(5)                     |    körperlicher(2)           |    Elektro(3)                |
# |    AbsolventIn(7)            |    Automation(3)             |    Kunden(2)                 |    Datenbanken(3)            |    Deutschkenntnisse(4)      |    MAS(5)                    |    Flexibilität(6)           |    Planung(2)                |
# |    Kältetechnik(3)           |    Gastronomie(2)            |    Feiertagen(2)             |    Arbeitsvermittlung(3)     |    Deutsch(4)                |    Git(5)                    |    Handlungsweise(7)         |    Überwachung(2)            |
# |    Gerüstbauer(0)            |    Akutbereich(3)            |    prozessorientierten(7)    |    IAM(3)                    |    Englischkenntnisse(4)     |    Python(5)                 |    Flexibilität(7)           |    effizient(6)              |
# |    Kommunikationstechnik(0)  |    filialisierten(3)         |    technisches(3)            |    technologischen(7)        |    Deutschkenntnisse(4)      |    PHP(5)                    |    Teamfähigkeit(6)          |    ISPS-Codes(2)             |
# |    Beikoch(0)                |    Healthcarebereich(3)      |    Denkvermögen(7)           |    objektorientierten(5)     |    Englischkenntnisse(4)     |    Programmierkenntnisse(3)  |    Motivation(6)             |    technisches(2)            |
# |    Digi-tale(3)              |    ePowerTrain(3)            |    Beratungsumfeld(3)        |    automatisierter(3)        |    Englischkenntnisse(4)     |    ServiceNow(5)             |    betreffend(7)             |    Modellierung(2)           |
# |    Erzieher(0)               |    Versicherungen(3)         |    Klasse(7)                 |    Brötchen(7)               |    Englischkenntnisse(4)     |    Office-Paket(5)           |    Freundliches(6)           |    Ausdauer(6)               |
# |    Messtechnik(3)            |    Softwareentwickler(1)     |    Kunden(2)                 |    IT-Systeme(3)             |    Englischkenntnisse(4)     |    Ranorex(5)                |    ergebnisorientierte(2)    |    werkzeuge(2)              |
# |    Wirtschafts(0)            |    Finanzbuchhaltung(3)      |    spezifischen(7)           |    Anlagenbau(3)             |    Deutsch(4)                |    C#(5)                     |    Einsatzbereitschaft(2)    |    Formular(3)               |
# |    Psychosom(0)              |    in(7)                     |    Teilhabe(7)               |    VIII(7)                   |    Englischkenntnisse(4)     |    Javascript(5)             |    Eigeninitiative(6)        |    Führungsmethoden(2)       |
# |    Umweltplanung(0)          |    Einzelhandel(3)           |    Konzeptionsstärke(7)      |    automatischer(7)          |    Englischkenntnisse(4)     |    UI(5)                     |    Team(6)                   |                              |
# |    Koordination(2)           |    Untendrehern(3)           |    Handeln(7)                |    Unternehmensbewertung(3)  |    Englischkenntnisse(4)     |    basierte(7)               |    teamfähige(6)             |    strukturierter(2)         |
# |    Informatik(0)             |    agilen(3)                 |    operativen(2)             |    Responsive(3)             |    Deutschkenntnisse(4)      |    Sass(5)                   |    Flexibilität(6)           |    Team(6)                   |
# |    Informatik(0)             |    agiler(2)                 |    Handeln(7)                |    Betreuungsrecht(3)        |    Deutschkenntnisse(4)      |    Learning(5)               |    Bewusstsein(7)            |    industriellen(3)          |
# |    Design(0)                 |    Frontend(3)               |    agilen(2)                 |    Personalberatung(3)       |    Deutschkenntnisse(4)      |    Programming(3)            |    Zeitliche(7)              |    parkts(1)                 |
# |    HTL-Ausbildung(7)         |                              |    lösungsorientiertes(6)    |    Transport(2)              |    Englischkenntnisse(4)     |    C#(5)                     |    Analytisches(2)           |    Netzwerke(3)              |
# |    Psychiatrie(3)            |    Teststrategien(3)         |    VKR-Schweissprüfung(7)    |    Fenstern(3)               |    Dialekt(7)                |    JavaScript-Framework(5)   |    selbständige(6)           |    physikalisches(3)         |
# |    Staplerschein(3)          |    Finanzbranche(7)          |    per(7)                    |    IT-Security(3)            |    Deutschkenntnisse(4)      |    Git(5)                    |    teamorientierten(6)       |    professionelle(6)         |
# |    Medizin(0)                |    Gastronomie(3)            |    Fahrzeug(7)               |    Sozialrecht(3)            |                              |    Medieninformatik(3)       |    eigeninitiatives(6)       |    Fachfrau(0)               |
# |    Facharzt(1)               |    Frontend(3)               |    Kunden(2)                 |    Trockenbau(3)             |    Italienische(4)           |    HTML(5)                   |    Kommunikationsstärke(6)   |    Neues(6)                  |
# |    technischer(0)            |                              |    körperliche(7)            |    Softwareentwicklung(3)    |    Deutsch(4)                |    SAP(5)                    |    Teamfähigkeit(6)          |    wirtschaftlichem(0)       |
# |    Lagerbereich(0)           |    Entwickler(1)             |    Leitungsposition(2)       |    Datenbanken(5)            |    Englischkenntnisse(4)     |    Arriba(5)                 |                              |    Pflege(3)                 |
# |    Tech(7)                   |    Frontend(3)               |    Denken(2)                 |    Public(3)                 |    Deutsch(4)                |    Ruby(5)                   |    strukturierten(6)         |    Technologien(3)           |
# |    Psychiatrie(0)            |    Empfangsdienst(3)         |    Reisebereitschaft(2)      |    umwelttechnischen(3)      |    Deutsch(4)                |    JavaScript(5)             |    flexibel(6)               |    Einbauschränken(3)        |
# |    Psychotraumatherapie(3)   |    Hauswirtschaftliche(3)    |    Kunden(7)                 |                              |    Deutschkenntnisse(4)      |    Git(5)                    |    Motivation(6)             |                              |
# |    Informatik(0)             |    Gastronomie(1)            |    Montagebereitschaft(2)    |    SUVA(7)                   |    Deutschkenntnisse(4)      |    Docker(5)                 |    Stressresistenz(6)        |    Studium(0)                |
# |    Gesundheits(0)            |    gesuchten(7)              |    Wochenendarbeit(2)        |    Lesen(2)                  |    Englischkenntnisse(4)     |    HTML(5)                   |    selbstständige(6)         |    sozialer(2)               |
# |    Schwergewicht(7)          |    Gastronomie(3)            |    Denken(7)                 |    Zeichnungen(3)            |    Englisch(4)               |    Linux(5)                  |    strategisches(6)          |    Pharmareferenten(0)       |
# |    Elektrotechnik(0)         |    3-Schicht(2)              |    Technische(3)             |    Datenbanken(3)            |    Deutsch(4)                |    Studio(5)                 |    lösungsorientiertes(2)    |    turienten(0)              |
# |    Lebensmittelhandwerk(0)   |    Einesolide(3)             |    Montagebereitschaft(7)    |    Fördermittelgebern(3)     |    Deutschkenntnisse(4)      |    Java(5)                   |    Team(6)                   |    arbeitsagogischen(3)      |
# |    technische(0)             |    Rechtschreibsicher(2)     |    Führerscheine(2)          |    Heizungsanlagen(3)        |    Englischkenntnisse(4)     |    Regular(5)                |    Überlegtes(6)             |    Testing-Tools(3)          |
# |    Koch(0)                   |    Gipser(1)                 |    Beratungsumfeld(3)        |    Programmierung(3)         |    deutschen(4)              |    CENELEC(5)                |    Zuverlässigkeit(6)        |    Risikobewusstsein(6)      |
# |    Elektrotechnik(0)         |    Gefahrenmeldetechnik(3)   |    körperliche(2)            |    objektorientierter(3)     |    Englischkenntnisse(4)     |    Keras(5)                  |    Selbständigkeit(6)        |    Entwicklungen(2)          |
# |    Informatik(0)             |    Lagerlogistik(3)          |    Staplerschein(3)          |    Staplerschein(3)          |    Englischkenntnisse(4)     |    OOP(5)                    |    strukturiert(6)           |    Systemen(3)               |
# |    Informationstechnik(0)    |    Frontend(3)               |    VKR-Schweissprüfung(2)    |    Wartung(2)                |    Englischkenntnisse(4)     |    UiPath(5)                 |                              |    Produkte(3)               |
# |    Nebenfach(7)              |    Frontend(3)               |    Testen(2)                 |    relationalen(7)           |    englischer(4)             |    Programming(3)            |    zeitliche(7)              |    flexiblen(6)              |
# |    Leitung(2)                |    Softwareentwicklung(3)    |    Schichtdienst(2)          |    Derivaten(3)              |    Englischkenntnisse(4)     |                              |    Teamfähigkeit(6)          |    psychische(3)             |
# |    Psychiatrie(0)            |    Entwickler(1)             |    Software(7)               |    Lieferanten(7)            |    Englisch(4)               |    System-Kenntnisse(2)      |    engagierte(6)             |    Einbauschränken(3)        |
# |    Informatik(0)             |    Anwendungsentwicklung(3)  |    Abstim-mungsgespräche(7)  |    Gesundheitswesen(3)       |    englischen(4)             |    Jenkins(5)                |    Zuverlässigkeit(6)        |    interdisziplinäres(6)     |
# |    Technikerausbildung(0)    |                              |    gültiger(7)               |    Planungs(2)               |    französisch(4)            |    Cross(3)                  |    Handwerklich(2)           |    dokumentieren(2)          |
# |                              |    Programmierung(3)         |    Affinität(7)              |    Datenbanken(3)            |    Deutschkenntnisse(4)      |    PC-Anwendungen(2)         |    mathematische(2)          |    Anleitung(2)              |
# |    zielführen-des(0)         |    Test(2)                   |    Instrumenten(7)           |    Mobile(3)                 |    Englischkenntnisse(4)     |    Microsoft(5)              |    rasche(6)                 |    komplexe(2)               |
# |    Informatiker(0)           |    Serviceberater(1)         |    Frühschicht(2)            |    Programmiersprache(3)     |    Deutsch(4)                |    React(5)                  |    kommunikative(6)          |    Weiterentwicklung(2)      |
# |    Küche(7)                  |    Requirements(3)           |    Software(2)               |    SDS-PAGE(5)               |    Hochdeutsch(4)            |    Boot(7)                   |    Selbstständige(6)         |    entladen(2)               |
# |    technischen(0)            |    familienergänzenden(7)    |    Kunden(2)                 |    motiverte(3)              |    Deutsch(4)                |    Visualforce(5)            |    Kundenfreundliches(6)     |    Ware(3)                   |
# |    IT(7)                     |    Gastronomie(3)            |    PKW-Fahrerlaubnis(2)      |    Leistungselektronik(3)    |    Deutschkenntnisse(4)      |    Javascript(5)             |                              |    Urteilsvermögen(6)        |
# |    CNC-Fachkraft(0)          |    Vertrieb(7)               |    Kunden(7)                 |    Demontage(3)              |    Englischkenntnisse(4)     |    ALM(5)                    |                              |    Produkten(3)              |
# |    FH/UNI(7)                 |    Frontend(3)               |    PKW-Führerschein(2)       |    Programmierkenntnisse(3)  |    Deutsch(4)                |    HTML(5)                   |    äusserst(7)               |    Kommunikation(3)          |
# |    Fachlagerist(0)           |    Empfang(3)                |    Pkw(7)                    |    Apps(3)                   |    Deutsch(4)                |    Apache(5)                 |    kommunikationsstarkes(6)  |    Breites(3)                |
# |    Fleischermeister(0)       |    Anlagenführer(1)          |    Reisebereitschaft(2)      |    Backend(3)                |    Deutschkenntnisse(4)      |    J2EE(5)                   |    Einfühlungsvermögen(6)    |    Berufsausbildung(0)       |
# |    GWH-Installateur(0)       |    Softwareentwickler(1)     |                              |    basierten(7)              |    Englisch(4)               |    Dresden(7)                |    Team(7)                   |    begeisterst(2)            |
# |    Psychosom(0)              |    Software-Tests(3)         |    Planung(2)                |    Programmierung(3)         |    Deutschkenntnisse(4)      |    Microsoft(5)              |    reagieren(7)              |    Impfschutz(2)             |
# |    Elektroniker(0)           |    Lkw-Fahrer(1)             |    PC(2)                     |                              |    Deutschkenntnisse(5)      |    Softwaretool(5)           |    Teamfähigkeit(6)          |    Geren(1)                  |
# |    kaufmännische(0)          |    Montage(2)                |    Reisebereitschaft(2)      |    Edelstahl(3)              |    Englischkenntnisse(4)     |    caret(5)                  |    Denkvermögen(7)           |    reflektiertes(6)          |
# |    Elektrotechnik(0)         |                              |    Kunden(2)                 |    Elektrophorese(3)         |    deutsch(4)                |    JavaScript(5)             |    prozessorientierte(2)     |    Trends(3)                 |
# |    Programmiererfahrung(3)   |                              |    Führerschein(2)           |    Schaltanlagen(3)          |    Deutschkenntnisse(4)      |    .Net(5)                   |    strukturierte(6)          |    serviceorientierten(3)    |
# |    Fachkraft(0)              |                              |    Fachdokumenten(7)         |    Steuerprotokolle(3)       |    Englisch(4)               |    Microsoft(5)              |    flexibel(6)               |    Produktionsprozesses(2)   |
# |    AbsolventIn(7)            |                              |    Wochenendarbeit(2)        |                              |    Englisch(4)               |    Revit(5)                  |    Teamfähigkeit(6)          |    Einführung(2)             |
# |    Anlagenmechaniker(0)      |                              |    Statur(7)                 |                              |    Englischkenntnisse(4)     |    UA(5)                     |    Detail(2)                 |    Veränderungsprozesse(2)   |
# |    Logopädie(3)              |                              |    Java-Projekten(2)         |    Softwareentwicklung(3)    |    Englisch(4)               |    Office(2)                 |    lösungsorientiertes(2)    |    sicheren(6)               |
# |    technischen(7)            |                              |    Tauglichkeit(7)           |    Fixed(3)                  |    Französisch(4)            |    iOS(5)                    |    Zuverlässigkeit(6)        |    Kenntnisse(4)             |
# |                              |                              |    Kunden(7)                 |    Automation(3)             |    Englischkenntnisse(4)     |    EPlan(5)                  |    lösungsorientierte(2)     |    Ausbildung(0)             |
# |    kaufmännische(0)          |                              |    Menschen(6)               |    Stack(7)                  |    Englisch(4)               |    Xamarin(5)                |    analytische(6)            |    Jahre(2)                  |
# |    Heilerziehungspfleger(0)  |                              |    Reisebereitschaft(2)      |    Security(3)               |    Deutschkenntnisse(4)      |    Java(5)                   |    Zuverlässigkeit(6)        |    Macherpersönlichkeit(6)   |
# |    Psychotherapie(3)         |                              |    Motoren-(3)               |    Detailhandel(1)           |    Englischkenntnisse(4)     |    OO(5)                     |    ungsgeschick(7)           |    PC/Laptop(2)              |
# |    Fleischerei(0)            |                              |    Schichtarbeit(2)          |    Active(3)                 |    Englischkenntnisse(4)     |    Message(3)                |    Teamfähigkeit(6)          |    Pharmaberater(1)          |
# |    Gas(3)                    |                              |    Moderation(7)             |    hochperformanten(7)       |    Englischkenntnisse(4)     |    Webentwicklung(3)         |    Auffassungsfaehigkeit(6)  |    Team(6)                   |
# |    Verwaltungsausbildung(7)  |                              |    Fahrausweis(2)            |    EDI(5)                    |    Muttersprache(7)          |    X.509-Zertifikaten(5)     |    Selbständiges(6)          |    Landessprache(4)          |
# |    kaufmännische(0)          |                              |    Lebensmittelbereich(3)    |    kulturellen(7)            |    Deutsch(4)                |    Java-Frameworks(5)        |    zielstrebig(6)            |    Durchführen(2)            |
# |    Gipser(0)                 |                              |    Konzeption(2)             |    Monitoring(5)             |    Deutsch(4)                |                              |    strukturiertes(6)         |    flexibler(6)              |
# |    IT-Umfeld(0)              |                              |    Denken(7)                 |    Trockenbau(3)             |    Deutschkenntnisse(4)      |    SQL(5)                    |    Genauigkeit(6)            |    Business-Gesprächen(6)    |
# |    Human(0)                  |                              |    prozessorientierten(2)    |    Lernens(3)                |    Englischkenntnisse(4)     |    Entwicklungstools(3)      |    Teamgeist(6)              |    Herstellung(3)            |
# |    Leistungselektronik(0)    |                              |    Nutzung(7)                |    AI(3)                     |    Deutschkenntnisse(4)      |    OO(5)                     |    zuverlässige(6)           |    Mitarbeit(2)              |
# |    Pflegefachperson(0)       |                              |    Kunden(2)                 |    Integration(2)            |    Deutschkenntnisse(4)      |    ERP-System(7)             |    Zuverlässigkeit(6)        |    selbstverständlich(6)     |
# |    Koch(0)                   |                              |    Handeln(7)                |    Webanwendungen(3)         |    Englisch(4)               |    Representational(7)       |    Kreativität(6)            |    MS-Office-Produkte(5)     |
# |    Informatik(0)             |                              |    Leitung(2)                |    Installations(3)          |    Deutsch(4)                |    .NET(5)                   |    Eigeninitiative(6)        |    systematischem(2)         |
# |    Erzieher(0)               |                              |    Reisebereitschaft(2)      |    Montageabteilung(2)       |    Deutschkenntnisse(4)      |    versierter(7)             |                              |    Tüftler-Gen(3)            |
# |    Textilingenieur(0)        |                              |    kundenspezifische(2)      |    Engineeringssystemen(3)   |    MS-Office-Kenntnisse(2)   |    CSS(5)                    |    flexibel(6)               |    21G(5)                    |
# |                              |                              |    Software(3)               |    Call(3)                   |    Deutschkenntnisse(4)      |    HTML5(5)                  |    selbstständigen(6)        |    PC-Kenntnisse(2)          |
# |    Betriebstechnik(0)        |                              |    externen(2)               |    HGB(3)                    |    Deutschkenntnisse(4)      |    Office-Paket(5)           |    Überzeugungskraft(6)      |    technisches(3)            |
# |    handwerklich(2)           |                              |    3-Schichtarbeit(2)        |    Programmierung(3)         |    Englischkenntnisse(4)     |    4HANA(7)                  |    Selbstaendiges(6)         |    Inhouse-Recruiting(3)     |
# |    Psychotherapie(3)         |                              |    Kundenberatung(3)         |    Lagerarbeit(3)            |    Englischkenntnisse(4)     |    C#(5)                     |    Belastbarkeit(6)          |    Verwaltungserfahrung(2)   |
# |    AbsolventIn(7)            |                              |    routinierte(7)            |    Betrieb(7)                |    Englischkenntnisse(4)     |    Java(5)                   |    analytischem(6)           |    Hörleistung(3)            |
# |    Heilpädagoge(0)           |                              |    Kundenorientierung(2)     |    Quality(7)                |    Englischkenntnisse(5)     |    Spring(5)                 |    absolute(7)               |    regionalen(3)             |
# |    Medieninformatik(0)       |                              |    Leistungsfreude(7)        |    Integration(3)            |                              |    Bürotechnologie(3)        |    Selbstständigkeit(6)      |    Macherpersönlichkeit(6)   |
# |    Psychologie(0)            |                              |    Vertrieb(2)               |    Transport(2)              |    Deutschkenntnisse(4)      |    Navigator(3)              |    motivieren(2)             |    CAS(5)                    |
# |    Technomathematik(0)       |                              |    Fahrerlaubnis(7)          |    Logos(3)                  |    Fremdsprache(7)           |    C#(5)                     |    lösungsorientiert(6)      |    schnell(6)                |
# |    Mechatronik(0)            |                              |    Kundenorientierung(2)     |    Quality(3)                |    verhandlungssichere(7)    |    Microsoft(5)              |    Kontaktfreude(7)          |    Agilität(6)               |
# |    Informatik(0)             |                              |    Fließenden(7)             |    Mountainbike(3)           |    Deutsch(4)                |    AngularJS(5)              |    Zuverlässigkeit(6)        |    Selbstverantwortung(6)    |
# |    Provisional(7)            |                              |    Kundenorientierung(2)     |    Applikationen(3)          |    Bevorzugt(7)              |                              |    Eigeninitiative(6)        |    Team(6)                   |
# |                              |                              |    bundesweite(7)            |    Transport(2)              |    Bevorzugt(7)              |    .NET(5)                   |                              |    Verantwortung(6)          |
# |    Psychosomatik(3)          |                              |    Montieren(3)              |    Webtechnologien(3)        |    Spanisch(4)               |    XML(5)                    |    Teamarbeit(6)             |    Inhouse-Recruiting(3)     |
# |    Bereit(7)                 |                              |    verkäuferische(2)         |    Altsysteme(7)             |    Deutsch(4)                |    JBoss(5)                  |    Sorgfalt(6)               |    Freundlichkeit(6)         |
# |    Informatikstudium(0)      |                              |    Gabelstaplerschein(3)     |    Derivatives(3)            |    Englischkenntnisse(4)     |    Microsoft(5)              |    Eigeninitiative(6)        |    Alter(2)                  |
# |    Mathematik(0)             |                              |    Denken(7)                 |    Medien(2)                 |    Englischkenntnisse(4)     |    Access(5)                 |    eigenverantwortliche(6)   |    Beziehungen(3)            |
# |    Heizung(3)                |                              |    zeitweilige(7)            |                              |    Englisch(4)               |    Hype(5)                   |    zuverlässige(6)           |    Strukturierte(6)          |
# |    IT-Sicherheit(0)          |                              |    VKR-Schweissprüfung(2)    |    Demontage(2)              |    Deutschkenntnisse(4)      |    Visual(5)                 |    Problemlösefähigkeit(2)   |    proaktiv(6)               |
# |    Schaltschrankbau(3)       |                              |    Konfigurieren(2)          |    Flugzeugbau(7)            |    Englischkenntnisse(4)     |    REST(7)                   |    Arbeitseinstellung(7)     |    komplexe(2)               |
# |    Medizin(0)                |                              |    begabt(7)                 |    HDX3D(7)                  |    Deutsch(4)                |    MS-Office(7)              |    Kontaktfreude(6)          |    Extrudern(3)              |
# |    Heilpädagogik(0)          |                              |    behinderten(2)            |    Banken(3)                 |    englisch(4)               |    MS(5)                     |    speditive(6)              |    Projekten(2)              |
# |    Landwirtschaftliche(0)    |                              |    Bedienung(7)              |    Sourcing(3)               |    Englischkenntnisse(4)     |    JBoss(5)                  |    Engagement(6)             |    Technologien(3)           |
# |    Wirtschaftsinformatik(0)  |                              |    Normen(2)                 |    Kunststoff-Schweißen(3)   |    Deutsch(4)                |    Web-basierte(3)           |    Zuverlässig(7)            |    verantwortungsvollen(6)   |
# |    Vorkontierung(3)          |                              |    Kundenorientierung(2)     |    Administration(7)         |    zweisprachig(7)           |    IT-Anwenderkenntnisse(2)  |    Teamfähigkeit(6)          |    Schwerpunkt(5)            |
# |    Psychologie(0)            |                              |    Java-Projekten(3)         |    Systeme(7)                |    Deutschkenntnisse(4)      |    REST(5)                   |    Kommunikation(6)          |    RowLevel(5)               |
# |    Krankenpfleger(0)         |                              |    Montagebereitschaft(7)    |    SPICE(5)                  |    Englisch(4)               |    CSS(5)                    |    Flexibilität(6)           |    entladen(3)               |
# |    Facharzt(7)               |                              |    Unterstützung(2)          |    IEF(5)                    |    Deutsch(4)                |    C++(5)                    |    Durchsetzungsvermögen(6)  |    initiative(6)             |
# |    Psychosomatik(3)          |                              |    umwelttechnisch(3)        |    Detailhandel(2)           |    Deutschkenntnisse(4)      |    APIs(7)                   |    teamorientierter(6)       |    Tools(3)                  |
# |    Wirtschaftsinformatik(0)  |                              |    unternehmerische(2)       |    Test(3)                   |    Deutschkenntnisse(4)      |    JUnit(5)                  |    Menschen(2)               |    patientenorientierte(3)   |
# |    Systemintegration(0)      |                              |    begabt(7)                 |    Steuerungstechnik(3)      |    Deutschkenntnisse(4)      |    CANoe(5)                  |    lösungsorientiertes(2)    |    Geschick(3)               |
# |    IT-Systemelektroniker(0)  |                              |    Projektbezogene(7)        |    relationalen(3)           |    Deutschkenntnisse(4)      |    Server-Architekturen(3)   |    Eigeninitiative(6)        |    soziale(3)                |
# |    Facharzt(7)               |                              |    Querdenker(7)             |    Deployment(3)             |    Englischkenntnisse(4)     |    UFT(5)                    |    kompetenten(6)            |    entladen(2)               |
# |    Sicherheitsbereich(7)     |                              |    Reisebereitschaft(2)      |    C_HANATEC_12(5)           |    Deutscher(4)              |    Windows(5)                |    Handwerkliche(3)          |    Fachkraft(0)              |
# |    Psychotherapie(3)         |                              |    Weiterentwicklung(7)      |    E-Health(3)               |    Italienisch(4)            |    JavaScript(5)             |    Einfühlungsvermögen(6)    |    Programmen(3)             |
# |    Facharzt(7)               |                              |    Fahrerlaubnis(2)          |    Programmierung(3)         |    deutscher(4)              |    Scripting(5)              |    konzeptionelle(6)         |    umzusetzen(2)             |
# |    Wissenschaften(0)         |                              |    Samstagsarbeit(2)         |    Kandidaten(7)             |    Englischkenntnisse(4)     |    Visual(5)                 |    verhandlungsstarke(2)     |    Kindern(3)                |
# |    FH(7)                     |                              |    Führerscheine(2)          |    Verdichtungsgeräte(3)     |    Französische(4)           |    3D(5)                     |    Genauigkeit(6)            |    Betreuung(3)              |
# |    Metallbearbeitung(0)      |                              |    Denken(2)                 |                              |    Französisch(4)            |    CMS(5)                    |    leistungsorientierte(6)   |    konstruktive(2)           |
# |    Psychosomatik(3)          |                              |    kaufmännisches(2)         |    UX(5)                     |    Deutschkenntnisse(4)      |    XD(5)                     |    Menschen(6)               |    Approbation(2)            |
# |    Architekturstudium(0)     |                              |    Kunden(7)                 |    Responsive(3)             |    Englisch(4)               |    27001(7)                  |    Verhandlungsgeschick(6)   |    PKW(2)                    |
# |    Bankkaufmann(0)           |                              |    Kunden(2)                 |    Innovationsprozesse(2)    |    deutschen(4)              |    Source(3)                 |                              |    Expert(1)                 |
# |    Psychiatrie(3)            |                              |    Kundenorientierung(2)     |    Fenstern(3)               |    Englisch(4)               |    Android(5)                |    konzentriert(6)           |    Durchführung(2)           |
# |    Facharzt(0)               |                              |                              |    Webtechnologien(3)        |    mündlich(7)               |    Projektabwicklung(7)      |    freundliches(7)           |    Fahrerkarte(2)            |
# |    Pädagogik(0)              |                              |    Denken(7)                 |    Softwareentwicklung(3)    |    Deutschkenntnisse(7)      |    Java(5)                   |    Flexibilität(6)           |    gesammelt(5)              |
# |    Produktdesign(0)          |                              |    Freundliche(6)            |    Baumgutachten(3)          |    Englischkenntnisse(4)     |    Datenbank-Anbindungen(5)  |                              |    Berufsausbildung(0)       |
# |    Informatik(0)             |                              |    Schichtarbeit(2)          |    Atemtherapie(3)           |    Deutschkenntnisse(4)      |    Keywords(7)               |    Zuverlässigkeit(6)        |    entwickeln(2)             |
# |    Psychotherapie(3)         |                              |    Technik(2)                |    Türen(3)                  |    Englischkenntnisse(2)     |    HTML5(5)                  |    Zeitliche(7)              |    installieren(2)           |
# |    Medieninformatik(0)       |                              |    Kundenorientierung(2)     |                              |    Italienisch(4)            |    XML(5)                    |    eigenständige(6)          |    Macherpersönlichkeit(6)   |
# |                              |                              |    Montage(2)                |    Engineering(3)            |    Englischkenntnisse(4)     |    SAP(5)                    |    engagierte(6)             |    Bereitschaft(2)           |
# |    Facharzt(0)               |                              |    Verkaufsgespräch(7)       |    Consors(7)                |    Deutschkenntnissen(4)     |    Eclipse(5)                |    Sorgfältige(6)            |    gesundheitlichen(3)       |
# |    Staatsexamen(7)           |                              |    Montagebereitschaft(7)    |    Simulationsverfahren(3)   |    Deutsch(4)                |    Scripting(5)              |    engagierte(6)             |    Zusammenarbeit(2)         |
# |    Führungserfahrung(0)      |                              |    agilen(3)                 |    Test(3)                   |    Spanisch(4)               |    Spring(5)                 |    Kontaktfreudige(6)        |    Grund(3)                  |
# |    ETH(7)                    |                              |    Kaufmännisches(6)         |    Absatzfinanzierung(3)     |    Englisch-Kenntnisse(4)    |    ABAP(5)                   |    serviceorientiert(2)      |    Kommunikation(6)          |
# |    Informationstechnik(0)    |                              |    Anwender-Support(3)       |    E-Health(7)               |    mündlich(7)               |    SQL(5)                    |    Selbständigkeit(6)        |    externenÂÂ(3)             |
# |    Finanzen(0)               |                              |    Anlieferungen(7)          |    Symbol(3)                 |    Englischkenntnisse(4)     |    Angular(5)                |    Flexibilität(6)           |    Innovationen(3)           |
# |    Mechatronik(3)            |                              |    Führerausweis(2)          |    Social(3)                 |    Deutsch(4)                |    ORACLE(5)                 |    Teamfähigkeit(6)          |    Versorgungsplanung(3)     |
# |    Fachärztin(7)             |                              |    Trainings(7)              |    Kindern(2)                |    Deutschkenntnisse(4)      |    HTML(5)                   |    auszuprobieren(7)         |    Agilität(2)               |
# |    Reife(6)                  |                              |    Führerschein(2)           |    Sanitär-(3)               |    Deutsch(4)                |    Eclipse-RCP(5)            |    Verhandlungsgeschick(6)   |    verantwortlich(2)         |
# |    Informatik(0)             |                              |    Führung(2)                |    Krankenhäusern(3)         |    Deutschkenntnisse(4)      |    Fanuc(5)                  |    Durchsetzungsvermögen(6)  |    Weiterbildung(2)          |
# |    Lagerlogistik(0)          |                              |    Beratungsumfeld(3)        |    IT(7)                     |    Englisch(4)               |                              |    Durchsetzungsvermögen(7)  |    Weiterbildung(3)          |
# |    Studienganges(7)          |                              |    digitalen(2)              |    Administration(2)         |    deutsche(4)               |    Cloud(5)                  |    Motivation(6)             |                              |
# |    Elektrotechnik(0)         |                              |    Abstraktionsvermögen(6)   |    maschinellen(3)           |    Bevorzugt(7)              |    Lotus(5)                  |    Flexibilität(6)           |                              |
# |    Pflegebasiskurs(0)        |                              |    Führungserfahrung(2)      |    Metall(3)                 |    Englisch(4)               |    IPMA(0)                   |    auszeichnet(7)            |    Kundenstandort(2)         |
# |    Informatik(0)             |                              |    Verkaufsgespräche(2)      |    Orthopädie(3)             |    ◾idealerweise(7)         |    Cloud(5)                  |    Beratungshaltung(6)       |    Tüftler-Gen(3)            |
# |    Einzelhandelskaufmann(1)  |                              |    Reisebereitschaft(7)      |    Peripherie(3)             |    Deutschkenntnisse(4)      |    Navision(5)               |    konzeptionelle(6)         |    einzuarbeiten(2)          |
# |    IT(7)                     |                              |    Kunden(7)                 |    Asset(3)                  |    deutsch(4)                |    PHP(5)                    |    Selbstständigkeit(6)      |    zuverlässigen(6)          |
# |    Informatik(0)             |                              |    Entschädigung(7)          |    IT(7)                     |    mündlich(7)               |    Steuerungen(7)            |    Zuverlässigkeit(6)        |    Private(3)                |
# |    Facharzt(0)               |                              |    Handeln(7)                |    Business(3)               |    Englisch(4)               |    ERP(7)                    |    schnelle(6)               |    Säule(3)                  |
# |    Wirtschaftsinformatik(0)  |                              |    Trainings(7)              |    Sourcing(3)               |    Italienisch(4)            |    AS(5)                     |    Flexibilität(6)           |    Ordnung(2)                |
# |    Fachinformatiker(0)       |                              |    Software(3)               |    Betriebssysteme(3)        |    Englischkenntnisse(4)     |    Heidenhain-(3)            |    Teamgeist(6)              |    elektronischen(3)         |
# |    Heilpädagogin(7)          |                              |    Führung(2)                |    Sozialmedizin(3)          |    MS-Office-Kenntnisse(7)   |    Python(5)                 |    Patientenorientierung(3)  |    Standard(2)               |
# |    Betriebswirt(0)           |                              |    PKW(7)                    |    CAE(5)                    |    Deutschkenntnisse(4)      |    NoSQL(5)                  |    Teamfähigkeit(6)          |    mitbringst(0)             |
# |    technische(0)             |                              |    technisches(7)            |    HDX3D(7)                  |    Englischkenntnisse(4)     |    AWS(5)                    |                              |    Veränderungen(2)          |
# |    Fachinformatiker(0)       |                              |    Gabelstaplerschein(2)     |    Infografik(3)             |    deutsch(4)                |    Node.js(5)                |    Teamarbeit(6)             |    unternehmerische(2)       |
# |    Hochschulstudium(7)       |                              |    Reisebereitschaft(2)      |    Architektur(3)            |    Englischkenntnisse(4)     |    C++(5)                    |    Selbständiges(6)          |    multikulturellen(3)       |
# |    Informatik(0)             |                              |    Führerschein(2)           |    ISO(7)                    |    Deutschkenntnisse(4)      |    Java(5)                   |    Qualitätsbewusstsein(2)   |    innovative(6)             |
# ...
# |                              |                              |                              |                              |                              |    MySQL(5)                  |                              |                              |
# |                              |                              |                              |                              |                              |    Python(5)                 |    analytische(6)            |                              |
# |                              |                              |                              |                              |                              |    C++(5)                    |                              |                              |
# |                              |                              |                              |                              |                              |    EE(5)                     |    Kontaktfreudige(6)        |                              |
# |                              |                              |                              |                              |                              |    CSS(5)                    |    Pünktlichkeit(6)          |                              |
# |                              |                              |                              |                              |                              |    Spring(5)                 |    Sozialkompetenz(6)        |                              |
# |                              |                              |                              |                              |                              |    IoT(5)                    |    Kreativität(6)            |                              |
# |                              |                              |                              |                              |                              |    PHPStorm(5)               |    Äußeres(7)                |                              |
# |                              |                              |                              |                              |                              |    PHP(5)                    |    Teamfähigkeit(6)          |                              |
# |                              |                              |                              |                              |                              |    Web(3)                    |                              |                              |
# |                              |                              |                              |                              |                              |    Javascript(5)             |    Managementkompetenz(3)    |                              |
# |                              |                              |                              |                              |                              |    VBA(5)                    |    mobil(2)                  |                              |
# |                              |                              |                              |                              |                              |    http(5)                   |    strukturiertes(6)         |                              |
# |                              |                              |                              |                              |                              |    XSLT(5)                   |    Sozialkompetenz(6)        |                              |
# |                              |                              |                              |                              |                              |    OOD(5)                    |    Teamorientierung(6)       |                              |
# |                              |                              |                              |                              |                              |    STL(5)                    |    selbstständige(6)         |                              |
# |                              |                              |                              |                              |                              |    Laravel(5)                |    strukturierte(6)          |                              |
# |                              |                              |                              |                              |                              |    Ivanti(5)                 |                              |                              |
# |                              |                              |                              |                              |                              |    SAP(5)                    |    aufgeschlossenes(6)       |                              |
# |                              |                              |                              |                              |                              |    Lizenzerfahrung(5)        |    Motivation(6)             |                              |
# |                              |                              |                              |                              |                              |    O/R(3)                    |    Flexibilität(6)           |                              |
# |                              |                              |                              |                              |                              |    Java(5)                   |    engagierte(6)             |                              |
# |                              |                              |                              |                              |                              |    S(7)                      |    Teamfähigkeit(6)          |                              |
# |                              |                              |                              |                              |                              |    WCF(5)                    |    Denkweise(7)              |                              |
# |                              |                              |                              |                              |                              |    Gitflow(5)                |    lösungsorientierte(6)     |                              |
# |                              |                              |                              |                              |                              |    Node.js(5)                |    Gesprächskompetenz(6)     |                              |
# |                              |                              |                              |                              |                              |    CNC-Bearbeitung(5)        |    Sorgfältige(6)            |                              |
# |                              |                              |                              |                              |                              |    CISM(5)                   |    Eigeninitiative(6)        |                              |
# |                              |                              |                              |                              |                              |    CSS(5)                    |    Flexibilität(6)           |                              |
# |                              |                              |                              |                              |                              |    OO(5)                     |    eigenen(7)                |                              |
# |                              |                              |                              |                              |                              |    Eclipse(5)                |    zielstrebige(6)           |                              |
# |                              |                              |                              |                              |                              |    JavaScript(5)             |    kreatives(6)              |                              |
# |                              |                              |                              |                              |                              |    HTML5(5)                  |    Leistungsbereitschaft(6)  |                              |
# |                              |                              |                              |                              |                              |    CSS(5)                    |    Einsatzbereitschaft(6)    |                              |
# |                              |                              |                              |                              |                              |    Network(5)                |    Eigeninitiative(6)        |                              |
# |                              |                              |                              |                              |                              |                              |    Exakte(2)                 |                              |
# |                              |                              |                              |                              |                              |    Sharepoint(5)             |    Beratungskompetenz(6)     |                              |
# |                              |                              |                              |                              |                              |    REST(5)                   |    Auffassungsgabe(7)        |                              |
# |                              |                              |                              |                              |                              |    HTML5(5)                  |    Leistungsbereitschaft(6)  |                              |
# |                              |                              |                              |                              |                              |    JavaScript(5)             |    Eigeninitiative(6)        |                              |
# |                              |                              |                              |                              |                              |    Deploymentprozesse(3)     |                              |                              |
# |                              |                              |                              |                              |                              |    JEE(7)                    |    Neues(7)                  |                              |
# |                              |                              |                              |                              |                              |    Adobe(5)                  |    selbstständige(6)         |                              |
# |                              |                              |                              |                              |                              |    SAP(5)                    |    Selbständige(6)           |                              |
# |                              |                              |                              |                              |                              |                              |    Erscheinungsbild(7)       |                              |
# |                              |                              |                              |                              |                              |    Windchill(5)              |                              |                              |
# |                              |                              |                              |                              |                              |    LabView(5)                |    eigenverantwortliche(6)   |                              |
# |                              |                              |                              |                              |                              |    C#(5)                     |    Teamfähigkeit(6)          |                              |
# |                              |                              |                              |                              |                              |    Symfony(5)                |    Teamfähigkeit(6)          |                              |
# |                              |                              |                              |                              |                              |    Kubernetes(7)             |    betreffend(7)             |                              |
# |                              |                              |                              |                              |                              |    Cloud(7)                  |    rasche(7)                 |                              |
# |                              |                              |                              |                              |                              |    JFace(5)                  |    Team(6)                   |                              |
# |                              |                              |                              |                              |                              |    JavaScript(5)             |    Flexible(6)               |                              |
# |                              |                              |                              |                              |                              |    Programmiersprachen(3)    |    selbständige(7)           |                              |
# |                              |                              |                              |                              |                              |    SQL(5)                    |    analytische(2)            |                              |
# |                              |                              |                              |                              |                              |    Server(3)                 |                              |                              |
# |                              |                              |                              |                              |                              |    MacBook(5)                |                              |                              |
# |                              |                              |                              |                              |                              |    Office(5)                 |    Flexibilität(6)           |                              |
# |                              |                              |                              |                              |                              |    AngularJS(5)              |    strukturierten(6)         |                              |
# |                              |                              |                              |                              |                              |    Frameworks(3)             |    Kreativität(6)            |                              |
# |                              |                              |                              |                              |                              |    Unity(5)                  |    Leistungsbereitschaft(6)  |                              |
# |                              |                              |                              |                              |                              |    Web(3)                    |                              |                              |
# |                              |                              |                              |                              |                              |    MS(7)                     |    Initiative(6)             |                              |
# |                              |                              |                              |                              |                              |    .Net(5)                   |    Teamfähigkeit(6)          |                              |
